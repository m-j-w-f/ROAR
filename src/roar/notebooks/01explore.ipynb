# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Data Exploration

# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
import polars as pl
import seaborn as sns

from roar import (
    ALL_VEHICLES,
    EXTRAS_DIR,
    ROOT_DIR,
    TRACK_COLORS,
    TYRE_COLORS,
    VEHICLE_CLEAN_NAMES,
    VEHICLE_COLORS,
)
from roar.preprocessing import get_channel_mapping, load_data_df

# Set style for clean, modern plots
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (7, 5)
plt.rcParams["figure.dpi"] = 100

# %%
# Some data cleaning for better usability
all_channel_names = pl.read_csv(EXTRAS_DIR / "all_measurement_channels_name.csv")
all_channel_names = all_channel_names.with_columns(
    pl.col("vehicle")
    .str.split(",")
    .replace(VEHICLE_CLEAN_NAMES)
    .replace({tuple(["alle"]): ALL_VEHICLES})
    .list.eval(pl.element().str.strip_prefix(" ").replace(VEHICLE_CLEAN_NAMES)),
    pl.col("relevance").cast(pl.Categorical),
)
all_channel_names
# Out:
# shape: (136, 6)
# ┌──────────────────────┬──────────────────┬─────────────────┬───────────┬──────────────┬───────────┐
# │ description          ┆ channel_name     ┆ synonym_1       ┆ synonym_2 ┆ vehicle      ┆ relevance │
# │ ---                  ┆ ---              ┆ ---             ┆ ---       ┆ ---          ┆ ---       │
# │ str                  ┆ str              ┆ str             ┆ str       ┆ list[str]    ┆ cat       │
# ╞══════════════════════╪══════════════════╪═════════════════╪═══════════╪══════════════╪═══════════╡
# │ Fzg-CAN - Antrieb    ┆ Antrieb          ┆ null            ┆ null      ┆ ["ID.4"]     ┆ nein      │
# │ Fzg-CAN              ┆ BCM1_Aussen_Temp ┆ null            ┆ null      ┆ ["ID.4", "Q8 ┆ ja        │
# │                      ┆                  ┆                 ┆           ┆ e-tron", …   ┆           │
# │                      ┆                  ┆                 ┆           ┆ "E-Gol…      ┆           │
# │ HEAD-CAN - labCTRL   ┆ CAN1_labCTRLI_   ┆ null            ┆ null      ┆ ["ID.4", "Q8 ┆ nein      │
# │                      ┆                  ┆                 ┆           ┆ e-tron", …   ┆           │
# │                      ┆                  ┆                 ┆           ┆ "E-Gol…      ┆           │
# │ HEAD-CAN - labDX     ┆ CAN1_labDX_B     ┆ null            ┆ null      ┆ ["ID.4", "Q8 ┆ nein      │
# │                      ┆                  ┆                 ┆           ┆ e-tron", …   ┆           │
# │                      ┆                  ┆                 ┆           ┆ "E-Gol…      ┆           │
# │ SIS - Trailing Edge  ┆ Ch_1_labV12      ┆ TrailK1         ┆ null      ┆ ["ID.4", "Q8 ┆ ja        │
# │ - K1                 ┆                  ┆                 ┆           ┆ e-tron", …   ┆           │
# │                      ┆                  ┆                 ┆           ┆ "E-Gol…      ┆           │
# │ …                    ┆ …                ┆ …               ┆ …         ┆ …            ┆ …         │
# │ iMAR                 ┆ v_east_CAN_Sig_  ┆ null            ┆ null      ┆ ["ID.4", "Q8 ┆ ja        │
# │                      ┆                  ┆                 ┆           ┆ e-tron", …   ┆           │
# │                      ┆                  ┆                 ┆           ┆ "E-Gol…      ┆           │
# │ iMAR                 ┆ v_north_CAN_Sig  ┆ null            ┆ null      ┆ ["ID.4", "Q8 ┆ ja        │
# │                      ┆                  ┆                 ┆           ┆ e-tron", …   ┆           │
# │                      ┆                  ┆                 ┆           ┆ "E-Gol…      ┆           │
# │ iMAR                 ┆ v_up_CAN_Sig_11  ┆ v_up_CAN_Sig_21 ┆ null      ┆ ["ID.4", "Q8 ┆ ja        │
# │                      ┆                  ┆                 ┆           ┆ e-tron", …   ┆           │
# │                      ┆                  ┆                 ┆           ┆ "E-Gol…      ┆           │
# │ iMAR                 ┆ xAlt_CAN_Sig_14  ┆ xAlt_CAN_Sig_27 ┆ null      ┆ ["ID.4", "Q8 ┆ evtl      │
# │                      ┆                  ┆                 ┆           ┆ e-tron", …   ┆           │
# │                      ┆                  ┆                 ┆           ┆ "E-Gol…      ┆           │
# │ iMAR                 ┆ yaw_CAN_Sig_15_  ┆ yaw_CAN_Sig_8_  ┆ null      ┆ ["ID.4", "Q8 ┆ evtl      │
# │                      ┆                  ┆                 ┆           ┆ e-tron", …   ┆           │
# │                      ┆                  ┆                 ┆           ┆ "E-Gol…      ┆           │
# └──────────────────────┴──────────────────┴─────────────────┴───────────┴──────────────┴───────────┘

# %%
with pl.Config(tbl_rows=31, tbl_cols=6):
    print(all_channel_names.filter(pl.col("relevance") == "ja"))
# Out:
# shape: (31, 6)
# ┌─────────────────┬─────────────────┬────────────────┬────────────────┬────────────────┬───────────┐
# │ description     ┆ channel_name    ┆ synonym_1      ┆ synonym_2      ┆ vehicle        ┆ relevance │
# │ ---             ┆ ---             ┆ ---            ┆ ---            ┆ ---            ┆ ---       │
# │ str             ┆ str             ┆ str            ┆ str            ┆ list[str]      ┆ cat       │
# ╞═════════════════╪═════════════════╪════════════════╪════════════════╪════════════════╪═══════════╡
# │ Fzg-CAN         ┆ BCM1_Aussen_Tem ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆ p               ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ SIS - Trailing  ┆ Ch_1_labV12     ┆ TrailK1        ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ Edge - K1       ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ SIS - Trailing  ┆ Ch_2_labV12     ┆ TrailK2        ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ Edge - K2       ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ SIS - Leading   ┆ Ch_3_labV12     ┆ LeadK1         ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ Edge - K1       ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ SIS - Leading   ┆ Ch_4_labV12     ┆ LeadK2         ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ Edge - K2       ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Stra�entemperat ┆ Ch_5_labV12     ┆ Temperatur     ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ ur              ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Luftfeuchte -   ┆ Ch_7_labV12     ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ Umgebung        ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Lufttemperatur  ┆ Ch_8_labV12     ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ - Umgebung      ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Fzg-CAN         ┆ ESP_HL_Radgesch ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆ w               ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Fzg-CAN         ┆ ESP_HR_Radgesch ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆ w               ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Fzg-CAN         ┆ ESP_VL_Radgesch ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆ w               ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Fzg-CAN         ┆ ESP_VR_Radgesch ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆ w               ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Fzg-CAN         ┆ FA_Hoehenwert_H ┆ null           ┆ null           ┆ ["Q8 e-tron",  ┆ ja        │
# │                 ┆ L               ┆                ┆                ┆ "Taycan"]      ┆           │
# │ Fzg-CAN         ┆ FA_Hoehenwert_H ┆ null           ┆ null           ┆ ["Q8 e-tron",  ┆ ja        │
# │                 ┆ R               ┆                ┆                ┆ "Taycan"]      ┆           │
# │ Fzg-CAN         ┆ FA_Hoehenwert_V ┆ null           ┆ null           ┆ ["Q8 e-tron",  ┆ ja        │
# │                 ┆ L               ┆                ┆                ┆ "Taycan"]      ┆           │
# │ Fzg-CAN         ┆ FA_Hoehenwert_V ┆ null           ┆ null           ┆ ["Q8 e-tron",  ┆ ja        │
# │                 ┆ R               ┆                ┆                ┆ "Taycan"]      ┆           │
# │ Thermokamera -  ┆ IREnd           ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ Endbild         ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Thermokamera -  ┆ IRStart         ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ Startbild       ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ iMAR            ┆ Lat_CAN_Sig_13_ ┆ Lat_CAN_Sig_25 ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆ _              ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ iMAR            ┆ Long_CAN_Sig_12 ┆ Long_CAN_Sig_2 ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆ 3              ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ NAWS            ┆ NAWSPressure    ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ NAWS            ┆ NAWSSound       ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ NAWS            ┆ NAWSTemperature ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ iMAR            ┆ a_x_CAN_Sig_4_  ┆ a_x_CAN_Sig_6_ ┆ a_x_CAN_Sig_10 ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆                ┆ _              ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ iMAR            ┆ a_y_CAN_Sig_3_  ┆ a_y_CAN_Sig_5_ ┆ a_y_CAN_Sig_9_ ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ iMAR            ┆ a_z_CAN_Sig_5_  ┆ a_z_CAN_Sig_7_ ┆ a_z_CAN_Sig_11 ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆                ┆ _              ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ iMAR            ┆ bUTC_CAN_Sig_24 ┆ bUTC_CAN_Sig_4 ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆ 1              ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ Mikrofon - Vorb ┆ mic_iso         ┆ MikrofonOst    ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │ eifahrtger�usch ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ iMAR            ┆ v_east_CAN_Sig_ ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ iMAR            ┆ v_north_CAN_Sig ┆ null           ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆                ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# │ iMAR            ┆ v_up_CAN_Sig_11 ┆ v_up_CAN_Sig_2 ┆ null           ┆ ["ID.4", "Q8   ┆ ja        │
# │                 ┆                 ┆ 1              ┆                ┆ e-tron", …     ┆           │
# │                 ┆                 ┆                ┆                ┆ "E-Gol…        ┆           │
# └─────────────────┴─────────────────┴────────────────┴────────────────┴────────────────┴───────────┘

# %%
# Speed/measurement type information
speed_info = pl.read_csv(EXTRAS_DIR / "speed.csv")
speed_info
# Out:
# shape: (6, 6)
# ┌──────────────────────────┬────────────┬───────────┬─────────┬─────────┬──────────────┐
# │ messtyp                  ┆ short_name ┆ meas_name ┆ min_kph ┆ max_kph ┆ acceleration │
# │ ---                      ┆ ---        ┆ ---       ┆ ---     ┆ ---     ┆ ---          │
# │ str                      ┆ str        ┆ str       ┆ i64     ┆ i64     ┆ i64          │
# ╞══════════════════════════╪════════════╪═══════════╪═════════╪═════════╪══════════════╡
# │ v1 = 45 km/h  / 80 km/h  ┆ v1         ┆ mess0     ┆ 45      ┆ 80      ┆ null         │
# │ v2 = 80 km/h  / 100 km/h ┆ v2         ┆ mess1     ┆ 80      ┆ 100     ┆ null         │
# │ v3 = 100 km/h / 120 km/h ┆ v3         ┆ mess2     ┆ 100     ┆ 120     ┆ null         │
# │ a1 = 1 m/s²              ┆ a1         ┆ mess3     ┆ null    ┆ null    ┆ 1            │
# │ a2 = 2 m/s²              ┆ a2         ┆ mess4     ┆ null    ┆ null    ┆ 2            │
# │ a3 = 3 m/s²              ┆ a3         ┆ mess5     ┆ null    ┆ null    ┆ 3            │
# └──────────────────────────┴────────────┴───────────┴─────────┴─────────┴──────────────┘

# %%
# Track information
tracks = pl.read_csv(EXTRAS_DIR / "tracks.csv")
tracks
# Out:
# shape: (3, 5)
# ┌──────────┬────────────────────┬──────────────────────┬─────────────────────┬─────────────────────┐
# │ track_ID ┆ name               ┆ gps                  ┆ gps_start           ┆ gps_ende            │
# │ ---      ┆ ---                ┆ ---                  ┆ ---                 ┆ ---                 │
# │ i64      ┆ str                ┆ str                  ┆ str                 ┆ str                 │
# ╞══════════╪════════════════════╪══════════════════════╪═════════════════════╪═════════════════════╡
# │ 150      ┆ Unknown Test Track ┆ null                 ┆ null                ┆ null                │
# │ 211      ┆ ika Teststrecke    ┆ 50.79101691007796,   ┆ 50.79115036301304,  ┆ 50.790885556264705, │
# │          ┆                    ┆ 6.048780870…         ┆ 6.049006938…        ┆ 6.04855011…         │
# │ 259      ┆ ika - ISO          ┆ 50.79101691007796,   ┆ 50.79115036301304,  ┆ 50.790885556264705, │
# │          ┆                    ┆ 6.048780870…         ┆ 6.049006938…        ┆ 6.04855011…         │
# └──────────┴────────────────────┴──────────────────────┴─────────────────────┴─────────────────────┘

# %%
# tyre information
tyres = pl.read_csv(EXTRAS_DIR / "tyres.csv")
print(tyres.select("hersteller", "name", "fahrzeug"))
# Out:
# shape: (6, 3)
# ┌─────────────┬──────────────────────┬───────────┐
# │ hersteller  ┆ name                 ┆ fahrzeug  │
# │ ---         ┆ ---                  ┆ ---       │
# │ str         ┆ str                  ┆ str       │
# ╞═════════════╪══════════════════════╪═══════════╡
# │ Continental ┆ EcoContact 6 Q       ┆ ID.4      │
# │ Uniroyal    ┆ RainSport 5          ┆ ID.4      │
# │ Continental ┆ Premium Contact 6 AO ┆ Q8 e-tron │
# │ Pirelli     ┆ P-Zero R             ┆ Taycan    │
# │ Hankook     ┆ Ventus S1 evo3 ev    ┆ Q8 e-tron │
# │ BFGoodrich  ┆ Summer SRTT          ┆ E-Golf    │
# └─────────────┴──────────────────────┴───────────┘

# %% [markdown]
# ## Load the h5 files
# And investigate the contents

# %% [markdown]
# ### Overview of the data files
# List and inspect HDF5 files in the dataset to understand the layout of available experiments, file metadata (vehicle, track, tyre).

# %%
# List all h5 files in the data directory
files_df = load_data_df()
files_df
# Out:
# shape: (204, 7)
# ┌────────────────────┬───────────────────┬───────────┬─────────┬──────────┬─────────┬──────────────┐
# │ file_path          ┆ file_stem         ┆ vehicle   ┆ tyre_ID ┆ track_ID ┆ measure ┆ date         │
# │ ---                ┆ ---               ┆ ---       ┆ ---     ┆ ---      ┆ ---     ┆ ---          │
# │ str                ┆ str               ┆ str       ┆ i64     ┆ i64      ┆ cat     ┆ datetime[μs] │
# ╞════════════════════╪═══════════════════╪═══════════╪═════════╪══════════╪═════════╪══════════════╡
# │ /Users/moritzfeik/ ┆ track150_Q8 e-tro ┆ Q8 e-tron ┆ 12      ┆ 150      ┆ meas1   ┆ 2025-08-15   │
# │ Developer/RO…      ┆ n_tyre12_meas…    ┆           ┆         ┆          ┆         ┆ 13:11:23     │
# │ /Users/moritzfeik/ ┆ track150_Q8 e-tro ┆ Q8 e-tron ┆ 12      ┆ 150      ┆ meas1   ┆ 2025-08-15   │
# │ Developer/RO…      ┆ n_tyre12_meas…    ┆           ┆         ┆          ┆         ┆ 13:13:03     │
# │ /Users/moritzfeik/ ┆ track150_Q8 e-tro ┆ Q8 e-tron ┆ 12      ┆ 150      ┆ meas2   ┆ 2025-08-15   │
# │ Developer/RO…      ┆ n_tyre12_meas…    ┆           ┆         ┆          ┆         ┆ 13:15:55     │
# │ /Users/moritzfeik/ ┆ track150_Q8 e-tro ┆ Q8 e-tron ┆ 12      ┆ 150      ┆ meas1   ┆ 2025-08-15   │
# │ Developer/RO…      ┆ n_tyre12_meas…    ┆           ┆         ┆          ┆         ┆ 13:06:24     │
# │ /Users/moritzfeik/ ┆ track150_Q8 e-tro ┆ Q8 e-tron ┆ 12      ┆ 150      ┆ meas2   ┆ 2025-08-15   │
# │ Developer/RO…      ┆ n_tyre12_meas…    ┆           ┆         ┆          ┆         ┆ 13:15:11     │
# │ …                  ┆ …                 ┆ …         ┆ …       ┆ …        ┆ …       ┆ …            │
# │ /Users/moritzfeik/ ┆ track211_E-Golf_t ┆ E-Golf    ┆ 13      ┆ 211      ┆ meas2   ┆ 2025-09-26   │
# │ Developer/RO…      ┆ yre13_meas2_2…    ┆           ┆         ┆          ┆         ┆ 14:51:55     │
# │ /Users/moritzfeik/ ┆ track211_E-Golf_t ┆ E-Golf    ┆ 13      ┆ 211      ┆ meas5   ┆ 2025-09-26   │
# │ Developer/RO…      ┆ yre13_meas5_2…    ┆           ┆         ┆          ┆         ┆ 15:11:17     │
# │ /Users/moritzfeik/ ┆ track211_E-Golf_t ┆ E-Golf    ┆ 13      ┆ 211      ┆ meas2   ┆ 2025-09-26   │
# │ Developer/RO…      ┆ yre13_meas2_2…    ┆           ┆         ┆          ┆         ┆ 14:51:05     │
# │ /Users/moritzfeik/ ┆ track211_E-Golf_t ┆ E-Golf    ┆ 13      ┆ 211      ┆ meas5   ┆ 2025-09-26   │
# │ Developer/RO…      ┆ yre13_meas5_2…    ┆           ┆         ┆          ┆         ┆ 15:09:38     │
# │ /Users/moritzfeik/ ┆ track211_E-Golf_t ┆ E-Golf    ┆ 13      ┆ 211      ┆ meas6   ┆ 2025-09-26   │
# │ Developer/RO…      ┆ yre13_meas6_2…    ┆           ┆         ┆          ┆         ┆ 15:15:26     │
# └────────────────────┴───────────────────┴───────────┴─────────┴──────────┴─────────┴──────────────┘

# %% [markdown]
# ### Extract variables and sample rates from HDF5
# Extract HDF5 dataset variables and read properties like variable shape and sample rate to know which channels exist in each file and the sampling frequency.

# %%
def extract_h5_variables(filename):
    """Extract variable information from an HDF5 file."""
    variables = []

    with h5py.File(filename, "r") as f:

        def collect_datasets(name, obj):
            if isinstance(obj, h5py.Dataset):
                # Get sample_rate from attributes if it exists
                sample_rate = obj.attrs.get("sample_rate", None)
                if isinstance(sample_rate, np.ndarray):
                    sample_rate = sample_rate.item()
                else:
                    sample_rate = None

                variables.append(
                    {
                        "variable_name": name,
                        "variable_shape": list(obj.shape),
                        "sample_rate": sample_rate,
                    }
                )

        f.visititems(collect_datasets)

    return variables


def expand_files_with_variables_efficient(files_df, filename_col="file_path"):
    """More efficient version using Polars operations."""
    struct_schema = pl.Struct(
        {
            "variable_name": pl.Utf8,
            "variable_shape": pl.List(pl.Int64),
            "sample_rate": pl.Float64(),
        }
    )

    # Apply extraction to each file and explode
    expanded_df = (
        files_df.with_columns(
            pl.col(filename_col)
            .map_elements(extract_h5_variables, return_dtype=pl.List(struct_schema))
            .alias("variables")
        )
        .explode("variables")
        .unnest("variables")
    )

    # Fix the variable_name using all_channel_names
    mapping_dict = get_channel_mapping()
    expanded_df = expanded_df.with_columns(pl.col("variable_name").replace(mapping_dict))

    return expanded_df


files_df_expanded = expand_files_with_variables_efficient(files_df)
files_df_expanded
# Out:
# shape: (16_815, 10)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ file_path  ┆ file_stem ┆ vehicle   ┆ tyre_ID ┆ … ┆ date      ┆ variable_ ┆ variable_ ┆ sample_ra │
# │ ---        ┆ ---       ┆ ---       ┆ ---     ┆   ┆ ---       ┆ name      ┆ shape     ┆ te        │
# │ str        ┆ str       ┆ str       ┆ i64     ┆   ┆ datetime[ ┆ ---       ┆ ---       ┆ ---       │
# │            ┆           ┆           ┆         ┆   ┆ μs]       ┆ str       ┆ list[i64] ┆ f64       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ 2025-08-1 ┆ BCM1_Auss ┆ [1, 7300] ┆ 1000.0    │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ 5         ┆ en_Temp   ┆           ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆ 13:11:23  ┆           ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ 2025-08-1 ┆ CAN1_labC ┆ [1,       ┆ 36000.0   │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ 5         ┆ TRLI_     ┆ 262800]   ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆ 13:11:23  ┆           ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ 2025-08-1 ┆ CAN2_labD ┆ [1,       ┆ 72000.0   │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ 5         ┆ X_B       ┆ 525600]   ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆ 13:11:23  ┆           ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ 2025-08-1 ┆ Ch_1_labV ┆ [1,       ┆ 48000.0   │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ 5         ┆ 12        ┆ 350400]   ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆ 13:11:23  ┆           ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ 2025-08-1 ┆ Ch_1_labV ┆ [350400]  ┆ 48000.0   │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ 5         ┆ 12_cleane ┆           ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆ 13:11:23  ┆ d         ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …         ┆ …         ┆ …       ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ 2025-09-2 ┆ v_east_CA ┆ [1,       ┆ 1000.0    │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ 6         ┆ N_Sig_    ┆ 10000]    ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆ 15:15:26  ┆           ┆           ┆           │
# │ …          ┆ 6_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ 2025-09-2 ┆ v_north_C ┆ [1,       ┆ 1000.0    │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ 6         ┆ AN_Sig    ┆ 10000]    ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆ 15:15:26  ┆           ┆           ┆           │
# │ …          ┆ 6_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ 2025-09-2 ┆ v_up_CAN_ ┆ [1,       ┆ 1000.0    │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ 6         ┆ Sig_11    ┆ 10000]    ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆ 15:15:26  ┆           ┆           ┆           │
# │ …          ┆ 6_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ 2025-09-2 ┆ xAlt_CAN_ ┆ [1,       ┆ 1000.0    │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ 6         ┆ Sig_14    ┆ 10000]    ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆ 15:15:26  ┆           ┆           ┆           │
# │ …          ┆ 6_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ 2025-09-2 ┆ yaw_CAN_S ┆ [1,       ┆ 1000.0    │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ 6         ┆ ig_15_    ┆ 10000]    ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆ 15:15:26  ┆           ┆           ┆           │
# │ …          ┆ 6_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Filter relevant channels
# Use the `all_channel_names` relevance flag to keep only channels we care about for analysis (e.g., audio and sensor channels), and round the sample rate for easier grouping and plotting.

# %%
files_df_expanded_relevant = (
    files_df_expanded.join(
        all_channel_names.select(pl.col("channel_name"), pl.col("relevance")),
        left_on="variable_name",
        right_on="channel_name",
        how="left",
    )
    .filter(pl.col("relevance") == "ja")
    .with_columns(pl.col("sample_rate").round(1))
)

# %% [markdown]
# # Visualizing dataset distribution and sampling characteristics
# We'll create a series of visualizations to inspect how experiments are distributed across tyres, vehicles, and tracks, as well as to analyze sample rates and recording durations. This helps us find skews, missing combinations, and sampling inconsistencies.

# %%
# Tyre distribution pie chart
pdf = (
    files_df.group_by("tyre_ID")
    .agg(pl.col("file_path").n_unique().alias("experiments"))
    .sort("tyre_ID")
    .to_pandas()
)

fig, ax = plt.subplots(figsize=(8, 6))
colors = [TYRE_COLORS.get(t, "#95a5a6") for t in pdf["tyre_ID"]]

ax.pie(
    pdf["experiments"],
    labels=[f"Tyre {t}" for t in pdf["tyre_ID"]],
    autopct="%1.1f%%",
    colors=colors,
    startangle=90,
    explode=[0.02] * len(pdf),
    shadow=False,
    wedgeprops={"edgecolor": "white", "linewidth": 2},
    textprops={"fontsize": 16},
)

ax.set_title("Experiments by Tyre ID", fontsize=18)
plt.tight_layout()
plt.savefig(ROOT_DIR / "plots" / "experiments_per_tyre_id_pie.pdf", dpi=300)

# %%
# Pie chart of experiments by Vehicle
pdf = (
    files_df.group_by("vehicle")
    .agg(pl.col("file_path").n_unique().alias("experiments"))
    .sort("vehicle")
    .to_pandas()
)

fig, ax = plt.subplots(figsize=(8, 6))
colors = [VEHICLE_COLORS.get(v, "#95a5a6") for v in pdf["vehicle"]]

# Clean vehicle names for display
clean_labels = [v.split(" ", 1)[1] if " " in v else v for v in pdf["vehicle"]]

ax.pie(
    pdf["experiments"],
    labels=clean_labels,
    autopct="%1.1f%%",
    colors=colors,
    startangle=90,
    explode=[0.02] * len(pdf),
    shadow=False,
    wedgeprops={"edgecolor": "white", "linewidth": 2},
    textprops={"fontsize": 16},
)

ax.set_title("Experiments by Vehicle", fontsize=18)
plt.tight_layout()
plt.savefig(ROOT_DIR / "plots" / "experiments_per_vehicle_pie.pdf", dpi=300)

# %%
# Experiments per Track ID
tracks_cnt = files_df.group_by("track_ID").agg(pl.len().alias("count"))
ax = plt.subplots(figsize=(6, 6))[1]
fig = sns.barplot(
    tracks_cnt, x="track_ID", y="count", hue="track_ID", ax=ax, palette=TRACK_COLORS, legend=False
)
fig.set_xlabel("Track ID", fontsize=16)
fig.set_ylabel("Number of Experiments", fontsize=16)
fig.set_title("Number of Experiments per Track ID", fontsize=18)
fig.tick_params(axis="both", labelsize=14)
fig.xaxis.label.set_text("Track ID")
fig.yaxis.label.set_text("Number of Experiments")
plt.tight_layout()
plt.savefig(ROOT_DIR / "plots" / "experiments_per_track_id.pdf", dpi=300)

# %%
# Heatmap of Tyre × Track experiments
pdf = (
    files_df.group_by(["tyre_ID", "track_ID"])
    .agg(pl.col("file_path").n_unique().alias("experiments"))
    .to_pandas()
)

pivot_data = pdf.pivot(index="tyre_ID", columns="track_ID", values="experiments")

fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(
    pivot_data,
    annot=True,
    fmt=".0f",
    cmap="flare_r",
    ax=ax,
    cbar_kws={"label": "Experiments", "shrink": 0.8},
    annot_kws={"fontsize": 11, "fontweight": "bold"},
    linewidths=0.5,
    linecolor="white",
)
ax.set_xlabel("Track ID", fontsize=12)
ax.set_ylabel("Tyre ID", fontsize=12)
ax.set_title("Experiments: Tyre × Track", fontsize=14, pad=15)
plt.tight_layout()
plt.savefig(ROOT_DIR / "plots" / "heatmap_experiments.pdf", dpi=300)

# %%
# Stacked bar chart of experiments by Track, colored by Tyre ID
pdf = (
    files_df.group_by(["track_ID", "tyre_ID"])
    .agg(pl.col("file_path").n_unique().alias("experiments"))
    .to_pandas()
)

pivot_data = pdf.pivot(index="track_ID", columns="tyre_ID", values="experiments").fillna(0)

# Sort by total experiments
pivot_data["total"] = pivot_data.sum(axis=1)
pivot_data = pivot_data.sort_values("total", ascending=False).drop(columns="total")

fig, ax = plt.subplots(figsize=(9, 6))

# Get colors for each tyre column
colors = [TYRE_COLORS.get(int(col), "#95a5a6") for col in pivot_data.columns]

pivot_data.plot(
    kind="bar",
    stacked=True,
    ax=ax,
    color=colors,
    width=0.75,
    edgecolor="white",
    linewidth=0.5,
)

ax.set_xlabel("Track ID", fontsize=12)
ax.set_ylabel("Number of Experiments", fontsize=12)
ax.set_title("Experiments by Track (stacked by Tyre)", fontsize=14, pad=15)
ax.legend(
    title="Tyre ID",
    loc="upper right",
    fontsize=9,
    title_fontsize=10,
    framealpha=0.9,
)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig(ROOT_DIR / "plots" / "experiments_per_track_stacked_by_tyre_bar.pdf")

# %%
files_df.columns
# Out:
# ['file_path', 'file_stem', 'vehicle', 'tyre_ID', 'track_ID', 'measure', 'date']

# %%
# Stacked bar chart of experiments by Track, colored by Tyre ID
pdf = (
    files_df.group_by(["track_ID", "vehicle"])
    .agg(pl.col("file_path").n_unique().alias("experiments"))
    .to_pandas()
)

pivot_data = pdf.pivot(index="track_ID", columns="vehicle", values="experiments").fillna(0)

# Sort by total experiments
pivot_data["total"] = pivot_data.sum(axis=1)
pivot_data = pivot_data.sort_values("total", ascending=False).drop(columns="total")

fig, ax = plt.subplots(figsize=(8, 5))

# Get colors for each tyre column
# colors = [VEHICLE_COLORS.get(int(col), "#95a5a6") for col in pivot_data.columns]
colors = [VEHICLE_COLORS.get(v, "#95a5a6") for v in pivot_data.columns]


pivot_data.plot(
    kind="bar",
    stacked=True,
    ax=ax,
    color=colors,
    width=0.75,
    edgecolor="white",
    linewidth=0.5,
)

ax.set_xlabel("Track ID", fontsize=12)
ax.set_ylabel("Number of Experiments", fontsize=12)
ax.set_title("Experiments by Track (stacked by Vehicle)", fontsize=14, pad=15)
ax.legend(
    title="Vehicle",
    loc="upper right",
    fontsize=9,
    title_fontsize=10,
    framealpha=0.9,
)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig(ROOT_DIR / "plots" / "experiments_per_track_stacked_by_vehicle_bar.pdf", dpi=300)

# %%
# Bar chart of experiments by Tyre, colored by vehicle type"""
pdf = (
    files_df.group_by(["tyre_ID", "vehicle"])
    .agg(pl.col("file_path").n_unique().alias("experiments"))
    .sort("experiments", descending=True)
)

fig, ax = plt.subplots(figsize=(9, 6))

sns.barplot(
    data=pdf,
    x="tyre_ID",
    y="experiments",
    hue="vehicle",
    palette=VEHICLE_COLORS,
    dodge=False,
    ax=ax,
    edgecolor="white",
    linewidth=1,
)

ax.set_xlabel("Tyre ID", fontsize=12)
ax.set_ylabel("Number of Experiments", fontsize=12)
ax.set_title("Experiments by Tyre (colored by Vehicle)", fontsize=14, pad=15)

# Clean legend labels
handles, labels = ax.get_legend_handles_labels()
clean_labels = [lab.split(" ", 1)[1] if " " in lab else lab for lab in labels]
ax.legend(
    handles,
    clean_labels,
    title="Vehicle",
    loc="upper right",
    fontsize=9,
    title_fontsize=10,
    framealpha=0.9,
)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig(ROOT_DIR / "plots" / "experiments_per_tyre_id_bar.pdf", dpi=300)

# %%
def print_dataset_summary(df):
    """Print dataset summary statistics"""
    print("=" * 45)
    print("           DATASET SUMMARY")
    print("=" * 45)
    print(f"  Total Rows:          {len(df):,}")
    print(f"  Unique Variables:    {df['variable_name'].n_unique()}")
    print(f"  Unique Experiments:  {df['file_path'].n_unique()}")
    print()
    print(f"  Vehicles:  {df['vehicle'].n_unique()}")
    print(f"  Tyres:     {df['tyre_ID'].n_unique()}")
    print(f"  Tracks:    {df['track_ID'].n_unique()}")
    print()
    print("  Sample Rates:")
    print(f"    Min:   {df['sample_rate'].min()} Hz")
    print(f"    Max:   {df['sample_rate'].max()} Hz")
    print(f"    Mean:  {df['sample_rate'].mean():.1f} Hz")
    print()
    print("  Date Range:")
    print(f"    From:  {df['date'].min()}")
    print(f"    To:    {df['date'].max()}")
    print("=" * 45)


print_dataset_summary(files_df_expanded)
# Out:
# =============================================
#            DATASET SUMMARY
# =============================================
#   Total Rows:          16,815
#   Unique Variables:    144
#   Unique Experiments:  204
#
#   Vehicles:  4
#   Tyres:     6
#   Tracks:    2
#
#   Sample Rates:
#     Min:   142.85714285714286 Hz
#     Max:   71999.99999999988 Hz
#     Mean:  11576.8 Hz
#
#   Date Range:
#     From:  2025-07-11 09:39:41
#     To:    2025-09-29 17:28:02
# =============================================

# %%
files_df_expanded_relevant.filter(pl.col("variable_name") == "v_east_CAN_Sig_")
# Out:
# shape: (204, 11)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ file_path  ┆ file_stem ┆ vehicle   ┆ tyre_ID ┆ … ┆ variable_ ┆ variable_ ┆ sample_ra ┆ relevance │
# │ ---        ┆ ---       ┆ ---       ┆ ---     ┆   ┆ name      ┆ shape     ┆ te        ┆ ---       │
# │ str        ┆ str       ┆ str       ┆ i64     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ cat       │
# │            ┆           ┆           ┆         ┆   ┆ str       ┆ list[i64] ┆ f64       ┆           │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ v_east_CA ┆ [1, 7300] ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ N_Sig_    ┆           ┆           ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ v_east_CA ┆ [1, 3350] ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ N_Sig_    ┆           ┆           ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ v_east_CA ┆ [1, 2200] ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ N_Sig_    ┆           ┆           ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ v_east_CA ┆ [1, 3700] ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ N_Sig_    ┆           ┆           ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track150_ ┆ Q8 e-tron ┆ 12      ┆ … ┆ v_east_CA ┆ [1, 2700] ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ Q8 e-tron ┆           ┆         ┆   ┆ N_Sig_    ┆           ┆           ┆           │
# │ veloper/RO ┆ _tyre12_m ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ eas…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …         ┆ …         ┆ …       ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ v_east_CA ┆ [1, 5100] ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ N_Sig_    ┆           ┆           ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ 2_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ v_east_CA ┆ [1, 4850] ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ N_Sig_    ┆           ┆           ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ 5_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ v_east_CA ┆ [1, 4850] ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ N_Sig_    ┆           ┆           ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ 2_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ v_east_CA ┆ [1, 5950] ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ N_Sig_    ┆           ┆           ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ 5_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ /Users/mor ┆ track211_ ┆ E-Golf    ┆ 13      ┆ … ┆ v_east_CA ┆ [1,       ┆ 1000.0    ┆ ja        │
# │ itzfeik/De ┆ E-Golf_ty ┆           ┆         ┆   ┆ N_Sig_    ┆ 10000]    ┆           ┆           │
# │ veloper/RO ┆ re13_meas ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ 6_2…      ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
def plot_sample_rate_by_variable(df):
    """Plot sample rates for different variables"""
    pdf = (
        df.group_by(["variable_name", "sample_rate"])
        .agg(pl.len().alias("count"))
        .filter(pl.col("sample_rate").is_not_null())
        .to_pandas()
    )

    fig, ax = plt.subplots(figsize=(11, 6))

    sns.scatterplot(
        data=pdf,
        x="sample_rate",
        y="variable_name",
        size="count",
        sizes=(50, 400),
        # alpha=0.7,
        ax=ax,
        color="#2a9d8f",
        legend=False,
    )

    ax.set_xlabel("Sample Rate (Hz)", fontsize=12)
    ax.set_ylabel("Variable Name", fontsize=12)
    ax.set_title("Sample Rates by Variable", fontsize=14, pad=15)
    ax.grid(True, alpha=0.3, axis="x")
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    plt.tight_layout()
    return fig


fig = plot_sample_rate_by_variable(df=files_df_expanded_relevant)

# %% [markdown]
# ## Recording durations & channel length analysis
# Investigate recording durations across channels, vehicles, tracks and tyres. This is useful to identify long vs short recordings, detect truncated files, and choose consistent durations for modeling or further preprocessing.

# %%
# Check the distribution of recording lengths (ignoring the ir images)
recording_lengths_1d = files_df_expanded_relevant.filter(
    pl.col("variable_shape").list.len() == 2
).with_columns(
    (pl.col("variable_shape").list.last() / pl.col("sample_rate")).alias("recording_duration_s"),
)

df = (
    recording_lengths_1d.group_by("file_path")
    .agg(
        pl.struct(
            [
                pl.col("variable_name"),
                pl.col("recording_duration_s"),
            ]
        ).alias("var_durations"),
        pl.col("recording_duration_s").mean().alias("mean_duration"),
    )
    .sort("mean_duration", descending=True)
    .select(pl.exclude("mean_duration"))
)

for row in df.iter_rows(named=True):
    print(f"File: {row['file_path']}")
    s = ""
    for var in row["var_durations"]:
        s += f"{var['variable_name']}: {var['recording_duration_s']:.1f}s, "
    print(f"Durations (s): {s}")
    print("-" * 40)
# Out:
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/04_E-Golf/tyre13/track150_E-Golf_tyre13_meas2_2p5_1_2025-09-26_15-26-16.h5
# Durations (s): BCM1_Aussen_Temp: 19.5s, Ch_1_labV12: 19.5s, Ch_2_labV12: 19.5s, Ch_3_labV12: 19.5s, Ch_4_labV12: 19.5s, Ch_5_labV12: 19.5s, Ch_7_labV12: 19.5s, Ch_8_labV12: 19.5s, ESP_HL_Radgeschw: 19.5s, ESP_HR_Radgeschw: 19.5s, ESP_VL_Radgeschw: 19.5s, ESP_VR_Radgeschw: 19.5s, Lat_CAN_Sig_13_: 19.5s, Long_CAN_Sig_12: 19.5s, NAWSPressure: 19.3s, NAWSSound: 19.3s, NAWSTemperature: 19.3s, a_x_CAN_Sig_4_: 19.5s, a_y_CAN_Sig_3_: 19.5s, a_z_CAN_Sig_5_: 19.5s, bUTC_CAN_Sig_24: 19.5s, mic_iso: 8.6s, v_east_CAN_Sig_: 19.5s, v_north_CAN_Sig: 19.5s, v_up_CAN_Sig_11: 19.5s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/04_E-Golf/tyre13/track150_E-Golf_tyre13_meas3_2p5_1_2025-09-26_15-28-48.h5
# Durations (s): BCM1_Aussen_Temp: 15.8s, Ch_1_labV12: 15.8s, Ch_2_labV12: 15.8s, Ch_3_labV12: 15.8s, Ch_4_labV12: 15.8s, Ch_5_labV12: 15.8s, Ch_7_labV12: 15.8s, Ch_8_labV12: 15.8s, ESP_HL_Radgeschw: 15.8s, ESP_HR_Radgeschw: 15.8s, ESP_VL_Radgeschw: 15.8s, ESP_VR_Radgeschw: 15.8s, Lat_CAN_Sig_13_: 15.8s, Long_CAN_Sig_12: 15.8s, NAWSPressure: 16.3s, NAWSSound: 16.3s, NAWSTemperature: 16.3s, a_x_CAN_Sig_4_: 15.8s, a_y_CAN_Sig_3_: 15.8s, a_z_CAN_Sig_5_: 15.8s, bUTC_CAN_Sig_24: 15.8s, mic_iso: 7.4s, v_east_CAN_Sig_: 15.8s, v_north_CAN_Sig: 15.8s, v_up_CAN_Sig_11: 15.8s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/04_E-Golf/tyre13/track150_E-Golf_tyre13_meas3_2p5_1_2025-09-26_15-30-07.h5
# Durations (s): BCM1_Aussen_Temp: 15.2s, Ch_1_labV12: 15.2s, Ch_2_labV12: 15.2s, Ch_3_labV12: 15.2s, Ch_4_labV12: 15.2s, Ch_5_labV12: 15.2s, Ch_7_labV12: 15.2s, Ch_8_labV12: 15.2s, ESP_HL_Radgeschw: 15.2s, ESP_HR_Radgeschw: 15.2s, ESP_VL_Radgeschw: 15.2s, ESP_VR_Radgeschw: 15.2s, Lat_CAN_Sig_13_: 15.2s, Long_CAN_Sig_12: 15.2s, NAWSPressure: 15.4s, NAWSSound: 15.4s, NAWSTemperature: 15.4s, a_x_CAN_Sig_4_: 15.2s, a_y_CAN_Sig_3_: 15.2s, a_z_CAN_Sig_5_: 15.2s, bUTC_CAN_Sig_24: 15.2s, mic_iso: 8.5s, v_east_CAN_Sig_: 15.2s, v_north_CAN_Sig: 15.2s, v_up_CAN_Sig_11: 15.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/04_E-Golf/tyre13/track150_E-Golf_tyre13_meas3_2p5_1_2025-09-26_15-27-12.h5
# Durations (s): BCM1_Aussen_Temp: 13.4s, Ch_1_labV12: 13.4s, Ch_2_labV12: 13.4s, Ch_3_labV12: 13.4s, Ch_4_labV12: 13.4s, Ch_5_labV12: 13.4s, Ch_7_labV12: 13.4s, Ch_8_labV12: 13.4s, ESP_HL_Radgeschw: 13.4s, ESP_HR_Radgeschw: 13.4s, ESP_VL_Radgeschw: 13.4s, ESP_VR_Radgeschw: 13.4s, Lat_CAN_Sig_13_: 13.4s, Long_CAN_Sig_12: 13.4s, NAWSPressure: 13.4s, NAWSSound: 13.4s, NAWSTemperature: 13.4s, a_x_CAN_Sig_4_: 13.4s, a_y_CAN_Sig_3_: 13.4s, a_z_CAN_Sig_5_: 13.4s, bUTC_CAN_Sig_24: 13.4s, mic_iso: 6.8s, v_east_CAN_Sig_: 13.4s, v_north_CAN_Sig: 13.4s, v_up_CAN_Sig_11: 13.4s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas1_2p5_1_2025-09-29_16-57-57.h5
# Durations (s): BCM1_Aussen_Temp: 13.2s, Ch_1_labV12: 13.2s, Ch_2_labV12: 13.2s, Ch_3_labV12: 13.2s, Ch_4_labV12: 13.2s, Ch_5_labV12: 13.2s, Ch_7_labV12: 13.2s, Ch_8_labV12: 13.2s, ESP_HL_Radgeschw: 13.2s, ESP_HR_Radgeschw: 13.2s, ESP_VL_Radgeschw: 13.2s, ESP_VR_Radgeschw: 13.2s, FA_Hoehenwert_HL: 13.2s, FA_Hoehenwert_HR: 13.2s, FA_Hoehenwert_VL: 13.2s, FA_Hoehenwert_VR: 13.2s, Lat_CAN_Sig_13_: 13.2s, Long_CAN_Sig_12: 13.2s, NAWSPressure: 13.6s, NAWSSound: 13.6s, NAWSTemperature: 13.6s, a_x_CAN_Sig_4_: 13.2s, a_y_CAN_Sig_3_: 13.2s, a_z_CAN_Sig_5_: 13.2s, bUTC_CAN_Sig_24: 13.2s, mic_iso: 9.0s, v_east_CAN_Sig_: 13.2s, v_north_CAN_Sig: 13.2s, v_up_CAN_Sig_11: 13.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/04_E-Golf/tyre13/track150_E-Golf_tyre13_meas3_2p5_1_2025-09-26_15-28-03.h5
# Durations (s): BCM1_Aussen_Temp: 11.7s, Ch_1_labV12: 11.7s, Ch_2_labV12: 11.7s, Ch_3_labV12: 11.7s, Ch_4_labV12: 11.7s, Ch_5_labV12: 11.7s, Ch_7_labV12: 11.7s, Ch_8_labV12: 11.7s, ESP_HL_Radgeschw: 11.7s, ESP_HR_Radgeschw: 11.7s, ESP_VL_Radgeschw: 11.7s, ESP_VR_Radgeschw: 11.7s, Lat_CAN_Sig_13_: 11.7s, Long_CAN_Sig_12: 11.7s, NAWSPressure: 11.7s, NAWSSound: 11.7s, NAWSTemperature: 11.7s, a_x_CAN_Sig_4_: 11.7s, a_y_CAN_Sig_3_: 11.7s, a_z_CAN_Sig_5_: 11.7s, bUTC_CAN_Sig_24: 11.7s, mic_iso: 6.8s, v_east_CAN_Sig_: 11.7s, v_north_CAN_Sig: 11.7s, v_up_CAN_Sig_11: 11.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre12/track211_Q8 e-tron_tyre12_meas1_2p5_1_2025-08-15_11-46-48.h5
# Durations (s): BCM1_Aussen_Temp: 11.1s, Ch_1_labV12: 11.1s, Ch_2_labV12: 11.1s, Ch_3_labV12: 11.1s, Ch_4_labV12: 11.1s, Ch_5_labV12: 11.1s, ESP_HL_Radgeschw: 11.1s, ESP_HR_Radgeschw: 11.1s, ESP_VL_Radgeschw: 11.1s, ESP_VR_Radgeschw: 11.1s, Lat_CAN_Sig_13_: 11.1s, Long_CAN_Sig_12: 11.1s, NAWSPressure: 11.0s, NAWSSound: 11.0s, NAWSTemperature: 11.0s, a_x_CAN_Sig_4_: 11.1s, a_y_CAN_Sig_3_: 11.1s, a_z_CAN_Sig_5_: 11.1s, bUTC_CAN_Sig_24: 11.1s, mic_iso: 7.2s, v_east_CAN_Sig_: 11.1s, v_north_CAN_Sig: 11.1s, v_up_CAN_Sig_11: 11.1s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas1_2p5_1_2025-09-29_16-59-29.h5
# Durations (s): BCM1_Aussen_Temp: 10.4s, Ch_1_labV12: 10.4s, Ch_2_labV12: 10.4s, Ch_3_labV12: 10.4s, Ch_4_labV12: 10.4s, Ch_5_labV12: 10.4s, Ch_7_labV12: 10.4s, Ch_8_labV12: 10.4s, ESP_HL_Radgeschw: 10.4s, ESP_HR_Radgeschw: 10.4s, ESP_VL_Radgeschw: 10.4s, ESP_VR_Radgeschw: 10.4s, FA_Hoehenwert_HL: 10.4s, FA_Hoehenwert_HR: 10.4s, FA_Hoehenwert_VL: 10.4s, FA_Hoehenwert_VR: 10.4s, Lat_CAN_Sig_13_: 10.4s, Long_CAN_Sig_12: 10.4s, NAWSPressure: 11.0s, NAWSSound: 11.0s, NAWSTemperature: 11.0s, a_x_CAN_Sig_4_: 10.4s, a_y_CAN_Sig_3_: 10.4s, a_z_CAN_Sig_5_: 10.4s, bUTC_CAN_Sig_24: 10.4s, mic_iso: 8.2s, v_east_CAN_Sig_: 10.4s, v_north_CAN_Sig: 10.4s, v_up_CAN_Sig_11: 10.4s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas4_2p5_1_2025-09-29_17-10-58.h5
# Durations (s): BCM1_Aussen_Temp: 10.3s, Ch_1_labV12: 10.3s, Ch_2_labV12: 10.3s, Ch_3_labV12: 10.3s, Ch_4_labV12: 10.3s, Ch_5_labV12: 10.3s, Ch_7_labV12: 10.3s, Ch_8_labV12: 10.3s, ESP_HL_Radgeschw: 10.3s, ESP_HR_Radgeschw: 10.3s, ESP_VL_Radgeschw: 10.3s, ESP_VR_Radgeschw: 10.3s, FA_Hoehenwert_HL: 10.3s, FA_Hoehenwert_HR: 10.3s, FA_Hoehenwert_VL: 10.3s, FA_Hoehenwert_VR: 10.3s, Lat_CAN_Sig_13_: 10.3s, Long_CAN_Sig_12: 10.3s, NAWSPressure: 10.3s, NAWSSound: 10.3s, NAWSTemperature: 10.3s, a_x_CAN_Sig_4_: 10.3s, a_y_CAN_Sig_3_: 10.3s, a_z_CAN_Sig_5_: 10.3s, bUTC_CAN_Sig_24: 10.3s, mic_iso: 6.4s, v_east_CAN_Sig_: 10.3s, v_north_CAN_Sig: 10.3s, v_up_CAN_Sig_11: 10.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/03_Taycan/tyre10/track211_Taycan_tyre10_meas1_2p5_1_2025-09-23_17-00-35.h5
# Durations (s): Ch_1_labV12: 10.1s, Ch_2_labV12: 10.1s, Ch_3_labV12: 10.1s, Ch_4_labV12: 10.1s, Ch_5_labV12: 10.1s, Ch_7_labV12: 10.1s, Ch_8_labV12: 10.1s, ESP_HL_Radgeschw: 10.1s, ESP_HR_Radgeschw: 10.1s, ESP_VL_Radgeschw: 10.1s, ESP_VR_Radgeschw: 10.1s, FA_Hoehenwert_HL: 10.1s, FA_Hoehenwert_HR: 10.1s, FA_Hoehenwert_VL: 10.1s, FA_Hoehenwert_VR: 10.1s, Lat_CAN_Sig_13_: 10.1s, Long_CAN_Sig_12: 10.1s, NAWSPressure: 10.0s, NAWSSound: 10.1s, NAWSTemperature: 10.0s, a_x_CAN_Sig_4_: 10.1s, a_y_CAN_Sig_3_: 10.1s, a_z_CAN_Sig_5_: 10.1s, bUTC_CAN_Sig_24: 10.1s, mic_iso: 8.0s, v_east_CAN_Sig_: 10.1s, v_north_CAN_Sig: 10.1s, v_up_CAN_Sig_11: 10.1s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas4_2p5_1_2025-09-29_17-08-11.h5
# Durations (s): BCM1_Aussen_Temp: 10.0s, Ch_1_labV12: 10.0s, Ch_2_labV12: 10.0s, Ch_3_labV12: 10.0s, Ch_4_labV12: 10.0s, Ch_5_labV12: 10.0s, Ch_7_labV12: 10.0s, Ch_8_labV12: 10.0s, ESP_HL_Radgeschw: 10.0s, ESP_HR_Radgeschw: 10.0s, ESP_VL_Radgeschw: 10.0s, ESP_VR_Radgeschw: 10.0s, FA_Hoehenwert_HL: 10.0s, FA_Hoehenwert_HR: 10.0s, FA_Hoehenwert_VL: 10.0s, FA_Hoehenwert_VR: 10.0s, Lat_CAN_Sig_13_: 10.0s, Long_CAN_Sig_12: 10.0s, NAWSPressure: 10.1s, NAWSSound: 10.1s, NAWSTemperature: 10.1s, a_x_CAN_Sig_4_: 10.0s, a_y_CAN_Sig_3_: 10.0s, a_z_CAN_Sig_5_: 10.0s, bUTC_CAN_Sig_24: 10.0s, mic_iso: 8.0s, v_east_CAN_Sig_: 10.0s, v_north_CAN_Sig: 10.0s, v_up_CAN_Sig_11: 10.0s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas5_2p5_1_2025-09-29_17-12-08.h5
# Durations (s): BCM1_Aussen_Temp: 10.1s, Ch_1_labV12: 10.1s, Ch_2_labV12: 10.1s, Ch_3_labV12: 10.1s, Ch_4_labV12: 10.1s, Ch_5_labV12: 10.1s, Ch_7_labV12: 10.1s, Ch_8_labV12: 10.1s, ESP_HL_Radgeschw: 10.1s, ESP_HR_Radgeschw: 10.1s, ESP_VL_Radgeschw: 10.1s, ESP_VR_Radgeschw: 10.1s, FA_Hoehenwert_HL: 10.1s, FA_Hoehenwert_HR: 10.1s, FA_Hoehenwert_VL: 10.1s, FA_Hoehenwert_VR: 10.1s, Lat_CAN_Sig_13_: 10.1s, Long_CAN_Sig_12: 10.1s, NAWSPressure: 10.1s, NAWSSound: 10.1s, NAWSTemperature: 10.1s, a_x_CAN_Sig_4_: 10.1s, a_y_CAN_Sig_3_: 10.1s, a_z_CAN_Sig_5_: 10.1s, bUTC_CAN_Sig_24: 10.1s, mic_iso: 6.5s, v_east_CAN_Sig_: 10.1s, v_north_CAN_Sig: 10.1s, v_up_CAN_Sig_11: 10.1s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/04_E-Golf/tyre13/track150_E-Golf_tyre13_meas2_2p5_1_2025-09-26_15-23-21.h5
# Durations (s): BCM1_Aussen_Temp: 9.9s, Ch_1_labV12: 9.9s, Ch_2_labV12: 9.9s, Ch_3_labV12: 9.9s, Ch_4_labV12: 9.9s, Ch_5_labV12: 9.9s, Ch_7_labV12: 9.9s, Ch_8_labV12: 9.9s, ESP_HL_Radgeschw: 9.9s, ESP_HR_Radgeschw: 9.9s, ESP_VL_Radgeschw: 9.9s, ESP_VR_Radgeschw: 9.9s, Lat_CAN_Sig_13_: 9.9s, Long_CAN_Sig_12: 9.9s, NAWSPressure: 9.9s, NAWSSound: 9.9s, NAWSTemperature: 9.9s, a_x_CAN_Sig_4_: 9.9s, a_y_CAN_Sig_3_: 9.9s, a_z_CAN_Sig_5_: 9.9s, bUTC_CAN_Sig_24: 9.9s, mic_iso: 8.8s, v_east_CAN_Sig_: 9.9s, v_north_CAN_Sig: 9.9s, v_up_CAN_Sig_11: 9.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/04_E-Golf/tyre13/track211_E-Golf_tyre13_meas6_2p5_1_2025-09-26_15-15-26.h5
# Durations (s): BCM1_Aussen_Temp: 10.0s, Ch_1_labV12: 10.0s, Ch_2_labV12: 10.0s, Ch_3_labV12: 10.0s, Ch_4_labV12: 10.0s, Ch_5_labV12: 10.0s, Ch_7_labV12: 10.0s, Ch_8_labV12: 10.0s, ESP_HL_Radgeschw: 10.0s, ESP_HR_Radgeschw: 10.0s, ESP_VL_Radgeschw: 10.0s, ESP_VR_Radgeschw: 10.0s, Lat_CAN_Sig_13_: 10.0s, Long_CAN_Sig_12: 10.0s, NAWSPressure: 10.1s, NAWSSound: 10.1s, NAWSTemperature: 10.1s, a_x_CAN_Sig_4_: 10.0s, a_y_CAN_Sig_3_: 10.0s, a_z_CAN_Sig_5_: 10.0s, bUTC_CAN_Sig_24: 10.0s, mic_iso: 7.1s, v_east_CAN_Sig_: 10.0s, v_north_CAN_Sig: 10.0s, v_up_CAN_Sig_11: 10.0s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas1_2p5_1_2025-09-29_16-58-46.h5
# Durations (s): BCM1_Aussen_Temp: 9.8s, Ch_1_labV12: 9.8s, Ch_2_labV12: 9.8s, Ch_3_labV12: 9.8s, Ch_4_labV12: 9.8s, Ch_5_labV12: 9.8s, Ch_7_labV12: 9.8s, Ch_8_labV12: 9.8s, ESP_HL_Radgeschw: 9.8s, ESP_HR_Radgeschw: 9.8s, ESP_VL_Radgeschw: 9.8s, ESP_VR_Radgeschw: 9.8s, FA_Hoehenwert_HL: 9.8s, FA_Hoehenwert_HR: 9.8s, FA_Hoehenwert_VL: 9.8s, FA_Hoehenwert_VR: 9.8s, Lat_CAN_Sig_13_: 9.8s, Long_CAN_Sig_12: 9.8s, NAWSPressure: 10.4s, NAWSSound: 10.5s, NAWSTemperature: 10.4s, a_x_CAN_Sig_4_: 9.8s, a_y_CAN_Sig_3_: 9.8s, a_z_CAN_Sig_5_: 9.8s, bUTC_CAN_Sig_24: 9.8s, mic_iso: 8.4s, v_east_CAN_Sig_: 9.8s, v_north_CAN_Sig: 9.8s, v_up_CAN_Sig_11: 9.8s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas5_2p5_1_2025-09-29_17-13-40.h5
# Durations (s): BCM1_Aussen_Temp: 9.7s, Ch_1_labV12: 9.7s, Ch_2_labV12: 9.7s, Ch_3_labV12: 9.7s, Ch_4_labV12: 9.7s, Ch_5_labV12: 9.7s, Ch_7_labV12: 9.7s, Ch_8_labV12: 9.7s, ESP_HL_Radgeschw: 9.7s, ESP_HR_Radgeschw: 9.7s, ESP_VL_Radgeschw: 9.7s, ESP_VR_Radgeschw: 9.7s, FA_Hoehenwert_HL: 9.7s, FA_Hoehenwert_HR: 9.7s, FA_Hoehenwert_VL: 9.7s, FA_Hoehenwert_VR: 9.7s, Lat_CAN_Sig_13_: 9.7s, Long_CAN_Sig_12: 9.7s, NAWSPressure: 9.7s, NAWSSound: 9.7s, NAWSTemperature: 9.7s, a_x_CAN_Sig_4_: 9.7s, a_y_CAN_Sig_3_: 9.7s, a_z_CAN_Sig_5_: 9.7s, bUTC_CAN_Sig_24: 9.7s, mic_iso: 6.6s, v_east_CAN_Sig_: 9.7s, v_north_CAN_Sig: 9.7s, v_up_CAN_Sig_11: 9.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre12/track211_Q8 e-tron_tyre12_meas1_2p5_1_2025-08-15_11-49-17.h5
# Durations (s): BCM1_Aussen_Temp: 9.2s, Ch_1_labV12: 9.2s, Ch_2_labV12: 9.2s, Ch_3_labV12: 9.2s, Ch_4_labV12: 9.2s, Ch_5_labV12: 9.2s, ESP_HL_Radgeschw: 9.2s, ESP_HR_Radgeschw: 9.2s, ESP_VL_Radgeschw: 9.2s, ESP_VR_Radgeschw: 9.2s, Lat_CAN_Sig_13_: 9.2s, Long_CAN_Sig_12: 9.2s, NAWSPressure: 9.1s, NAWSSound: 9.1s, NAWSTemperature: 9.1s, a_x_CAN_Sig_4_: 9.2s, a_y_CAN_Sig_3_: 9.2s, a_z_CAN_Sig_5_: 9.2s, bUTC_CAN_Sig_24: 9.2s, mic_iso: 8.0s, v_east_CAN_Sig_: 9.2s, v_north_CAN_Sig: 9.2s, v_up_CAN_Sig_11: 9.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas5_2p5_1_2025-09-29_17-12-56.h5
# Durations (s): BCM1_Aussen_Temp: 9.0s, Ch_1_labV12: 9.0s, Ch_2_labV12: 9.0s, Ch_3_labV12: 9.0s, Ch_4_labV12: 9.0s, Ch_5_labV12: 9.0s, Ch_7_labV12: 9.0s, Ch_8_labV12: 9.0s, ESP_HL_Radgeschw: 9.0s, ESP_HR_Radgeschw: 9.0s, ESP_VL_Radgeschw: 9.0s, ESP_VR_Radgeschw: 9.0s, FA_Hoehenwert_HL: 9.0s, FA_Hoehenwert_HR: 9.0s, FA_Hoehenwert_VL: 9.0s, FA_Hoehenwert_VR: 9.0s, Lat_CAN_Sig_13_: 9.0s, Long_CAN_Sig_12: 9.0s, NAWSPressure: 9.5s, NAWSSound: 9.5s, NAWSTemperature: 9.5s, a_x_CAN_Sig_4_: 9.0s, a_y_CAN_Sig_3_: 9.0s, a_z_CAN_Sig_5_: 9.0s, bUTC_CAN_Sig_24: 9.0s, mic_iso: 6.8s, v_east_CAN_Sig_: 9.0s, v_north_CAN_Sig: 9.0s, v_up_CAN_Sig_11: 9.0s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas6_2p5_1_2025-09-29_17-16-23.h5
# Durations (s): BCM1_Aussen_Temp: 9.0s, Ch_1_labV12: 9.0s, Ch_2_labV12: 9.0s, Ch_3_labV12: 9.0s, Ch_4_labV12: 9.0s, Ch_5_labV12: 9.0s, Ch_7_labV12: 9.0s, Ch_8_labV12: 9.0s, ESP_HL_Radgeschw: 9.0s, ESP_HR_Radgeschw: 9.0s, ESP_VL_Radgeschw: 9.0s, ESP_VR_Radgeschw: 9.0s, FA_Hoehenwert_HL: 9.0s, FA_Hoehenwert_HR: 9.0s, FA_Hoehenwert_VL: 9.0s, FA_Hoehenwert_VR: 9.0s, Lat_CAN_Sig_13_: 9.0s, Long_CAN_Sig_12: 9.0s, NAWSPressure: 9.0s, NAWSSound: 9.1s, NAWSTemperature: 9.0s, a_x_CAN_Sig_4_: 9.0s, a_y_CAN_Sig_3_: 9.0s, a_z_CAN_Sig_5_: 9.0s, bUTC_CAN_Sig_24: 9.0s, mic_iso: 7.0s, v_east_CAN_Sig_: 9.0s, v_north_CAN_Sig: 9.0s, v_up_CAN_Sig_11: 9.0s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-09-42.h5
# Durations (s): BCM1_Aussen_Temp: 8.2s, Ch_1_labV12: 8.2s, Ch_2_labV12: 8.2s, Ch_3_labV12: 8.2s, Ch_4_labV12: 8.2s, Ch_5_labV12: 8.2s, ESP_VL_Radgeschw: 8.2s, ESP_VR_Radgeschw: 8.2s, Lat_CAN_Sig_13_: 8.2s, Long_CAN_Sig_12: 8.2s, NAWSPressure: 8.6s, NAWSSound: 8.6s, NAWSTemperature: 8.6s, a_x_CAN_Sig_4_: 8.2s, a_y_CAN_Sig_3_: 8.2s, a_z_CAN_Sig_5_: 8.2s, bUTC_CAN_Sig_24: 8.2s, mic_iso: 7.0s, v_east_CAN_Sig_: 8.2s, v_north_CAN_Sig: 8.2s, v_up_CAN_Sig_11: 8.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/04_E-Golf/tyre13/track211_E-Golf_tyre13_meas6_2p5_1_2025-09-26_15-12-45.h5
# Durations (s): BCM1_Aussen_Temp: 8.2s, Ch_1_labV12: 8.2s, Ch_2_labV12: 8.2s, Ch_3_labV12: 8.2s, Ch_4_labV12: 8.2s, Ch_5_labV12: 8.2s, Ch_7_labV12: 8.2s, Ch_8_labV12: 8.2s, ESP_HL_Radgeschw: 8.2s, ESP_HR_Radgeschw: 8.2s, ESP_VL_Radgeschw: 8.2s, ESP_VR_Radgeschw: 8.2s, Lat_CAN_Sig_13_: 8.2s, Long_CAN_Sig_12: 8.2s, NAWSPressure: 8.2s, NAWSSound: 8.2s, NAWSTemperature: 8.2s, a_x_CAN_Sig_4_: 8.2s, a_y_CAN_Sig_3_: 8.2s, a_z_CAN_Sig_5_: 8.2s, bUTC_CAN_Sig_24: 8.2s, mic_iso: 7.3s, v_east_CAN_Sig_: 8.2s, v_north_CAN_Sig: 8.2s, v_up_CAN_Sig_11: 8.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-39-41.h5
# Durations (s): BCM1_Aussen_Temp: 8.2s, Ch_1_labV12: 8.2s, Ch_2_labV12: 8.2s, Ch_3_labV12: 8.2s, Ch_4_labV12: 8.2s, Ch_5_labV12: 8.2s, ESP_VL_Radgeschw: 8.2s, ESP_VR_Radgeschw: 8.2s, Lat_CAN_Sig_13_: 8.2s, Long_CAN_Sig_12: 8.2s, NAWSPressure: 8.5s, NAWSSound: 8.5s, NAWSTemperature: 8.5s, a_x_CAN_Sig_4_: 8.2s, a_y_CAN_Sig_3_: 8.2s, a_z_CAN_Sig_5_: 8.2s, bUTC_CAN_Sig_24: 8.2s, mic_iso: 4.8s, v_east_CAN_Sig_: 8.2s, v_north_CAN_Sig: 8.2s, v_up_CAN_Sig_11: 8.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-42-29.h5
# Durations (s): BCM1_Aussen_Temp: 7.8s, Ch_1_labV12: 7.8s, Ch_2_labV12: 7.8s, Ch_3_labV12: 7.8s, Ch_4_labV12: 7.8s, Ch_5_labV12: 7.8s, ESP_VL_Radgeschw: 7.8s, ESP_VR_Radgeschw: 7.8s, Lat_CAN_Sig_13_: 7.8s, Long_CAN_Sig_12: 7.8s, NAWSPressure: 8.2s, NAWSSound: 8.2s, NAWSTemperature: 8.2s, a_x_CAN_Sig_4_: 7.8s, a_y_CAN_Sig_3_: 7.8s, a_z_CAN_Sig_5_: 7.8s, bUTC_CAN_Sig_24: 7.8s, mic_iso: 7.3s, v_east_CAN_Sig_: 7.8s, v_north_CAN_Sig: 7.8s, v_up_CAN_Sig_11: 7.8s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas4_2p5_1_2025-09-29_17-07-27.h5
# Durations (s): BCM1_Aussen_Temp: 7.8s, Ch_1_labV12: 7.8s, Ch_2_labV12: 7.8s, Ch_3_labV12: 7.8s, Ch_4_labV12: 7.8s, Ch_5_labV12: 7.8s, Ch_7_labV12: 7.8s, Ch_8_labV12: 7.8s, ESP_HL_Radgeschw: 7.8s, ESP_HR_Radgeschw: 7.8s, ESP_VL_Radgeschw: 7.8s, ESP_VR_Radgeschw: 7.8s, FA_Hoehenwert_HL: 7.8s, FA_Hoehenwert_HR: 7.8s, FA_Hoehenwert_VL: 7.8s, FA_Hoehenwert_VR: 7.8s, Lat_CAN_Sig_13_: 7.8s, Long_CAN_Sig_12: 7.8s, NAWSPressure: 7.4s, NAWSSound: 7.4s, NAWSTemperature: 7.4s, a_x_CAN_Sig_4_: 7.8s, a_y_CAN_Sig_3_: 7.8s, a_z_CAN_Sig_5_: 7.8s, bUTC_CAN_Sig_24: 7.8s, mic_iso: 8.1s, v_east_CAN_Sig_: 7.8s, v_north_CAN_Sig: 7.8s, v_up_CAN_Sig_11: 7.8s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-44-56.h5
# Durations (s): BCM1_Aussen_Temp: 7.7s, Ch_1_labV12: 7.7s, Ch_2_labV12: 7.7s, Ch_3_labV12: 7.7s, Ch_4_labV12: 7.7s, Ch_5_labV12: 7.7s, ESP_VL_Radgeschw: 7.7s, ESP_VR_Radgeschw: 7.7s, Lat_CAN_Sig_13_: 7.7s, Long_CAN_Sig_12: 7.7s, NAWSPressure: 8.0s, NAWSSound: 8.0s, NAWSTemperature: 8.0s, a_x_CAN_Sig_4_: 7.7s, a_y_CAN_Sig_3_: 7.7s, a_z_CAN_Sig_5_: 7.7s, bUTC_CAN_Sig_24: 7.7s, mic_iso: 6.9s, v_east_CAN_Sig_: 7.7s, v_north_CAN_Sig: 7.7s, v_up_CAN_Sig_11: 7.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas6_2p5_1_2025-09-29_17-17-53.h5
# Durations (s): BCM1_Aussen_Temp: 7.7s, Ch_1_labV12: 7.7s, Ch_2_labV12: 7.7s, Ch_3_labV12: 7.7s, Ch_4_labV12: 7.7s, Ch_5_labV12: 7.7s, Ch_7_labV12: 7.7s, Ch_8_labV12: 7.7s, ESP_HL_Radgeschw: 7.7s, ESP_HR_Radgeschw: 7.7s, ESP_VL_Radgeschw: 7.7s, ESP_VR_Radgeschw: 7.7s, FA_Hoehenwert_HL: 7.7s, FA_Hoehenwert_HR: 7.7s, FA_Hoehenwert_VL: 7.7s, FA_Hoehenwert_VR: 7.7s, Lat_CAN_Sig_13_: 7.7s, Long_CAN_Sig_12: 7.7s, NAWSPressure: 8.2s, NAWSSound: 8.2s, NAWSTemperature: 8.2s, a_x_CAN_Sig_4_: 7.7s, a_y_CAN_Sig_3_: 7.7s, a_z_CAN_Sig_5_: 7.7s, bUTC_CAN_Sig_24: 7.7s, mic_iso: 6.0s, v_east_CAN_Sig_: 7.7s, v_north_CAN_Sig: 7.7s, v_up_CAN_Sig_11: 7.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre12/track211_Q8 e-tron_tyre12_meas1_2p5_1_2025-08-15_11-48-03.h5
# Durations (s): BCM1_Aussen_Temp: 7.7s, Ch_1_labV12: 7.7s, Ch_2_labV12: 7.7s, Ch_3_labV12: 7.7s, Ch_4_labV12: 7.7s, Ch_5_labV12: 7.7s, ESP_HL_Radgeschw: 7.7s, ESP_HR_Radgeschw: 7.7s, ESP_VL_Radgeschw: 7.7s, ESP_VR_Radgeschw: 7.7s, Lat_CAN_Sig_13_: 7.7s, Long_CAN_Sig_12: 7.7s, NAWSPressure: 7.7s, NAWSSound: 7.7s, NAWSTemperature: 7.7s, a_x_CAN_Sig_4_: 7.7s, a_y_CAN_Sig_3_: 7.7s, a_z_CAN_Sig_5_: 7.7s, bUTC_CAN_Sig_24: 7.7s, mic_iso: 7.2s, v_east_CAN_Sig_: 7.7s, v_north_CAN_Sig: 7.7s, v_up_CAN_Sig_11: 7.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/02_Q8 e-tron/tyre6/track150_Q8 e-tron_tyre6_meas1_2p5_1_2025-09-29_17-21-55.h5
# Durations (s): BCM1_Aussen_Temp: 7.5s, Ch_1_labV12: 7.5s, Ch_2_labV12: 7.5s, Ch_3_labV12: 7.5s, Ch_4_labV12: 7.5s, Ch_5_labV12: 7.5s, Ch_7_labV12: 7.5s, Ch_8_labV12: 7.5s, ESP_HL_Radgeschw: 7.5s, ESP_HR_Radgeschw: 7.5s, ESP_VL_Radgeschw: 7.5s, ESP_VR_Radgeschw: 7.5s, FA_Hoehenwert_HL: 7.5s, FA_Hoehenwert_HR: 7.5s, FA_Hoehenwert_VL: 7.5s, FA_Hoehenwert_VR: 7.5s, Lat_CAN_Sig_13_: 7.5s, Long_CAN_Sig_12: 7.5s, NAWSPressure: 7.5s, NAWSSound: 7.5s, NAWSTemperature: 7.5s, a_x_CAN_Sig_4_: 7.5s, a_y_CAN_Sig_3_: 7.5s, a_z_CAN_Sig_5_: 7.5s, bUTC_CAN_Sig_24: 7.5s, mic_iso: 6.6s, v_east_CAN_Sig_: 7.5s, v_north_CAN_Sig: 7.5s, v_up_CAN_Sig_11: 7.5s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/03_Taycan/tyre10/track211_Taycan_tyre10_meas5_2p5_1_2025-09-23_17-13-17.h5
# Durations (s): Ch_1_labV12: 7.5s, Ch_2_labV12: 7.5s, Ch_3_labV12: 7.5s, Ch_4_labV12: 7.5s, Ch_5_labV12: 7.5s, Ch_7_labV12: 7.5s, Ch_8_labV12: 7.5s, ESP_HL_Radgeschw: 7.5s, ESP_HR_Radgeschw: 7.5s, ESP_VL_Radgeschw: 7.5s, ESP_VR_Radgeschw: 7.5s, FA_Hoehenwert_HL: 7.5s, FA_Hoehenwert_HR: 7.5s, FA_Hoehenwert_VL: 7.5s, FA_Hoehenwert_VR: 7.5s, Lat_CAN_Sig_13_: 7.5s, Long_CAN_Sig_12: 7.5s, NAWSPressure: 7.4s, NAWSSound: 7.4s, NAWSTemperature: 7.4s, a_x_CAN_Sig_4_: 7.5s, a_y_CAN_Sig_3_: 7.5s, a_z_CAN_Sig_5_: 7.5s, bUTC_CAN_Sig_24: 7.5s, mic_iso: 4.8s, v_east_CAN_Sig_: 7.5s, v_north_CAN_Sig: 7.5s, v_up_CAN_Sig_11: 7.5s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/04_E-Golf/tyre13/track150_E-Golf_tyre13_meas1_2p5_1_2025-09-26_15-21-39.h5
# Durations (s): BCM1_Aussen_Temp: 7.3s, Ch_1_labV12: 7.3s, Ch_2_labV12: 7.3s, Ch_3_labV12: 7.3s, Ch_4_labV12: 7.3s, Ch_5_labV12: 7.3s, Ch_7_labV12: 7.3s, Ch_8_labV12: 7.3s, ESP_HL_Radgeschw: 7.3s, ESP_HR_Radgeschw: 7.3s, ESP_VL_Radgeschw: 7.3s, ESP_VR_Radgeschw: 7.3s, Lat_CAN_Sig_13_: 7.3s, Long_CAN_Sig_12: 7.3s, NAWSPressure: 7.3s, NAWSSound: 7.3s, NAWSTemperature: 7.3s, a_x_CAN_Sig_4_: 7.3s, a_y_CAN_Sig_3_: 7.3s, a_z_CAN_Sig_5_: 7.3s, bUTC_CAN_Sig_24: 7.3s, mic_iso: 9.6s, v_east_CAN_Sig_: 7.3s, v_north_CAN_Sig: 7.3s, v_up_CAN_Sig_11: 7.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/03_Taycan/tyre10/track211_Taycan_tyre10_meas1_2p5_1_2025-09-23_17-02-03.h5
# Durations (s): Ch_1_labV12: 7.4s, Ch_2_labV12: 7.4s, Ch_3_labV12: 7.4s, Ch_4_labV12: 7.4s, Ch_5_labV12: 7.4s, Ch_7_labV12: 7.4s, Ch_8_labV12: 7.4s, ESP_HL_Radgeschw: 7.4s, ESP_HR_Radgeschw: 7.4s, ESP_VL_Radgeschw: 7.4s, ESP_VR_Radgeschw: 7.4s, FA_Hoehenwert_HL: 7.4s, FA_Hoehenwert_HR: 7.4s, FA_Hoehenwert_VL: 7.4s, FA_Hoehenwert_VR: 7.4s, Lat_CAN_Sig_13_: 7.4s, Long_CAN_Sig_12: 7.4s, NAWSPressure: 7.4s, NAWSSound: 7.4s, NAWSTemperature: 7.4s, a_x_CAN_Sig_4_: 7.4s, a_y_CAN_Sig_3_: 7.4s, a_z_CAN_Sig_5_: 7.4s, bUTC_CAN_Sig_24: 7.4s, mic_iso: 6.6s, v_east_CAN_Sig_: 7.4s, v_north_CAN_Sig: 7.4s, v_up_CAN_Sig_11: 7.4s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas3_2p5_1_2025-09-29_17-04-49.h5
# Durations (s): BCM1_Aussen_Temp: 7.3s, Ch_1_labV12: 7.3s, Ch_2_labV12: 7.3s, Ch_3_labV12: 7.3s, Ch_4_labV12: 7.3s, Ch_5_labV12: 7.3s, Ch_7_labV12: 7.3s, Ch_8_labV12: 7.3s, ESP_HL_Radgeschw: 7.3s, ESP_HR_Radgeschw: 7.3s, ESP_VL_Radgeschw: 7.3s, ESP_VR_Radgeschw: 7.3s, FA_Hoehenwert_HL: 7.3s, FA_Hoehenwert_HR: 7.3s, FA_Hoehenwert_VL: 7.3s, FA_Hoehenwert_VR: 7.3s, Lat_CAN_Sig_13_: 7.3s, Long_CAN_Sig_12: 7.3s, NAWSPressure: 7.6s, NAWSSound: 7.6s, NAWSTemperature: 7.6s, a_x_CAN_Sig_4_: 7.3s, a_y_CAN_Sig_3_: 7.3s, a_z_CAN_Sig_5_: 7.3s, bUTC_CAN_Sig_24: 7.3s, mic_iso: 4.4s, v_east_CAN_Sig_: 7.3s, v_north_CAN_Sig: 7.3s, v_up_CAN_Sig_11: 7.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/03_Taycan/tyre10/track211_Taycan_tyre10_meas2_2p5_1_2025-09-23_17-03-13.h5
# Durations (s): Ch_1_labV12: 7.3s, Ch_2_labV12: 7.3s, Ch_3_labV12: 7.3s, Ch_4_labV12: 7.3s, Ch_5_labV12: 7.3s, Ch_7_labV12: 7.3s, Ch_8_labV12: 7.3s, ESP_HL_Radgeschw: 7.3s, ESP_HR_Radgeschw: 7.3s, ESP_VL_Radgeschw: 7.3s, ESP_VR_Radgeschw: 7.3s, FA_Hoehenwert_HL: 7.3s, FA_Hoehenwert_HR: 7.3s, FA_Hoehenwert_VL: 7.3s, FA_Hoehenwert_VR: 7.3s, Lat_CAN_Sig_13_: 7.3s, Long_CAN_Sig_12: 7.3s, NAWSPressure: 7.4s, NAWSSound: 7.4s, NAWSTemperature: 7.4s, a_x_CAN_Sig_4_: 7.3s, a_y_CAN_Sig_3_: 7.3s, a_z_CAN_Sig_5_: 7.3s, bUTC_CAN_Sig_24: 7.3s, mic_iso: 3.8s, v_east_CAN_Sig_: 7.3s, v_north_CAN_Sig: 7.3s, v_up_CAN_Sig_11: 7.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/02_Q8 e-tron/tyre12/track150_Q8 e-tron_tyre12_meas0_2p5_1_2025-08-15_13-11-23.h5
# Durations (s): BCM1_Aussen_Temp: 7.3s, Ch_1_labV12: 7.3s, Ch_2_labV12: 7.3s, Ch_3_labV12: 7.3s, Ch_4_labV12: 7.3s, Ch_5_labV12: 7.3s, ESP_HL_Radgeschw: 7.3s, ESP_HR_Radgeschw: 7.3s, ESP_VL_Radgeschw: 7.3s, ESP_VR_Radgeschw: 7.3s, Lat_CAN_Sig_13_: 7.3s, Long_CAN_Sig_12: 7.3s, NAWSPressure: 7.3s, NAWSSound: 7.3s, NAWSTemperature: 7.3s, a_x_CAN_Sig_4_: 7.3s, a_y_CAN_Sig_3_: 7.3s, a_z_CAN_Sig_5_: 7.3s, bUTC_CAN_Sig_24: 7.3s, mic_iso: 4.1s, v_east_CAN_Sig_: 7.3s, v_north_CAN_Sig: 7.3s, v_up_CAN_Sig_11: 7.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/03_Taycan/tyre10/track211_Taycan_tyre10_meas4_2p5_1_2025-09-23_17-09-35.h5
# Durations (s): Ch_1_labV12: 7.2s, Ch_2_labV12: 7.2s, Ch_3_labV12: 7.2s, Ch_4_labV12: 7.2s, Ch_5_labV12: 7.2s, Ch_7_labV12: 7.2s, Ch_8_labV12: 7.2s, ESP_HL_Radgeschw: 7.2s, ESP_HR_Radgeschw: 7.2s, ESP_VL_Radgeschw: 7.2s, ESP_VR_Radgeschw: 7.2s, FA_Hoehenwert_HL: 7.2s, FA_Hoehenwert_HR: 7.2s, FA_Hoehenwert_VL: 7.2s, FA_Hoehenwert_VR: 7.2s, Lat_CAN_Sig_13_: 7.2s, Long_CAN_Sig_12: 7.2s, NAWSPressure: 7.2s, NAWSSound: 7.2s, NAWSTemperature: 7.2s, a_x_CAN_Sig_4_: 7.2s, a_y_CAN_Sig_3_: 7.2s, a_z_CAN_Sig_5_: 7.2s, bUTC_CAN_Sig_24: 7.2s, mic_iso: 6.1s, v_east_CAN_Sig_: 7.2s, v_north_CAN_Sig: 7.2s, v_up_CAN_Sig_11: 7.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-02-20.h5
# Durations (s): BCM1_Aussen_Temp: 7.2s, Ch_1_labV12: 7.2s, Ch_2_labV12: 7.2s, Ch_3_labV12: 7.2s, Ch_4_labV12: 7.2s, Ch_5_labV12: 7.2s, ESP_VL_Radgeschw: 7.2s, ESP_VR_Radgeschw: 7.2s, Lat_CAN_Sig_13_: 7.2s, Long_CAN_Sig_12: 7.2s, NAWSPressure: 7.5s, NAWSSound: 7.5s, NAWSTemperature: 7.5s, a_x_CAN_Sig_4_: 7.2s, a_y_CAN_Sig_3_: 7.2s, a_z_CAN_Sig_5_: 7.2s, bUTC_CAN_Sig_24: 7.2s, mic_iso: 5.4s, v_east_CAN_Sig_: 7.2s, v_north_CAN_Sig: 7.2s, v_up_CAN_Sig_11: 7.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/03_Taycan/tyre10/track211_Taycan_tyre10_meas4_2p5_1_2025-09-23_17-11-02.h5
# Durations (s): Ch_1_labV12: 7.2s, Ch_2_labV12: 7.2s, Ch_3_labV12: 7.2s, Ch_4_labV12: 7.2s, Ch_5_labV12: 7.2s, Ch_7_labV12: 7.2s, Ch_8_labV12: 7.2s, ESP_HL_Radgeschw: 7.2s, ESP_HR_Radgeschw: 7.2s, ESP_VL_Radgeschw: 7.2s, ESP_VR_Radgeschw: 7.2s, FA_Hoehenwert_HL: 7.2s, FA_Hoehenwert_HR: 7.2s, FA_Hoehenwert_VL: 7.2s, FA_Hoehenwert_VR: 7.2s, Lat_CAN_Sig_13_: 7.2s, Long_CAN_Sig_12: 7.2s, NAWSPressure: 7.1s, NAWSSound: 7.1s, NAWSTemperature: 7.1s, a_x_CAN_Sig_4_: 7.2s, a_y_CAN_Sig_3_: 7.2s, a_z_CAN_Sig_5_: 7.2s, bUTC_CAN_Sig_24: 7.2s, mic_iso: 5.9s, v_east_CAN_Sig_: 7.2s, v_north_CAN_Sig: 7.2s, v_up_CAN_Sig_11: 7.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-01-19.h5
# Durations (s): BCM1_Aussen_Temp: 7.0s, Ch_1_labV12: 7.0s, Ch_2_labV12: 7.0s, Ch_3_labV12: 7.0s, Ch_4_labV12: 7.0s, Ch_5_labV12: 7.0s, ESP_VL_Radgeschw: 7.0s, ESP_VR_Radgeschw: 7.0s, Lat_CAN_Sig_13_: 7.0s, Long_CAN_Sig_12: 7.0s, NAWSPressure: 7.3s, NAWSSound: 7.3s, NAWSTemperature: 7.3s, a_x_CAN_Sig_4_: 7.0s, a_y_CAN_Sig_3_: 7.0s, a_z_CAN_Sig_5_: 7.0s, bUTC_CAN_Sig_24: 7.0s, mic_iso: 5.6s, v_east_CAN_Sig_: 7.0s, v_north_CAN_Sig: 7.0s, v_up_CAN_Sig_11: 7.0s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/04_E-Golf/tyre13/track150_E-Golf_tyre13_meas2_2p5_1_2025-09-26_15-24-18.h5
# Durations (s): BCM1_Aussen_Temp: 6.8s, Ch_1_labV12: 6.8s, Ch_2_labV12: 6.8s, Ch_3_labV12: 6.8s, Ch_4_labV12: 6.8s, Ch_5_labV12: 6.8s, Ch_7_labV12: 6.8s, Ch_8_labV12: 6.8s, ESP_HL_Radgeschw: 6.8s, ESP_HR_Radgeschw: 6.8s, ESP_VL_Radgeschw: 6.8s, ESP_VR_Radgeschw: 6.8s, Lat_CAN_Sig_13_: 6.8s, Long_CAN_Sig_12: 6.8s, NAWSPressure: 7.4s, NAWSSound: 7.4s, NAWSTemperature: 7.4s, a_x_CAN_Sig_4_: 6.8s, a_y_CAN_Sig_3_: 6.8s, a_z_CAN_Sig_5_: 6.8s, bUTC_CAN_Sig_24: 6.8s, mic_iso: 8.1s, v_east_CAN_Sig_: 6.8s, v_north_CAN_Sig: 6.8s, v_up_CAN_Sig_11: 6.8s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-55-07.h5
# Durations (s): BCM1_Aussen_Temp: 7.0s, Ch_1_labV12: 7.0s, Ch_2_labV12: 7.0s, Ch_3_labV12: 7.0s, Ch_4_labV12: 7.0s, Ch_5_labV12: 7.0s, ESP_VL_Radgeschw: 7.0s, ESP_VR_Radgeschw: 7.0s, Lat_CAN_Sig_13_: 7.0s, Long_CAN_Sig_12: 7.0s, NAWSPressure: 7.2s, NAWSSound: 7.2s, NAWSTemperature: 7.2s, a_x_CAN_Sig_4_: 7.0s, a_y_CAN_Sig_3_: 7.0s, a_z_CAN_Sig_5_: 7.0s, bUTC_CAN_Sig_24: 7.0s, mic_iso: 6.0s, v_east_CAN_Sig_: 7.0s, v_north_CAN_Sig: 7.0s, v_up_CAN_Sig_11: 7.0s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/02_Q8 e-tron/tyre6/track150_Q8 e-tron_tyre6_meas1_2p5_1_2025-09-29_17-23-26.h5
# Durations (s): BCM1_Aussen_Temp: 6.9s, Ch_1_labV12: 6.9s, Ch_2_labV12: 6.9s, Ch_3_labV12: 6.9s, Ch_4_labV12: 6.9s, Ch_5_labV12: 6.9s, Ch_7_labV12: 6.9s, Ch_8_labV12: 6.9s, ESP_HL_Radgeschw: 6.9s, ESP_HR_Radgeschw: 6.9s, ESP_VL_Radgeschw: 6.9s, ESP_VR_Radgeschw: 6.9s, FA_Hoehenwert_HL: 6.9s, FA_Hoehenwert_HR: 6.9s, FA_Hoehenwert_VL: 6.9s, FA_Hoehenwert_VR: 6.9s, Lat_CAN_Sig_13_: 6.9s, Long_CAN_Sig_12: 6.9s, NAWSPressure: 6.9s, NAWSSound: 6.9s, NAWSTemperature: 6.9s, a_x_CAN_Sig_4_: 6.9s, a_y_CAN_Sig_3_: 6.9s, a_z_CAN_Sig_5_: 6.9s, bUTC_CAN_Sig_24: 6.9s, mic_iso: 6.8s, v_east_CAN_Sig_: 6.9s, v_north_CAN_Sig: 6.9s, v_up_CAN_Sig_11: 6.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas2_2p5_1_2025-09-29_17-01-27.h5
# Durations (s): BCM1_Aussen_Temp: 6.9s, Ch_1_labV12: 6.9s, Ch_2_labV12: 6.9s, Ch_3_labV12: 6.9s, Ch_4_labV12: 6.9s, Ch_5_labV12: 6.9s, Ch_7_labV12: 6.9s, Ch_8_labV12: 6.9s, ESP_HL_Radgeschw: 6.9s, ESP_HR_Radgeschw: 6.9s, ESP_VL_Radgeschw: 6.9s, ESP_VR_Radgeschw: 6.9s, FA_Hoehenwert_HL: 6.9s, FA_Hoehenwert_HR: 6.9s, FA_Hoehenwert_VL: 6.9s, FA_Hoehenwert_VR: 6.9s, Lat_CAN_Sig_13_: 6.9s, Long_CAN_Sig_12: 6.9s, NAWSPressure: 6.9s, NAWSSound: 6.9s, NAWSTemperature: 6.9s, a_x_CAN_Sig_4_: 6.9s, a_y_CAN_Sig_3_: 6.9s, a_z_CAN_Sig_5_: 6.9s, bUTC_CAN_Sig_24: 6.9s, mic_iso: 5.8s, v_east_CAN_Sig_: 6.9s, v_north_CAN_Sig: 6.9s, v_up_CAN_Sig_11: 6.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas6_2p5_1_2025-09-29_17-17-12.h5
# Durations (s): BCM1_Aussen_Temp: 6.8s, Ch_1_labV12: 6.8s, Ch_2_labV12: 6.8s, Ch_3_labV12: 6.8s, Ch_4_labV12: 6.8s, Ch_5_labV12: 6.8s, Ch_7_labV12: 6.8s, Ch_8_labV12: 6.8s, ESP_HL_Radgeschw: 6.8s, ESP_HR_Radgeschw: 6.8s, ESP_VL_Radgeschw: 6.8s, ESP_VR_Radgeschw: 6.8s, FA_Hoehenwert_HL: 6.8s, FA_Hoehenwert_HR: 6.8s, FA_Hoehenwert_VL: 6.8s, FA_Hoehenwert_VR: 6.8s, Lat_CAN_Sig_13_: 6.8s, Long_CAN_Sig_12: 6.8s, NAWSPressure: 7.2s, NAWSSound: 7.2s, NAWSTemperature: 7.2s, a_x_CAN_Sig_4_: 6.8s, a_y_CAN_Sig_3_: 6.8s, a_z_CAN_Sig_5_: 6.8s, bUTC_CAN_Sig_24: 6.8s, mic_iso: 7.3s, v_east_CAN_Sig_: 6.8s, v_north_CAN_Sig: 6.8s, v_up_CAN_Sig_11: 6.8s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-03-24.h5
# Durations (s): BCM1_Aussen_Temp: 6.8s, Ch_1_labV12: 6.8s, Ch_2_labV12: 6.8s, Ch_3_labV12: 6.8s, Ch_4_labV12: 6.8s, Ch_5_labV12: 6.8s, ESP_VL_Radgeschw: 6.8s, ESP_VR_Radgeschw: 6.8s, Lat_CAN_Sig_13_: 6.8s, Long_CAN_Sig_12: 6.8s, NAWSPressure: 7.1s, NAWSSound: 7.1s, NAWSTemperature: 7.1s, a_x_CAN_Sig_4_: 6.8s, a_y_CAN_Sig_3_: 6.8s, a_z_CAN_Sig_5_: 6.8s, bUTC_CAN_Sig_24: 6.8s, mic_iso: 5.9s, v_east_CAN_Sig_: 6.8s, v_north_CAN_Sig: 6.8s, v_up_CAN_Sig_11: 6.8s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-59-53.h5
# Durations (s): BCM1_Aussen_Temp: 6.8s, Ch_1_labV12: 6.8s, Ch_2_labV12: 6.8s, Ch_3_labV12: 6.8s, Ch_4_labV12: 6.8s, Ch_5_labV12: 6.8s, ESP_VL_Radgeschw: 6.8s, ESP_VR_Radgeschw: 6.8s, Lat_CAN_Sig_13_: 6.8s, Long_CAN_Sig_12: 6.8s, NAWSPressure: 7.1s, NAWSSound: 7.1s, NAWSTemperature: 7.1s, a_x_CAN_Sig_4_: 6.8s, a_y_CAN_Sig_3_: 6.8s, a_z_CAN_Sig_5_: 6.8s, bUTC_CAN_Sig_24: 6.8s, mic_iso: 4.8s, v_east_CAN_Sig_: 6.8s, v_north_CAN_Sig: 6.8s, v_up_CAN_Sig_11: 6.8s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/03_Taycan/tyre10/track211_Taycan_tyre10_meas6_2p5_1_2025-09-23_17-15-37.h5
# Durations (s): Ch_1_labV12: 6.7s, Ch_2_labV12: 6.7s, Ch_3_labV12: 6.7s, Ch_4_labV12: 6.7s, Ch_5_labV12: 6.7s, Ch_7_labV12: 6.7s, Ch_8_labV12: 6.7s, ESP_HL_Radgeschw: 6.7s, ESP_HR_Radgeschw: 6.7s, ESP_VL_Radgeschw: 6.7s, ESP_VR_Radgeschw: 6.7s, FA_Hoehenwert_HL: 6.7s, FA_Hoehenwert_HR: 6.7s, FA_Hoehenwert_VL: 6.7s, FA_Hoehenwert_VR: 6.7s, Lat_CAN_Sig_13_: 6.7s, Long_CAN_Sig_12: 6.7s, NAWSPressure: 6.7s, NAWSSound: 6.7s, NAWSTemperature: 6.7s, a_x_CAN_Sig_4_: 6.7s, a_y_CAN_Sig_3_: 6.7s, a_z_CAN_Sig_5_: 6.7s, bUTC_CAN_Sig_24: 6.7s, mic_iso: 5.6s, v_east_CAN_Sig_: 6.7s, v_north_CAN_Sig: 6.7s, v_up_CAN_Sig_11: 6.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_2pt6_vr50_2025-07-11_10-35-11.h5
# Durations (s): BCM1_Aussen_Temp: 6.6s, Ch_1_labV12: 6.6s, Ch_2_labV12: 6.6s, Ch_3_labV12: 6.6s, Ch_4_labV12: 6.6s, Ch_5_labV12: 6.6s, ESP_VL_Radgeschw: 6.6s, ESP_VR_Radgeschw: 6.6s, Lat_CAN_Sig_13_: 6.6s, Long_CAN_Sig_12: 6.6s, NAWSPressure: 6.9s, NAWSSound: 6.9s, NAWSTemperature: 6.9s, a_x_CAN_Sig_4_: 6.6s, a_y_CAN_Sig_3_: 6.6s, a_z_CAN_Sig_5_: 6.6s, bUTC_CAN_Sig_24: 6.6s, mic_iso: 6.2s, v_east_CAN_Sig_: 6.6s, v_north_CAN_Sig: 6.6s, v_up_CAN_Sig_11: 6.6s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-06-45.h5
# Durations (s): BCM1_Aussen_Temp: 6.5s, Ch_1_labV12: 6.5s, Ch_2_labV12: 6.5s, Ch_3_labV12: 6.5s, Ch_4_labV12: 6.5s, Ch_5_labV12: 6.5s, ESP_VL_Radgeschw: 6.5s, ESP_VR_Radgeschw: 6.5s, Lat_CAN_Sig_13_: 6.5s, Long_CAN_Sig_12: 6.5s, NAWSPressure: 6.9s, NAWSSound: 6.9s, NAWSTemperature: 6.9s, a_x_CAN_Sig_4_: 6.5s, a_y_CAN_Sig_3_: 6.5s, a_z_CAN_Sig_5_: 6.5s, bUTC_CAN_Sig_24: 6.5s, mic_iso: 6.3s, v_east_CAN_Sig_: 6.5s, v_north_CAN_Sig: 6.5s, v_up_CAN_Sig_11: 6.5s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/03_Taycan/tyre10/track150_Taycan_tyre10_meas1_2p5_1_2025-09-23_17-21-41.h5
# Durations (s): Ch_1_labV12: 6.7s, Ch_2_labV12: 6.7s, Ch_3_labV12: 6.7s, Ch_4_labV12: 6.7s, Ch_5_labV12: 6.7s, Ch_7_labV12: 6.7s, Ch_8_labV12: 6.7s, ESP_HL_Radgeschw: 6.7s, ESP_HR_Radgeschw: 6.7s, ESP_VL_Radgeschw: 6.7s, ESP_VR_Radgeschw: 6.7s, FA_Hoehenwert_HL: 6.7s, FA_Hoehenwert_HR: 6.7s, FA_Hoehenwert_VL: 6.7s, FA_Hoehenwert_VR: 6.7s, Lat_CAN_Sig_13_: 6.7s, Long_CAN_Sig_12: 6.7s, NAWSPressure: 6.7s, NAWSSound: 6.7s, NAWSTemperature: 6.7s, a_x_CAN_Sig_4_: 6.7s, a_y_CAN_Sig_3_: 6.7s, a_z_CAN_Sig_5_: 6.7s, bUTC_CAN_Sig_24: 6.7s, mic_iso: 4.4s, v_east_CAN_Sig_: 6.7s, v_north_CAN_Sig: 6.7s, v_up_CAN_Sig_11: 6.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas3_2p5_1_2025-09-29_17-03-59.h5
# Durations (s): BCM1_Aussen_Temp: 6.7s, Ch_1_labV12: 6.7s, Ch_2_labV12: 6.7s, Ch_3_labV12: 6.7s, Ch_4_labV12: 6.7s, Ch_5_labV12: 6.7s, Ch_7_labV12: 6.7s, Ch_8_labV12: 6.7s, ESP_HL_Radgeschw: 6.7s, ESP_HR_Radgeschw: 6.7s, ESP_VL_Radgeschw: 6.7s, ESP_VR_Radgeschw: 6.7s, FA_Hoehenwert_HL: 6.7s, FA_Hoehenwert_HR: 6.7s, FA_Hoehenwert_VL: 6.7s, FA_Hoehenwert_VR: 6.7s, Lat_CAN_Sig_13_: 6.7s, Long_CAN_Sig_12: 6.7s, NAWSPressure: 6.6s, NAWSSound: 6.6s, NAWSTemperature: 6.6s, a_x_CAN_Sig_4_: 6.7s, a_y_CAN_Sig_3_: 6.7s, a_z_CAN_Sig_5_: 6.7s, bUTC_CAN_Sig_24: 6.7s, mic_iso: 4.5s, v_east_CAN_Sig_: 6.7s, v_north_CAN_Sig: 6.7s, v_up_CAN_Sig_11: 6.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-43-38.h5
# Durations (s): BCM1_Aussen_Temp: 6.3s, Ch_1_labV12: 6.3s, Ch_2_labV12: 6.3s, Ch_3_labV12: 6.3s, Ch_4_labV12: 6.3s, Ch_5_labV12: 6.3s, ESP_VL_Radgeschw: 6.3s, ESP_VR_Radgeschw: 6.3s, Lat_CAN_Sig_13_: 6.3s, Long_CAN_Sig_12: 6.3s, NAWSPressure: 6.6s, NAWSSound: 6.6s, NAWSTemperature: 6.6s, a_x_CAN_Sig_4_: 6.3s, a_y_CAN_Sig_3_: 6.3s, a_z_CAN_Sig_5_: 6.3s, bUTC_CAN_Sig_24: 6.3s, mic_iso: 6.5s, v_east_CAN_Sig_: 6.3s, v_north_CAN_Sig: 6.3s, v_up_CAN_Sig_11: 6.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-04-43.h5
# Durations (s): BCM1_Aussen_Temp: 6.4s, Ch_1_labV12: 6.4s, Ch_2_labV12: 6.4s, Ch_3_labV12: 6.4s, Ch_4_labV12: 6.4s, Ch_5_labV12: 6.4s, ESP_VL_Radgeschw: 6.4s, ESP_VR_Radgeschw: 6.4s, Lat_CAN_Sig_13_: 6.4s, Long_CAN_Sig_12: 6.4s, NAWSPressure: 6.7s, NAWSSound: 6.7s, NAWSTemperature: 6.7s, a_x_CAN_Sig_4_: 6.4s, a_y_CAN_Sig_3_: 6.4s, a_z_CAN_Sig_5_: 6.4s, bUTC_CAN_Sig_24: 6.4s, mic_iso: 5.5s, v_east_CAN_Sig_: 6.4s, v_north_CAN_Sig: 6.4s, v_up_CAN_Sig_11: 6.4s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-05-45.h5
# Durations (s): BCM1_Aussen_Temp: 6.3s, Ch_1_labV12: 6.3s, Ch_2_labV12: 6.3s, Ch_3_labV12: 6.3s, Ch_4_labV12: 6.3s, Ch_5_labV12: 6.3s, ESP_VL_Radgeschw: 6.3s, ESP_VR_Radgeschw: 6.3s, Lat_CAN_Sig_13_: 6.3s, Long_CAN_Sig_12: 6.3s, NAWSPressure: 6.6s, NAWSSound: 6.6s, NAWSTemperature: 6.6s, a_x_CAN_Sig_4_: 6.3s, a_y_CAN_Sig_3_: 6.3s, a_z_CAN_Sig_5_: 6.3s, bUTC_CAN_Sig_24: 6.3s, mic_iso: 5.8s, v_east_CAN_Sig_: 6.3s, v_north_CAN_Sig: 6.3s, v_up_CAN_Sig_11: 6.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-58-50.h5
# Durations (s): BCM1_Aussen_Temp: 6.3s, Ch_1_labV12: 6.3s, Ch_2_labV12: 6.3s, Ch_3_labV12: 6.3s, Ch_4_labV12: 6.3s, Ch_5_labV12: 6.3s, ESP_VL_Radgeschw: 6.3s, ESP_VR_Radgeschw: 6.3s, Lat_CAN_Sig_13_: 6.3s, Long_CAN_Sig_12: 6.3s, NAWSPressure: 6.6s, NAWSSound: 6.6s, NAWSTemperature: 6.6s, a_x_CAN_Sig_4_: 6.3s, a_y_CAN_Sig_3_: 6.3s, a_z_CAN_Sig_5_: 6.3s, bUTC_CAN_Sig_24: 6.3s, mic_iso: 5.3s, v_east_CAN_Sig_: 6.3s, v_north_CAN_Sig: 6.3s, v_up_CAN_Sig_11: 6.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/02_Q8 e-tron/tyre6/track211_Q8 e-tron_tyre6_meas2_2p5_1_2025-09-29_17-00-32.h5
# Durations (s): BCM1_Aussen_Temp: 6.3s, Ch_1_labV12: 6.3s, Ch_2_labV12: 6.3s, Ch_3_labV12: 6.3s, Ch_4_labV12: 6.3s, Ch_5_labV12: 6.3s, Ch_7_labV12: 6.3s, Ch_8_labV12: 6.3s, ESP_HL_Radgeschw: 6.3s, ESP_HR_Radgeschw: 6.3s, ESP_VL_Radgeschw: 6.3s, ESP_VR_Radgeschw: 6.3s, FA_Hoehenwert_HL: 6.3s, FA_Hoehenwert_HR: 6.3s, FA_Hoehenwert_VL: 6.3s, FA_Hoehenwert_VR: 6.3s, Lat_CAN_Sig_13_: 6.3s, Long_CAN_Sig_12: 6.3s, NAWSPressure: 6.3s, NAWSSound: 6.3s, NAWSTemperature: 6.3s, a_x_CAN_Sig_4_: 6.3s, a_y_CAN_Sig_3_: 6.3s, a_z_CAN_Sig_5_: 6.3s, bUTC_CAN_Sig_24: 6.3s, mic_iso: 6.1s, v_east_CAN_Sig_: 6.3s, v_north_CAN_Sig: 6.3s, v_up_CAN_Sig_11: 6.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/04_E-Golf/tyre13/track150_E-Golf_tyre13_meas1_2p5_1_2025-09-26_15-22-29.h5
# Durations (s): BCM1_Aussen_Temp: 6.1s, Ch_1_labV12: 6.1s, Ch_2_labV12: 6.1s, Ch_3_labV12: 6.1s, Ch_4_labV12: 6.1s, Ch_5_labV12: 6.1s, Ch_7_labV12: 6.1s, Ch_8_labV12: 6.1s, ESP_HL_Radgeschw: 6.1s, ESP_HR_Radgeschw: 6.1s, ESP_VL_Radgeschw: 6.1s, ESP_VR_Radgeschw: 6.1s, Lat_CAN_Sig_13_: 6.1s, Long_CAN_Sig_12: 6.1s, NAWSPressure: 6.6s, NAWSSound: 6.6s, NAWSTemperature: 6.6s, a_x_CAN_Sig_4_: 6.1s, a_y_CAN_Sig_3_: 6.1s, a_z_CAN_Sig_5_: 6.1s, bUTC_CAN_Sig_24: 6.1s, mic_iso: 10.5s, v_east_CAN_Sig_: 6.1s, v_north_CAN_Sig: 6.1s, v_up_CAN_Sig_11: 6.1s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/02_Q8 e-tron/tyre6/track150_Q8 e-tron_tyre6_meas1_2p5_1_2025-09-29_17-22-42.h5
# Durations (s): BCM1_Aussen_Temp: 6.2s, Ch_1_labV12: 6.2s, Ch_2_labV12: 6.2s, Ch_3_labV12: 6.2s, Ch_4_labV12: 6.2s, Ch_5_labV12: 6.2s, Ch_7_labV12: 6.2s, Ch_8_labV12: 6.2s, ESP_HL_Radgeschw: 6.2s, ESP_HR_Radgeschw: 6.2s, ESP_VL_Radgeschw: 6.2s, ESP_VR_Radgeschw: 6.2s, FA_Hoehenwert_HL: 6.2s, FA_Hoehenwert_HR: 6.2s, FA_Hoehenwert_VL: 6.2s, FA_Hoehenwert_VR: 6.2s, Lat_CAN_Sig_13_: 6.2s, Long_CAN_Sig_12: 6.2s, NAWSPressure: 6.2s, NAWSSound: 6.3s, NAWSTemperature: 6.2s, a_x_CAN_Sig_4_: 6.2s, a_y_CAN_Sig_3_: 6.2s, a_z_CAN_Sig_5_: 6.2s, bUTC_CAN_Sig_24: 6.2s, mic_iso: 7.5s, v_east_CAN_Sig_: 6.2s, v_north_CAN_Sig: 6.2s, v_up_CAN_Sig_11: 6.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-57-46.h5
# Durations (s): BCM1_Aussen_Temp: 6.2s, Ch_1_labV12: 6.2s, Ch_2_labV12: 6.2s, Ch_3_labV12: 6.2s, Ch_4_labV12: 6.2s, Ch_5_labV12: 6.2s, ESP_VL_Radgeschw: 6.2s, ESP_VR_Radgeschw: 6.2s, Lat_CAN_Sig_13_: 6.2s, Long_CAN_Sig_12: 6.2s, NAWSPressure: 6.5s, NAWSSound: 6.5s, NAWSTemperature: 6.5s, a_x_CAN_Sig_4_: 6.2s, a_y_CAN_Sig_3_: 6.2s, a_z_CAN_Sig_5_: 6.2s, bUTC_CAN_Sig_24: 6.2s, mic_iso: 6.1s, v_east_CAN_Sig_: 6.2s, v_north_CAN_Sig: 6.2s, v_up_CAN_Sig_11: 6.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-40-06.h5
# Durations (s): BCM1_Aussen_Temp: 6.2s, Ch_1_labV12: 6.2s, Ch_2_labV12: 6.2s, Ch_3_labV12: 6.2s, Ch_4_labV12: 6.2s, Ch_5_labV12: 6.2s, ESP_VL_Radgeschw: 6.2s, ESP_VR_Radgeschw: 6.2s, Lat_CAN_Sig_13_: 6.2s, Long_CAN_Sig_12: 6.2s, NAWSPressure: 6.5s, NAWSSound: 6.5s, NAWSTemperature: 6.5s, a_x_CAN_Sig_4_: 6.2s, a_y_CAN_Sig_3_: 6.2s, a_z_CAN_Sig_5_: 6.2s, bUTC_CAN_Sig_24: 6.2s, mic_iso: 6.5s, v_east_CAN_Sig_: 6.2s, v_north_CAN_Sig: 6.2s, v_up_CAN_Sig_11: 6.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-38-35.h5
# Durations (s): BCM1_Aussen_Temp: 6.2s, Ch_1_labV12: 6.2s, Ch_2_labV12: 6.2s, Ch_3_labV12: 6.2s, Ch_4_labV12: 6.2s, Ch_5_labV12: 6.2s, ESP_VL_Radgeschw: 6.2s, ESP_VR_Radgeschw: 6.2s, Lat_CAN_Sig_13_: 6.2s, Long_CAN_Sig_12: 6.2s, NAWSPressure: 6.4s, NAWSSound: 6.4s, NAWSTemperature: 6.4s, a_x_CAN_Sig_4_: 6.2s, a_y_CAN_Sig_3_: 6.2s, a_z_CAN_Sig_5_: 6.2s, bUTC_CAN_Sig_24: 6.2s, mic_iso: 6.0s, v_east_CAN_Sig_: 6.2s, v_north_CAN_Sig: 6.2s, v_up_CAN_Sig_11: 6.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/03_Taycan/tyre10/track150_Taycan_tyre10_meas1_2p5_1_2025-09-23_17-22-54.h5
# Durations (s): Ch_1_labV12: 6.2s, Ch_2_labV12: 6.2s, Ch_3_labV12: 6.2s, Ch_4_labV12: 6.2s, Ch_5_labV12: 6.2s, Ch_7_labV12: 6.2s, Ch_8_labV12: 6.2s, ESP_HL_Radgeschw: 6.2s, ESP_HR_Radgeschw: 6.2s, ESP_VL_Radgeschw: 6.2s, ESP_VR_Radgeschw: 6.2s, FA_Hoehenwert_HL: 6.2s, FA_Hoehenwert_HR: 6.2s, FA_Hoehenwert_VL: 6.2s, FA_Hoehenwert_VR: 6.2s, Lat_CAN_Sig_13_: 6.2s, Long_CAN_Sig_12: 6.2s, NAWSPressure: 6.3s, NAWSSound: 6.3s, NAWSTemperature: 6.3s, a_x_CAN_Sig_4_: 6.2s, a_y_CAN_Sig_3_: 6.2s, a_z_CAN_Sig_5_: 6.2s, bUTC_CAN_Sig_24: 6.2s, mic_iso: 5.1s, v_east_CAN_Sig_: 6.2s, v_north_CAN_Sig: 6.2s, v_up_CAN_Sig_11: 6.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/04_E-Golf/tyre13/track211_E-Golf_tyre13_meas1_2p5_1_2025-09-26_14-48-57.h5
# Durations (s): BCM1_Aussen_Temp: 5.9s, Ch_1_labV12: 5.9s, Ch_2_labV12: 5.9s, Ch_3_labV12: 5.9s, Ch_4_labV12: 5.9s, Ch_5_labV12: 5.9s, Ch_7_labV12: 5.9s, Ch_8_labV12: 5.9s, ESP_HL_Radgeschw: 5.9s, ESP_HR_Radgeschw: 5.9s, ESP_VL_Radgeschw: 5.9s, ESP_VR_Radgeschw: 5.9s, Lat_CAN_Sig_13_: 5.9s, Long_CAN_Sig_12: 5.9s, NAWSPressure: 6.2s, NAWSSound: 6.3s, NAWSTemperature: 6.2s, a_x_CAN_Sig_4_: 5.9s, a_y_CAN_Sig_3_: 5.9s, a_z_CAN_Sig_5_: 5.9s, bUTC_CAN_Sig_24: 5.9s, mic_iso: 7.9s, v_east_CAN_Sig_: 5.9s, v_north_CAN_Sig: 5.9s, v_up_CAN_Sig_11: 5.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-45-35.h5
# Durations (s): BCM1_Aussen_Temp: 6.0s, Ch_1_labV12: 6.0s, Ch_2_labV12: 6.0s, Ch_3_labV12: 6.0s, Ch_4_labV12: 6.0s, Ch_5_labV12: 6.0s, ESP_VL_Radgeschw: 6.0s, ESP_VR_Radgeschw: 6.0s, Lat_CAN_Sig_13_: 6.0s, Long_CAN_Sig_12: 6.0s, NAWSPressure: 6.2s, NAWSSound: 6.2s, NAWSTemperature: 6.2s, a_x_CAN_Sig_4_: 6.0s, a_y_CAN_Sig_3_: 6.0s, a_z_CAN_Sig_5_: 6.0s, bUTC_CAN_Sig_24: 6.0s, mic_iso: 6.6s, v_east_CAN_Sig_: 6.0s, v_north_CAN_Sig: 6.0s, v_up_CAN_Sig_11: 6.0s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/04_E-Golf/tyre13/track211_E-Golf_tyre13_meas5_2p5_1_2025-09-26_15-09-38.h5
# Durations (s): BCM1_Aussen_Temp: 6.0s, Ch_1_labV12: 6.0s, Ch_2_labV12: 6.0s, Ch_3_labV12: 6.0s, Ch_4_labV12: 6.0s, Ch_5_labV12: 6.0s, Ch_7_labV12: 6.0s, Ch_8_labV12: 6.0s, ESP_HL_Radgeschw: 6.0s, ESP_HR_Radgeschw: 6.0s, ESP_VL_Radgeschw: 6.0s, ESP_VR_Radgeschw: 6.0s, Lat_CAN_Sig_13_: 6.0s, Long_CAN_Sig_12: 6.0s, NAWSPressure: 5.9s, NAWSSound: 5.9s, NAWSTemperature: 5.9s, a_x_CAN_Sig_4_: 6.0s, a_y_CAN_Sig_3_: 6.0s, a_z_CAN_Sig_5_: 6.0s, bUTC_CAN_Sig_24: 6.0s, mic_iso: 6.3s, v_east_CAN_Sig_: 6.0s, v_north_CAN_Sig: 6.0s, v_up_CAN_Sig_11: 6.0s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-56-10.h5
# ...
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre3/track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-33-49.h5
# Durations (s): BCM1_Aussen_Temp: 2.6s, Ch_1_labV12: 2.6s, Ch_2_labV12: 2.6s, Ch_3_labV12: 2.6s, Ch_4_labV12: 2.6s, Ch_5_labV12: 2.6s, ESP_VL_Radgeschw: 2.6s, ESP_VR_Radgeschw: 2.6s, Lat_CAN_Sig_13_: 2.6s, Long_CAN_Sig_12: 2.6s, NAWSPressure: 2.8s, NAWSSound: 2.8s, NAWSTemperature: 2.8s, a_x_CAN_Sig_4_: 2.6s, a_y_CAN_Sig_3_: 2.6s, a_z_CAN_Sig_5_: 2.6s, bUTC_CAN_Sig_24: 2.6s, mic_iso: 4.6s, v_east_CAN_Sig_: 2.6s, v_north_CAN_Sig: 2.6s, v_up_CAN_Sig_11: 2.6s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/03_Taycan/tyre10/track211_Taycan_tyre10_meas3_2p5_1_2025-09-23_17-06-35.h5
# Durations (s): Ch_1_labV12: 2.7s, Ch_2_labV12: 2.7s, Ch_3_labV12: 2.7s, Ch_4_labV12: 2.7s, Ch_5_labV12: 2.7s, Ch_7_labV12: 2.7s, Ch_8_labV12: 2.7s, ESP_HL_Radgeschw: 2.7s, ESP_HR_Radgeschw: 2.7s, ESP_VL_Radgeschw: 2.7s, ESP_VR_Radgeschw: 2.7s, FA_Hoehenwert_HL: 2.7s, FA_Hoehenwert_HR: 2.7s, FA_Hoehenwert_VL: 2.7s, FA_Hoehenwert_VR: 2.7s, Lat_CAN_Sig_13_: 2.7s, Long_CAN_Sig_12: 2.7s, NAWSPressure: 2.7s, NAWSSound: 2.7s, NAWSTemperature: 2.7s, a_x_CAN_Sig_4_: 2.7s, a_y_CAN_Sig_3_: 2.7s, a_z_CAN_Sig_5_: 2.7s, bUTC_CAN_Sig_24: 2.7s, mic_iso: 4.1s, v_east_CAN_Sig_: 2.7s, v_north_CAN_Sig: 2.7s, v_up_CAN_Sig_11: 2.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/02_Q8 e-tron/tyre12/track150_Q8 e-tron_tyre12_meas2_2p5_1_2025-08-15_13-15-11.h5
# Durations (s): BCM1_Aussen_Temp: 2.7s, Ch_1_labV12: 2.7s, Ch_2_labV12: 2.7s, Ch_3_labV12: 2.7s, Ch_4_labV12: 2.7s, Ch_5_labV12: 2.7s, ESP_HL_Radgeschw: 2.7s, ESP_HR_Radgeschw: 2.7s, ESP_VL_Radgeschw: 2.7s, ESP_VR_Radgeschw: 2.7s, Lat_CAN_Sig_13_: 2.7s, Long_CAN_Sig_12: 2.7s, NAWSPressure: 2.5s, NAWSSound: 2.5s, NAWSTemperature: 2.5s, a_x_CAN_Sig_4_: 2.7s, a_y_CAN_Sig_3_: 2.7s, a_z_CAN_Sig_5_: 2.7s, bUTC_CAN_Sig_24: 2.7s, mic_iso: 3.3s, v_east_CAN_Sig_: 2.7s, v_north_CAN_Sig: 2.7s, v_up_CAN_Sig_11: 2.7s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas2_2p5_1_2025-08-07_10-32-56.h5
# Durations (s): BCM1_Aussen_Temp: 2.5s, Ch_1_labV12: 2.5s, Ch_2_labV12: 2.5s, Ch_3_labV12: 2.5s, Ch_4_labV12: 2.5s, Ch_5_labV12: 2.5s, ESP_VL_Radgeschw: 2.5s, ESP_VR_Radgeschw: 2.5s, Lat_CAN_Sig_13_: 2.5s, Long_CAN_Sig_12: 2.5s, NAWSPressure: 2.5s, NAWSSound: 2.5s, NAWSTemperature: 2.5s, a_x_CAN_Sig_4_: 2.5s, a_y_CAN_Sig_3_: 2.5s, a_z_CAN_Sig_5_: 2.5s, bUTC_CAN_Sig_24: 2.5s, mic_iso: 5.4s, v_east_CAN_Sig_: 2.5s, v_north_CAN_Sig: 2.5s, v_up_CAN_Sig_11: 2.5s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas3_2p5_1_2025-08-07_11-03-25.h5
# Durations (s): BCM1_Aussen_Temp: 2.5s, Ch_1_labV12: 2.5s, Ch_2_labV12: 2.5s, Ch_3_labV12: 2.5s, Ch_4_labV12: 2.5s, Ch_5_labV12: 2.5s, ESP_VL_Radgeschw: 2.5s, ESP_VR_Radgeschw: 2.5s, Lat_CAN_Sig_13_: 2.5s, Long_CAN_Sig_12: 2.5s, NAWSPressure: 2.5s, NAWSSound: 2.5s, NAWSTemperature: 2.5s, a_x_CAN_Sig_4_: 2.5s, a_y_CAN_Sig_3_: 2.5s, a_z_CAN_Sig_5_: 2.5s, bUTC_CAN_Sig_24: 2.5s, mic_iso: 4.4s, v_east_CAN_Sig_: 2.5s, v_north_CAN_Sig: 2.5s, v_up_CAN_Sig_11: 2.5s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas2_2p5_1_2025-08-07_10-58-48.h5
# Durations (s): BCM1_Aussen_Temp: 2.5s, Ch_1_labV12: 2.5s, Ch_2_labV12: 2.5s, Ch_3_labV12: 2.5s, Ch_4_labV12: 2.5s, Ch_5_labV12: 2.5s, ESP_VL_Radgeschw: 2.5s, ESP_VR_Radgeschw: 2.5s, Lat_CAN_Sig_13_: 2.5s, Long_CAN_Sig_12: 2.5s, NAWSPressure: 2.4s, NAWSSound: 2.5s, NAWSTemperature: 2.4s, a_x_CAN_Sig_4_: 2.5s, a_y_CAN_Sig_3_: 2.5s, a_z_CAN_Sig_5_: 2.5s, bUTC_CAN_Sig_24: 2.5s, mic_iso: 5.4s, v_east_CAN_Sig_: 2.5s, v_north_CAN_Sig: 2.5s, v_up_CAN_Sig_11: 2.5s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas2_2p5_1_2025-08-07_10-31-05.h5
# Durations (s): BCM1_Aussen_Temp: 2.4s, Ch_1_labV12: 2.4s, Ch_2_labV12: 2.4s, Ch_3_labV12: 2.4s, Ch_4_labV12: 2.4s, Ch_5_labV12: 2.4s, ESP_VL_Radgeschw: 2.4s, ESP_VR_Radgeschw: 2.4s, Lat_CAN_Sig_13_: 2.4s, Long_CAN_Sig_12: 2.4s, NAWSPressure: 2.4s, NAWSSound: 2.4s, NAWSTemperature: 2.4s, a_x_CAN_Sig_4_: 2.4s, a_y_CAN_Sig_3_: 2.4s, a_z_CAN_Sig_5_: 2.4s, bUTC_CAN_Sig_24: 2.4s, mic_iso: 4.1s, v_east_CAN_Sig_: 2.4s, v_north_CAN_Sig: 2.4s, v_up_CAN_Sig_11: 2.4s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas3_2p5_1_2025-08-07_11-02-35.h5
# Durations (s): BCM1_Aussen_Temp: 2.4s, Ch_1_labV12: 2.4s, Ch_2_labV12: 2.4s, Ch_3_labV12: 2.4s, Ch_4_labV12: 2.4s, Ch_5_labV12: 2.4s, ESP_VL_Radgeschw: 2.4s, ESP_VR_Radgeschw: 2.4s, Lat_CAN_Sig_13_: 2.4s, Long_CAN_Sig_12: 2.4s, NAWSPressure: 2.4s, NAWSSound: 2.4s, NAWSTemperature: 2.4s, a_x_CAN_Sig_4_: 2.4s, a_y_CAN_Sig_3_: 2.4s, a_z_CAN_Sig_5_: 2.4s, bUTC_CAN_Sig_24: 2.4s, mic_iso: 3.8s, v_east_CAN_Sig_: 2.4s, v_north_CAN_Sig: 2.4s, v_up_CAN_Sig_11: 2.4s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas2_2p5_1_2025-08-07_11-00-36.h5
# Durations (s): BCM1_Aussen_Temp: 2.4s, Ch_1_labV12: 2.4s, Ch_2_labV12: 2.4s, Ch_3_labV12: 2.4s, Ch_4_labV12: 2.4s, Ch_5_labV12: 2.4s, ESP_VL_Radgeschw: 2.4s, ESP_VR_Radgeschw: 2.4s, Lat_CAN_Sig_13_: 2.4s, Long_CAN_Sig_12: 2.4s, NAWSPressure: 2.4s, NAWSSound: 2.4s, NAWSTemperature: 2.4s, a_x_CAN_Sig_4_: 2.4s, a_y_CAN_Sig_3_: 2.4s, a_z_CAN_Sig_5_: 2.4s, bUTC_CAN_Sig_24: 2.4s, mic_iso: 4.7s, v_east_CAN_Sig_: 2.4s, v_north_CAN_Sig: 2.4s, v_up_CAN_Sig_11: 2.4s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas2_2p5_1_2025-08-07_10-32-00.h5
# Durations (s): BCM1_Aussen_Temp: 2.4s, Ch_1_labV12: 2.4s, Ch_2_labV12: 2.4s, Ch_3_labV12: 2.4s, Ch_4_labV12: 2.4s, Ch_5_labV12: 2.4s, ESP_VL_Radgeschw: 2.4s, ESP_VR_Radgeschw: 2.4s, Lat_CAN_Sig_13_: 2.4s, Long_CAN_Sig_12: 2.4s, NAWSPressure: 2.4s, NAWSSound: 2.4s, NAWSTemperature: 2.4s, a_x_CAN_Sig_4_: 2.4s, a_y_CAN_Sig_3_: 2.4s, a_z_CAN_Sig_5_: 2.4s, bUTC_CAN_Sig_24: 2.4s, mic_iso: 4.4s, v_east_CAN_Sig_: 2.4s, v_north_CAN_Sig: 2.4s, v_up_CAN_Sig_11: 2.4s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas2_2p5_1_2025-08-07_10-59-40.h5
# Durations (s): BCM1_Aussen_Temp: 2.3s, Ch_1_labV12: 2.3s, Ch_2_labV12: 2.3s, Ch_3_labV12: 2.3s, Ch_4_labV12: 2.3s, Ch_5_labV12: 2.3s, ESP_VL_Radgeschw: 2.3s, ESP_VR_Radgeschw: 2.3s, Lat_CAN_Sig_13_: 2.3s, Long_CAN_Sig_12: 2.3s, NAWSPressure: 2.3s, NAWSSound: 2.3s, NAWSTemperature: 2.3s, a_x_CAN_Sig_4_: 2.3s, a_y_CAN_Sig_3_: 2.3s, a_z_CAN_Sig_5_: 2.3s, bUTC_CAN_Sig_24: 2.3s, mic_iso: 5.2s, v_east_CAN_Sig_: 2.3s, v_north_CAN_Sig: 2.3s, v_up_CAN_Sig_11: 2.3s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/04_E-Golf/tyre13/track211_E-Golf_tyre13_meas3_2p5_1_2025-09-26_14-55-08.h5
# Durations (s): BCM1_Aussen_Temp: 2.2s, Ch_1_labV12: 2.2s, Ch_2_labV12: 2.2s, Ch_3_labV12: 2.2s, Ch_4_labV12: 2.2s, Ch_5_labV12: 2.2s, Ch_7_labV12: 2.2s, Ch_8_labV12: 2.2s, ESP_HL_Radgeschw: 2.2s, ESP_HR_Radgeschw: 2.2s, ESP_VL_Radgeschw: 2.2s, ESP_VR_Radgeschw: 2.2s, Lat_CAN_Sig_13_: 2.2s, Long_CAN_Sig_12: 2.2s, NAWSPressure: 2.5s, NAWSSound: 2.5s, NAWSTemperature: 2.5s, a_x_CAN_Sig_4_: 2.2s, a_y_CAN_Sig_3_: 2.2s, a_z_CAN_Sig_5_: 2.2s, bUTC_CAN_Sig_24: 2.2s, mic_iso: 6.0s, v_east_CAN_Sig_: 2.2s, v_north_CAN_Sig: 2.2s, v_up_CAN_Sig_11: 2.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas3_2p5_1_2025-08-07_10-35-50.h5
# Durations (s): BCM1_Aussen_Temp: 2.2s, Ch_1_labV12: 2.2s, Ch_2_labV12: 2.2s, Ch_3_labV12: 2.2s, Ch_4_labV12: 2.2s, Ch_5_labV12: 2.2s, ESP_VL_Radgeschw: 2.2s, ESP_VR_Radgeschw: 2.2s, Lat_CAN_Sig_13_: 2.2s, Long_CAN_Sig_12: 2.2s, NAWSPressure: 2.3s, NAWSSound: 2.3s, NAWSTemperature: 2.3s, a_x_CAN_Sig_4_: 2.2s, a_y_CAN_Sig_3_: 2.2s, a_z_CAN_Sig_5_: 2.2s, bUTC_CAN_Sig_24: 2.2s, mic_iso: 5.3s, v_east_CAN_Sig_: 2.2s, v_north_CAN_Sig: 2.2s, v_up_CAN_Sig_11: 2.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/02_Q8 e-tron/tyre12/track150_Q8 e-tron_tyre12_meas2_2p5_1_2025-08-15_13-14-26.h5
# Durations (s): BCM1_Aussen_Temp: 2.2s, Ch_1_labV12: 2.2s, Ch_2_labV12: 2.2s, Ch_3_labV12: 2.2s, Ch_4_labV12: 2.2s, Ch_5_labV12: 2.2s, ESP_HL_Radgeschw: 2.2s, ESP_HR_Radgeschw: 2.2s, ESP_VL_Radgeschw: 2.2s, ESP_VR_Radgeschw: 2.2s, Lat_CAN_Sig_13_: 2.2s, Long_CAN_Sig_12: 2.2s, NAWSPressure: 2.3s, NAWSSound: 2.3s, NAWSTemperature: 2.3s, a_x_CAN_Sig_4_: 2.2s, a_y_CAN_Sig_3_: 2.2s, a_z_CAN_Sig_5_: 2.2s, bUTC_CAN_Sig_24: 2.2s, mic_iso: 3.8s, v_east_CAN_Sig_: 2.2s, v_north_CAN_Sig: 2.2s, v_up_CAN_Sig_11: 2.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas3_2p5_1_2025-08-07_10-34-58.h5
# Durations (s): BCM1_Aussen_Temp: 2.1s, Ch_1_labV12: 2.1s, Ch_2_labV12: 2.1s, Ch_3_labV12: 2.1s, Ch_4_labV12: 2.1s, Ch_5_labV12: 2.1s, ESP_VL_Radgeschw: 2.1s, ESP_VR_Radgeschw: 2.1s, Lat_CAN_Sig_13_: 2.1s, Long_CAN_Sig_12: 2.1s, NAWSPressure: 2.2s, NAWSSound: 2.2s, NAWSTemperature: 2.2s, a_x_CAN_Sig_4_: 2.1s, a_y_CAN_Sig_3_: 2.1s, a_z_CAN_Sig_5_: 2.1s, bUTC_CAN_Sig_24: 2.1s, mic_iso: 4.3s, v_east_CAN_Sig_: 2.1s, v_north_CAN_Sig: 2.1s, v_up_CAN_Sig_11: 2.1s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/02_Q8 e-tron/tyre12/track150_Q8 e-tron_tyre12_meas2_2p5_1_2025-08-15_13-15-55.h5
# Durations (s): BCM1_Aussen_Temp: 2.2s, Ch_1_labV12: 2.2s, Ch_2_labV12: 2.2s, Ch_3_labV12: 2.2s, Ch_4_labV12: 2.2s, Ch_5_labV12: 2.2s, ESP_HL_Radgeschw: 2.2s, ESP_HR_Radgeschw: 2.2s, ESP_VL_Radgeschw: 2.2s, ESP_VR_Radgeschw: 2.2s, Lat_CAN_Sig_13_: 2.2s, Long_CAN_Sig_12: 2.2s, NAWSPressure: 2.2s, NAWSSound: 2.2s, NAWSTemperature: 2.2s, a_x_CAN_Sig_4_: 2.2s, a_y_CAN_Sig_3_: 2.2s, a_z_CAN_Sig_5_: 2.2s, bUTC_CAN_Sig_24: 2.2s, mic_iso: 3.4s, v_east_CAN_Sig_: 2.2s, v_north_CAN_Sig: 2.2s, v_up_CAN_Sig_11: 2.2s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/01_ID.4/tyre1/track150_ID.4_tyre1_meas2_2p5_1_2025-08-07_11-25-10.h5
# Durations (s): BCM1_Aussen_Temp: 2.1s, Ch_1_labV12: 2.1s, Ch_2_labV12: 2.1s, Ch_3_labV12: 2.1s, Ch_4_labV12: 2.1s, Ch_5_labV12: 2.1s, ESP_VL_Radgeschw: 2.1s, ESP_VR_Radgeschw: 2.1s, Lat_CAN_Sig_13_: 2.1s, Long_CAN_Sig_12: 2.1s, NAWSPressure: 2.1s, NAWSSound: 2.1s, NAWSTemperature: 2.1s, a_x_CAN_Sig_4_: 2.1s, a_y_CAN_Sig_3_: 2.1s, a_z_CAN_Sig_5_: 2.1s, bUTC_CAN_Sig_24: 2.1s, mic_iso: 3.4s, v_east_CAN_Sig_: 2.1s, v_north_CAN_Sig: 2.1s, v_up_CAN_Sig_11: 2.1s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas3_2p5_1_2025-08-07_10-37-54.h5
# Durations (s): BCM1_Aussen_Temp: 1.9s, Ch_1_labV12: 1.9s, Ch_2_labV12: 1.9s, Ch_3_labV12: 1.9s, Ch_4_labV12: 1.9s, Ch_5_labV12: 1.9s, ESP_VL_Radgeschw: 1.9s, ESP_VR_Radgeschw: 1.9s, Lat_CAN_Sig_13_: 1.9s, Long_CAN_Sig_12: 1.9s, NAWSPressure: 2.0s, NAWSSound: 2.0s, NAWSTemperature: 2.0s, a_x_CAN_Sig_4_: 1.9s, a_y_CAN_Sig_3_: 1.9s, a_z_CAN_Sig_5_: 1.9s, bUTC_CAN_Sig_24: 1.9s, mic_iso: 4.6s, v_east_CAN_Sig_: 1.9s, v_north_CAN_Sig: 1.9s, v_up_CAN_Sig_11: 1.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track211/01_ID.4/tyre1/track211_ID.4_tyre1_meas3_2p5_1_2025-08-07_11-01-45.h5
# Durations (s): BCM1_Aussen_Temp: 1.9s, Ch_1_labV12: 1.9s, Ch_2_labV12: 1.9s, Ch_3_labV12: 1.9s, Ch_4_labV12: 1.9s, Ch_5_labV12: 1.9s, ESP_VL_Radgeschw: 1.9s, ESP_VR_Radgeschw: 1.9s, Lat_CAN_Sig_13_: 1.9s, Long_CAN_Sig_12: 1.9s, NAWSPressure: 1.9s, NAWSSound: 1.9s, NAWSTemperature: 1.9s, a_x_CAN_Sig_4_: 1.9s, a_y_CAN_Sig_3_: 1.9s, a_z_CAN_Sig_5_: 1.9s, bUTC_CAN_Sig_24: 1.9s, mic_iso: 4.5s, v_east_CAN_Sig_: 1.9s, v_north_CAN_Sig: 1.9s, v_up_CAN_Sig_11: 1.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/01_ID.4/tyre1/track150_ID.4_tyre1_meas3_2p5_1_2025-08-07_11-28-02.h5
# Durations (s): BCM1_Aussen_Temp: 1.9s, Ch_1_labV12: 1.9s, Ch_2_labV12: 1.9s, Ch_3_labV12: 1.9s, Ch_4_labV12: 1.9s, Ch_5_labV12: 1.9s, ESP_VL_Radgeschw: 1.9s, ESP_VR_Radgeschw: 1.9s, Lat_CAN_Sig_13_: 1.9s, Long_CAN_Sig_12: 1.9s, NAWSPressure: 1.9s, NAWSSound: 1.9s, NAWSTemperature: 1.9s, a_x_CAN_Sig_4_: 1.9s, a_y_CAN_Sig_3_: 1.9s, a_z_CAN_Sig_5_: 1.9s, bUTC_CAN_Sig_24: 1.9s, mic_iso: 3.1s, v_east_CAN_Sig_: 1.9s, v_north_CAN_Sig: 1.9s, v_up_CAN_Sig_11: 1.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/01_ID.4/tyre1/track150_ID.4_tyre1_meas2_2p5_1_2025-08-07_11-26-06.h5
# Durations (s): BCM1_Aussen_Temp: 1.9s, Ch_1_labV12: 1.9s, Ch_2_labV12: 1.9s, Ch_3_labV12: 1.9s, Ch_4_labV12: 1.9s, Ch_5_labV12: 1.9s, ESP_VL_Radgeschw: 1.9s, ESP_VR_Radgeschw: 1.9s, Lat_CAN_Sig_13_: 1.9s, Long_CAN_Sig_12: 1.9s, NAWSPressure: 1.9s, NAWSSound: 1.9s, NAWSTemperature: 1.9s, a_x_CAN_Sig_4_: 1.9s, a_y_CAN_Sig_3_: 1.9s, a_z_CAN_Sig_5_: 1.9s, bUTC_CAN_Sig_24: 1.9s, mic_iso: 3.8s, v_east_CAN_Sig_: 1.9s, v_north_CAN_Sig: 1.9s, v_up_CAN_Sig_11: 1.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/01_ID.4/tyre1/track150_ID.4_tyre1_meas3_2p5_1_2025-08-07_11-27-11.h5
# Durations (s): BCM1_Aussen_Temp: 1.9s, Ch_1_labV12: 1.9s, Ch_2_labV12: 1.9s, Ch_3_labV12: 1.9s, Ch_4_labV12: 1.9s, Ch_5_labV12: 1.9s, ESP_VL_Radgeschw: 1.9s, ESP_VR_Radgeschw: 1.9s, Lat_CAN_Sig_13_: 1.9s, Long_CAN_Sig_12: 1.9s, NAWSPressure: 1.9s, NAWSSound: 1.9s, NAWSTemperature: 1.9s, a_x_CAN_Sig_4_: 1.9s, a_y_CAN_Sig_3_: 1.9s, a_z_CAN_Sig_5_: 1.9s, bUTC_CAN_Sig_24: 1.9s, mic_iso: 3.0s, v_east_CAN_Sig_: 1.9s, v_north_CAN_Sig: 1.9s, v_up_CAN_Sig_11: 1.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/01_ID.4/tyre1/track150_ID.4_tyre1_meas2_2p5_1_2025-08-07_11-24-13.h5
# Durations (s): BCM1_Aussen_Temp: 1.9s, Ch_1_labV12: 1.9s, Ch_2_labV12: 1.9s, Ch_3_labV12: 1.9s, Ch_4_labV12: 1.9s, Ch_5_labV12: 1.9s, ESP_VL_Radgeschw: 1.9s, ESP_VR_Radgeschw: 1.9s, Lat_CAN_Sig_13_: 1.9s, Long_CAN_Sig_12: 1.9s, NAWSPressure: 1.8s, NAWSSound: 1.8s, NAWSTemperature: 1.8s, a_x_CAN_Sig_4_: 1.9s, a_y_CAN_Sig_3_: 1.9s, a_z_CAN_Sig_5_: 1.9s, bUTC_CAN_Sig_24: 1.9s, mic_iso: 3.7s, v_east_CAN_Sig_: 1.9s, v_north_CAN_Sig: 1.9s, v_up_CAN_Sig_11: 1.9s,
# ----------------------------------------
# File: /Users/moritzfeik/Developer/ROAR/data_cleaned/track150/01_ID.4/tyre1/track150_ID.4_tyre1_meas3_2p5_1_2025-08-07_11-28-54.h5
# Durations (s): BCM1_Aussen_Temp: 1.6s, Ch_1_labV12: 1.6s, Ch_2_labV12: 1.6s, Ch_3_labV12: 1.6s, Ch_4_labV12: 1.6s, Ch_5_labV12: 1.6s, ESP_VL_Radgeschw: 1.6s, ESP_VR_Radgeschw: 1.6s, Lat_CAN_Sig_13_: 1.6s, Long_CAN_Sig_12: 1.6s, NAWSPressure: 1.6s, NAWSSound: 1.6s, NAWSTemperature: 1.6s, a_x_CAN_Sig_4_: 1.6s, a_y_CAN_Sig_3_: 1.6s, a_z_CAN_Sig_5_: 1.6s, bUTC_CAN_Sig_24: 1.6s, mic_iso: 3.3s, v_east_CAN_Sig_: 1.6s, v_north_CAN_Sig: 1.6s, v_up_CAN_Sig_11: 1.6s,
# ----------------------------------------

# %%
df = recording_lengths_1d.with_columns(
    pl.when(pl.col("variable_name") == "mic_iso")
    .then(pl.lit("mic_iso"))
    .otherwise(pl.lit("other_channels"))
    .alias("channel_type")
)

sns.boxplot(
    data=df.to_pandas(),
    x="channel_type",
    y="recording_duration_s",
    hue="track_ID",
    palette=TRACK_COLORS,
)
plt.title("Recording Duration Distribution", fontsize=14, fontweight="bold")
plt.ylabel("Duration (seconds)")
plt.xlabel("")
plt.savefig(
    ROOT_DIR / "plots" / "recording_duration_boxplot_by_channel_type.pdf",
    dpi=300,
    bbox_inches="tight",
)

# %%
fig = sns.displot(
    data=df.filter(pl.col("variable_name").is_in(["Ch_1_labV12", "mic_iso"])).to_pandas(),
    x="recording_duration_s",
    col="variable_name",
    hue="track_ID",
    palette=TRACK_COLORS,
    # stat="density",
    common_norm=False,
    facet_kws={"sharey": False},
)
plt.tight_layout()

sns.move_legend(
    fig,
    loc="upper right",
    title="Track ID",
    bbox_to_anchor=(0.98, 0.90),
    ncol=1,
    frameon=True,
    fontsize=12,
    title_fontsize=12,
)

for ax in fig.axes.flat:
    ax.set_xlabel(ax.get_xlabel(), fontsize=12)
    ax.set_ylabel(ax.get_ylabel(), fontsize=12)
    title = ax.get_title().split("= ")[-1]
    ax.set_title(title, fontsize=14)

fig.figure.suptitle("Recording Duration Distribution", fontsize=16, y=1.03)
plt.savefig(
    ROOT_DIR / "plots" / "recording_duration_distribution_by_channel_type.pdf",
    dpi=300,
    bbox_inches="tight",
)

# %%
# More statistics per channel type and track ID
df.group_by("channel_type", "track_ID").agg(
    pl.col("recording_duration_s").mean().alias("mean_recording_duration_s"),
    pl.col("recording_duration_s").std().alias("std_recording_duration_s"),
)
# Out:
# shape: (4, 4)
# ┌────────────────┬──────────┬───────────────────────────┬──────────────────────────┐
# │ channel_type   ┆ track_ID ┆ mean_recording_duration_s ┆ std_recording_duration_s │
# │ ---            ┆ ---      ┆ ---                       ┆ ---                      │
# │ str            ┆ i64      ┆ f64                       ┆ f64                      │
# ╞════════════════╪══════════╪═══════════════════════════╪══════════════════════════╡
# │ other_channels ┆ 211      ┆ 5.385028                  ┆ 2.20177                  │
# │ other_channels ┆ 150      ┆ 5.510658                  ┆ 3.879341                 │
# │ mic_iso        ┆ 150      ┆ 5.386203                  ┆ 2.067237                 │
# │ mic_iso        ┆ 211      ┆ 5.808878                  ┆ 1.283599                 │
# └────────────────┴──────────┴───────────────────────────┴──────────────────────────┘

# %%
# Plot histogram of recording durations (seconds) using seaborn (linear scale only)
fig = sns.displot(
    data=recording_lengths_1d.to_pandas(),
    x="recording_duration_s",
    col="vehicle",
    # Hue options
    hue="vehicle",
    multiple="stack",
    palette=VEHICLE_COLORS,
    col_order=ALL_VEHICLES,
    # hist options
    kind="hist",
    kde=False,
    bins=25,
    stat="percent",
)
fig.set_axis_labels("Recording Duration (s)", None)
plt.suptitle("Distribution of Recording Durations by Vehicle", y=1.02)
plt.savefig(ROOT_DIR / "plots" / "distribution_durations_per_vehicle.pdf", dpi=300)

# %%
fig = sns.displot(
    data=recording_lengths_1d.to_pandas(),
    x="recording_duration_s",
    col="vehicle",
    hue="tyre_ID",
    col_wrap=4,
    palette=TYRE_COLORS,
    kind="hist",
    kde=False,
    bins=25,
    multiple="stack",
    stat="percent",
    col_order=ALL_VEHICLES,
)
fig.set_axis_labels("Recording Duration (s)", None)
plt.suptitle("Distribution of Recording Durations by Vehicle and Tyre", y=1.02)
plt.savefig(ROOT_DIR / "plots" / "distribution_durations_per_vehicle_and_tyre.pdf", dpi=300)

# %%
fig = sns.displot(
    data=recording_lengths_1d.to_pandas(),
    x="recording_duration_s",
    col="track_ID",
    hue="vehicle",
    col_wrap=2,
    palette=VEHICLE_COLORS,
    kind="hist",
    kde=False,
    bins=25,
    multiple="stack",
    stat="percent",
)
fig.set_axis_labels("Recording Duration (s)", None)
plt.suptitle("Distribution of Recording Durations by Vehicle and Track")
plt.tight_layout()
# plt.savefig(ROOT_DIR / "plots" / "distribution_durations_per_vehicle_and_tyre.pdf", dpi=300)
