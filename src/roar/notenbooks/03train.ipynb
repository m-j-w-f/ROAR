# %% [markdown]
# ### Imports and constants

# %%
import h5py
import numpy as np
from scipy.signal import welch
import os
import glob
import re
from pathlib import Path
import pandas as pd
import librosa
from sklearn.model_selection import StratifiedKFold, LeaveOneGroupOut
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
MIC_CHANNELS = {
    "TrailK1": ["TrailK1", "Ch_1_labV12"],
    "TrailK2": ["TrailK2", "Ch_2_labV12"],
    "LeadK1":  ["LeadK1", "Ch_3_labV12"],
    "LeadK2":  ["LeadK2", "Ch_4_labV12"],
    "NAWSSound": ["NAWSSound"],
    "mic_iso": ["mic_iso"]
}

tracks = ["track150", "track211"]
cars = ["01_ID.4", "02_Q8 e-tron", "03_Taycan", "04_E-Golf"]
tyres = ["tyre1", "tyre3", "tyre6", "tyre10", "tyre12", "tyre13"]

experiment_mapping = {
    "track150": {
        "01_ID.4": ["tyre1"],
        "02_Q8 e-tron": ["tyre6", "tyre12"],
        "03_Taycan": ["tyre10"],
        "04_E-Golf": ["tyre13"]
    },
    "track211": {
        "01_ID.4": ["tyre1", "tyre3"],
        "02_Q8 e-tron": ["tyre6", "tyre12"],
        "03_Taycan": ["tyre10"],
        "04_E-Golf": ["tyre13"]
    }
}

# %% [markdown]
# ### Renaming the ikaISO files (track 259)

# %%
## Renaming helpers

def rename_h5_files(directory):
    pattern = re.compile(
        r"""
        ^(?P<prefix>b\d{2}_)?                # optional b##
        (?P<vehicle>ID4|Q8\ e-tron|Taycan|E-Golf)_
        (?P<tyre>[\w-]+)_
        (?P<test>ikaISO|ikaTP|ikaST)_
        (?P<amplitude>[^_]+)_
        (?P<speed>vr\d{2,3})_
        (?P<rest>.+\.h5)$
        """,
        re.VERBOSE
    )

    for path in Path(directory).glob("*.h5"):
        match = pattern.match(path.name)
        if not match:
            continue

        prefix = (match.group("prefix") or "").rstrip("_")
        parts = [
            match.group("test"),
            match.group("vehicle"),
            match.group("tyre"),
            match.group("amplitude"),
            match.group("speed"),
        ]
        if prefix:
            parts.append(prefix)

        parts.append(match.group("rest"))
        new_name = "_".join(parts)

        if new_name != path.name:
            new_path = path.with_name(new_name)
            print(f"Renaming {path.name} -> {new_name}")
            path.rename(new_path)

def retag_h5_files(directory):
    test_map = {"track150": "track211"}
    vehicle_map = {"ID.4": "ID.4"}
    tyre_map = {"tyre3": "tyre3"}
    pattern = re.compile(r"^(?P<test>[^_]+)_(?P<vehicle>[^_]+)_(?P<tyre>[^_]+)_(?P<rest>.+)$")

    for path in Path(directory).glob("*.h5"):
        match = pattern.match(path.name)
        if not match:
            continue

        test = test_map.get(match.group("test"), match.group("test"))
        vehicle = vehicle_map.get(match.group("vehicle"), match.group("vehicle"))
        tyre = tyre_map.get(match.group("tyre"), match.group("tyre"))

        new_name = f"{test}_{vehicle}_{tyre}_{match.group('rest')}"
        if new_name != path.name:
            print(f"Renaming {path.name} -> {new_name}")
            path.rename(path.with_name(new_name))

# %%
target_dir = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\259\01 VW ID4\02 UniRoyal RainSport5 - Tyre3"

rename_h5_files(target_dir)
# Out:
# Renaming ID4_RainSport5_ikaISO_2pt6_vr100_2025-07-11_10-32-06.h5 -> ikaISO_ID4_RainSport5_2pt6_vr100_2025-07-11_10-32-06.h5
# Renaming ID4_RainSport5_ikaISO_2pt6_vr100_2025-07-11_10-32-58.h5 -> ikaISO_ID4_RainSport5_2pt6_vr100_2025-07-11_10-32-58.h5
# Renaming ID4_RainSport5_ikaISO_2pt6_vr100_2025-07-11_10-33-49.h5 -> ikaISO_ID4_RainSport5_2pt6_vr100_2025-07-11_10-33-49.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-48-47.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-48-47.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-49-51.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-49-51.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-50-40.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-50-40.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-51-30.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-51-30.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-52-21.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-52-21.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_10-14-45.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_10-14-45.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_10-16-05.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_10-16-05.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_10-16-55.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_10-16-55.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_10-17-44.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_10-17-44.h5

# %%
target_dir = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\track211\01_ID.4\tyre3"

retag_h5_files(target_dir)
# Out:
# Renaming track150_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-06.h5 -> track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-06.h5
# Renaming track150_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-58.h5 -> track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-58.h5
# Renaming track150_ID.4_tyre3_2pt6_vr100_2025-07-11_10-33-49.h5 -> track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-33-49.h5
# Renaming track150_ID.4_tyre3_2pt6_vr45_2025-07-11_10-24-28.h5 -> track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-24-28.h5
# Renaming track150_ID.4_tyre3_2pt6_vr45_2025-07-11_10-25-31.h5 -> track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-25-31.h5
# Renaming track150_ID.4_tyre3_2pt6_vr45_2025-07-11_10-26-33.h5 -> track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-26-33.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_2025-07-11_10-35-11.h5 -> track211_ID.4_tyre3_2pt6_vr50_2025-07-11_10-35-11.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_2025-07-11_10-36-17.h5 -> track211_ID.4_tyre3_2pt6_vr50_2025-07-11_10-36-17.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-37-31.h5 -> track211_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-37-31.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-38-35.h5 -> track211_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-38-35.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-40-06.h5 -> track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-40-06.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-41-07.h5 -> track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-41-07.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-42-10.h5 -> track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-42-10.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-43-33.h5 -> track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-43-33.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-44-35.h5 -> track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-44-35.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-45-35.h5 -> track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-45-35.h5
# Renaming track150_ID.4_tyre3_2pt6_vr80_2025-07-11_10-27-40.h5 -> track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-27-40.h5
# Renaming track150_ID.4_tyre3_2pt6_vr80_2025-07-11_10-28-35.h5 -> track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-28-35.h5
# Renaming track150_ID.4_tyre3_2pt6_vr80_2025-07-11_10-29-30.h5 -> track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-29-30.h5
# Renaming track150_ID.4_tyre3_2pt6_vr80_2025-07-11_10-30-26.h5 -> track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-30-26.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-48-47.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-48-47.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-49-51.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-49-51.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-50-40.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-50-40.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-51-30.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-51-30.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-52-21.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-52-21.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_10-14-45.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-14-45.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-05.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-05.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-55.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-55.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_10-17-44.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-17-44.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_09-39-41.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-39-41.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_09-42-29.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-42-29.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_09-43-38.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-43-38.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_09-44-56.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-44-56.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_10-08-44.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-08-44.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_10-09-42.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-09-42.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_10-10-48.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-10-48.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-55-07.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-55-07.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-56-10.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-56-10.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-57-46.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-57-46.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-58-50.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-58-50.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-59-53.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-59-53.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-01-19.h5 -> track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-01-19.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-02-20.h5 -> track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-02-20.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-03-24.h5 -> track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-03-24.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-04-43.h5 -> track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-04-43.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-05-45.h5 -> track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-05-45.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-06-45.h5 -> track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-06-45.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-00.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-00.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-54.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-54.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_09-47-46.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_09-47-46.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_10-11-49.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_10-11-49.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_10-12-44.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_10-12-44.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_10-13-39.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_10-13-39.h5

# %% [markdown]
# ### NAMING INCONSISTENCY PROBLEMS

# %%
# File Naming suggests road type 150, metadata says 211

etron_testfilepath = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\data\data_original\02 Audi Q8\ikastandard\Tyre12\01_2025-08-15\track150_Q8 e-tron_tyre12_meas0_2p5_1_2025-08-15_13-06-24.h5"
etron_cleanedfilepath = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\track150\02_Q8 e-tron\tyre12\track150_Q8 e-tron_tyre12_meas0_2p5_1_2025-08-15_13-06-24.h5"
print("Original ETron file metadata:\n")
with h5py.File(etron_testfilepath, "r") as h5file:
    for meta_key in h5file.attrs.keys():
        print(f"{meta_key} = {h5file.attrs[meta_key]}")
print()
print("Cleaned ETron file metadata:\n")
with h5py.File(etron_cleanedfilepath, "r") as h5file:
    for meta_key in h5file.attrs.keys():
        print(f"{meta_key} = {h5file.attrs[meta_key]}")
# Out:
# Original ETron file metadata:
#
# CreationDate = 2025-08-15_13-06-24
# MeasCount = [1.]
# MeasName = Select Measurement
# MeasTypeID = [0.]
# Pressure = [2.5]
# TrackID = [211.]
# TrackName = ika Teststrecke
# TyreID = [12.]
# TyreName = R12 - Hankook Ventus S1 evo3 ev 255/50R20 109H
# carName = Q8 e-tron
#
# Cleaned ETron file metadata:
#
# CreationDate = 2025-08-15_13-06-24
# MeasCount = [1.]
# MeasName = Select Measurement
# MeasTypeID = [0.]
# Pressure = [2.5]
# TrackID = [211.]
# TrackName = ika Teststrecke
# TyreID = [12.]
# TyreName = R12 - Hankook Ventus S1 evo3 ev 255/50R20 109H
# carName = Q8 e-tron

# %%
# File Naming suggests road type 211, metadata says 150

ikaISO_testfilepath = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\data\data_original\01 VW ID4\01 ika ISO-Akustikstrecke track211\02 UniRoyal RainSport5 - Tyre3\b35_ID4_RainSport5_ikaISO_2pt6_vr50_2025-07-11_10-37-31.h5"
ikaISO_cleanedfilepath = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\track259\01_ID.4\tyre3\track259_ID.4_tyre3_2pt6_vr45_2025-07-11_10-24-28.h5"
print("Original IkaISO file metadata:\n")
with h5py.File(ikaISO_testfilepath, "r") as h5file:
    for meta_key in h5file.attrs.keys():
        print(f"{meta_key} = {h5file.attrs[meta_key]}")
print()
print("Cleaned IkaISO file metadata:\n")
with h5py.File(ikaISO_cleanedfilepath, "r") as h5file:
    for meta_key in h5file.attrs.keys():
        print(f"{meta_key} = {h5file.attrs[meta_key]}")
# Out:
# Original IkaISO file metadata:
#
# CreationDate = 2025-07-11_10-37-31
# MeasCount = [1.]
# MeasName = _Meas
# MeasTypeID = [0.]
# Pressure = ['2pt6']
# TrackID = [150.]
# TrackName = ['Road']
# TyreID = ['']
# TyreName = _UniRoyal RainSport5
# carName = ['Vehicle']
#
# Cleaned IkaISO file metadata:
#
# CreationDate = 2025-07-11_10-24-28
# MeasCount = [1.]
# MeasName = _Meas
# MeasTypeID = [0.]
# Pressure = ['2pt6']
# TrackID = [150.]
# TrackName = ['Road']
# TyreID = ['']
# TyreName = _UniRoyal RainSport5
# carName = ['Vehicle']

# %%
# List all test files and their metadata reveals mismatches

data_path = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data"
meta_keys = ["TrackID", "carName", "TyreID"]

test_paths = []

for track in tracks:
    for car in cars:
        for tyre in experiment_mapping.get(track, {}).get(car, []):
            if not tyre:
                continue
            test_path = os.path.join(data_path, track, car, tyre)
            test_paths.append(test_path)

for test_path in test_paths:
    print(f"[{test_path[len(data_path)+1:]}]\n")
    for testfilepath in os.listdir(test_path):
        if testfilepath.endswith(".h5"):
            full_testfilepath = os.path.join(test_path, testfilepath)
            with h5py.File(full_testfilepath, "r") as h5file:
                meta_values = []
                for meta_key in meta_keys:
                    meta_values.append(str(h5file.attrs.get(meta_key, "N/A")))
                print(", ".join(meta_values))
    print()
# Out:
# [track150\01_ID.4\tyre1]
#
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
#
# [track150\01_ID.4\tyre3]
#
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
#
# [track150\02_Q8 e-tron\tyre6]
#
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
#
# [track150\02_Q8 e-tron\tyre12]
#
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
#
# [track150\03_Taycan\tyre10]
#
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
#
# [track150\04_E-Golf\tyre13]
#
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
#
# [track211\01_ID.4\tyre1]
#
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
#
# [track211\02_Q8 e-tron\tyre6]
#
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
#
# [track211\02_Q8 e-tron\tyre12]
#
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
#
# [track211\03_Taycan\tyre10]
#
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
#
# [track211\04_E-Golf\tyre13]
#
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]

# %% [markdown]
# ### Single scalar audio feature extraction for baseline models and name parser

# %%
## Feature extraction helpers

def load_mic_signal(h5file, names):
    """Try all synonyms and return (signal, sample_rate) or (None, None)."""
    for n in names:
        if n in h5file:
            sig = h5file[n][:]
            fs = h5file[n].attrs.get("sample_rate", None)

            # sample_rate is sometimes an array, make it scalar float
            if fs is not None:
                fs = float(np.array(fs).ravel()[0])

            return sig, fs
    return None, None


# def extract_audio_features(signal, fs):
#     if signal is None or fs is None:
#         return {}

#     # Make sure signal is 1D float
#     x = np.asarray(signal, dtype=float).squeeze()
#     if x.ndim != 1 or x.size < 10:
#         # degenerate / empty channel
#         return {}

#     feats = {}

#     # --- Time-domain ---
#     feats["rms"] = float(np.sqrt(np.mean(x**2)))
#     feats["mean"] = float(np.mean(x))
#     feats["std"] = float(np.std(x))
#     feats["max"] = float(np.max(np.abs(x)))
#     feats["crest"] = float(feats["max"] / (feats["rms"] + 1e-9))

#     # zero-crossing rate
#     feats["zcr"] = float(((x[:-1] * x[1:]) < 0).mean())

#     # --- Frequency-domain using Welch PSD ---
#     f, psd = welch(x, fs, nperseg=min(4096, x.size))

#     # ensure 1D PSD
#     psd = np.asarray(psd).squeeze()
#     f = np.asarray(f).squeeze()

#     if f.ndim != 1 or psd.ndim != 1 or f.size != psd.size:
#         # something weird, bail out on frequency features
#         return feats

#     total_power = np.sum(psd) + 1e-9
#     feats["spec_centroid"] = float(np.sum(f * psd) / total_power)

#     # band powers
#     bands = [(0, 200), (200, 500), (500, 1000), (1000, 2000), (2000, 5000)]
#     for i, (lo, hi) in enumerate(bands):
#         mask = (f >= lo) & (f < hi)
#         if not np.any(mask):
#             feats[f"band_{i}"] = 0.0
#         else:
#             feats[f"band_{i}"] = float(np.sum(psd[mask]))

#     return feats

def extract_audio_features(signal, fs, n_mfcc=13, roll_percent=0.95):
    """
    Extract single-scalar audio features from a 1D signal.

    Time-domain:
        - rms, mean, std, max, crest, zcr

    Frequency-domain (Welch PSD):
        - spec_centroid
        - spec_rolloff (e.g. 95% of spectral energy)
        - spec_flatness (geometric mean / arithmetic mean of PSD)
        - spec_bandwidth (spectral spread around centroid)
        - band_i (absolute band powers over fixed frequency ranges)

    MFCC (if librosa is available):
        - mfcc_1 ... mfcc_n_mfcc (mean over time for each coefficient)
    """
    if signal is None or fs is None:
        return {}

    # Make sure signal is 1D float
    x = np.asarray(signal, dtype=float).squeeze()
    if x.ndim != 1 or x.size < 10:
        # degenerate / empty channel
        return {}

    feats = {}

    # --- Time-domain ---
    feats["rms"] = float(np.sqrt(np.mean(x**2)))
    feats["mean"] = float(np.mean(x))
    feats["std"] = float(np.std(x))
    feats["max"] = float(np.max(np.abs(x)))
    feats["crest"] = float(feats["max"] / (feats["rms"] + 1e-9))

    # zero-crossing rate
    feats["zcr"] = float(((x[:-1] * x[1:]) < 0).mean())

    # --- Frequency-domain using Welch PSD ---
    f, psd = welch(x, fs, nperseg=min(4096, x.size))

    # ensure 1D PSD
    psd = np.asarray(psd).squeeze()
    f = np.asarray(f).squeeze()

    if f.ndim != 1 or psd.ndim != 1 or f.size != psd.size:
        # something weird, bail out on frequency features
        return feats

    total_power = np.sum(psd) + 1e-9

    # Spectral centroid (power-weighted mean frequency)
    spec_centroid = np.sum(f * psd) / total_power
    feats["spec_centroid"] = float(spec_centroid)

    # --- NEW: Spectral rolloff ---
    # Frequency below which `roll_percent` of total spectral energy lies.
    # Common choice: roll_percent = 0.95
    cumulative_power = np.cumsum(psd)
    threshold = roll_percent * cumulative_power[-1]
    idx = np.searchsorted(cumulative_power, threshold)
    idx = min(idx, len(f) - 1)
    feats["spec_rolloff"] = float(f[idx])

    # --- NEW: Spectral flatness ---
    # Ratio of geometric mean to arithmetic mean of PSD.
    # ~1 → noise-like, <<1 → tone-like.
    psd_safe = psd + 1e-12  # avoid log(0) / division by zero
    geo_mean = float(np.exp(np.mean(np.log(psd_safe))))
    arith_mean = float(np.mean(psd_safe))
    feats["spec_flatness"] = float(geo_mean / (arith_mean + 1e-12))

    # --- NEW: Spectral bandwidth (spread around centroid) ---
    # Here: standard deviation of frequency around centroid, weighted by PSD.
    feats["spec_bandwidth"] = float(
        np.sqrt(np.sum(((f - spec_centroid) ** 2) * psd) / total_power)
    )

    # --- Band powers (already present, kept as-is) ---
    bands = [(0, 200), (200, 500), (500, 1000), (1000, 2000), (2000, 5000)]
    for i, (lo, hi) in enumerate(bands):
        mask = (f >= lo) & (f < hi)
        if not np.any(mask):
            feats[f"band_{i}"] = 0.0
        else:
            feats[f"band_{i}"] = float(np.sum(psd[mask]))

    # --- NEW: MFCC features (single scalars per coefficient) ---
    # We use librosa if available. Each coefficient is averaged over time.
    # librosa expects float32 and mono; x is already 1D float64
    mfcc = librosa.feature.mfcc(
        y=x.astype(np.float32),
        sr=fs,
        n_mfcc=n_mfcc
    )  # shape: (n_mfcc, n_frames)

    mfcc_means = mfcc.mean(axis=1)  # mean over time for each coeff
    for i, coeff in enumerate(mfcc_means, start=1):
        feats[f"mfcc_{i}"] = float(coeff)

    return feats



def extract_features_from_h5(path):
    with h5py.File(path, "r") as f:
        all_feats = {}

        for mic_name, synonyms in MIC_CHANNELS.items():
            sig, fs = load_mic_signal(f, synonyms)
            feats = extract_audio_features(sig, fs)

            for k, v in feats.items():
                all_feats[f"{mic_name}_{k}"] = v

        return all_feats

# %%
# Test feature extraction

features = extract_features_from_h5(r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\track211\02_Q8 e-tron\tyre12\track211_Q8 e-tron_tyre12_meas1_2p5_1_2025-08-15_11-46-48.h5")
for feature in features.keys():
    print(f"{feature}: {features[feature]}")
print(len(features))
# Out:
# TrailK1_rms: 1.9825720167974183
# TrailK1_mean: -7.507651404992822e-05
# TrailK1_std: 1.9825720153759108
# TrailK1_max: 8.968762397766113
# TrailK1_crest: 4.523801565468555
# TrailK1_zcr: 0.008376712625777952
# TrailK1_spec_centroid: 76.32497673989455
# TrailK1_spec_rolloff: 445.31249999999926
# TrailK1_spec_flatness: 3.621808391661969e-05
# TrailK1_spec_bandwidth: 205.7811301947801
# TrailK1_band_0: 0.26112378989874435
# TrailK1_band_1: 0.007389678246942566
# TrailK1_band_2: 0.009410983385702936
# TrailK1_band_3: 0.0033581412924817682
# TrailK1_band_4: 0.00013030426464310808
# TrailK1_mfcc_1: -26.38875389099121
# TrailK1_mfcc_2: 213.49420166015625
# TrailK1_mfcc_3: 20.737586975097656
# TrailK1_mfcc_4: -15.789554595947266
# TrailK1_mfcc_5: 2.5844292640686035
# TrailK1_mfcc_6: 1.983687162399292
# TrailK1_mfcc_7: 7.0902509689331055
# TrailK1_mfcc_8: 9.382965087890625
# TrailK1_mfcc_9: 6.579596519470215
# TrailK1_mfcc_10: 5.388495922088623
# TrailK1_mfcc_11: 3.723315715789795
# TrailK1_mfcc_12: 9.787144660949707
# TrailK1_mfcc_13: 10.762883186340332
# TrailK2_rms: 1.9467883905979049
# TrailK2_mean: 0.0003081211155831302
# TrailK2_std: 1.9467883662145096
# TrailK2_max: 9.150646209716797
# TrailK2_crest: 4.700380508333541
# TrailK2_zcr: 0.008842399778280125
# TrailK2_spec_centroid: 80.9199064871507
# TrailK2_spec_rolloff: 515.6249999999991
# TrailK2_spec_flatness: 4.019228692187646e-05
# TrailK2_spec_bandwidth: 215.9146785538445
# TrailK2_band_0: 0.2453080475099907
# TrailK2_band_1: 0.007004764478283981
# TrailK2_band_2: 0.00971479799788268
# TrailK2_band_3: 0.0036148711630344765
# TrailK2_band_4: 0.00013902888249632436
# TrailK2_mfcc_1: -27.638397216796875
# TrailK2_mfcc_2: 215.28260803222656
# TrailK2_mfcc_3: 21.4366397857666
# TrailK2_mfcc_4: -20.27928924560547
# TrailK2_mfcc_5: 3.4920334815979004
# TrailK2_mfcc_6: 3.536736488342285
# TrailK2_mfcc_7: 4.022161960601807
# TrailK2_mfcc_8: 11.546143531799316
# TrailK2_mfcc_9: 7.766989707946777
# TrailK2_mfcc_10: 1.0631864070892334
# TrailK2_mfcc_11: 7.041388988494873
# TrailK2_mfcc_12: 12.859000205993652
# TrailK2_mfcc_13: 5.201572418212891
# LeadK1_rms: 1.9063343049544212
# LeadK1_mean: -0.002668439659196499
# LeadK1_std: 1.9063324373455541
# LeadK1_max: 10.62474536895752
# LeadK1_crest: 5.573390425683053
# LeadK1_zcr: 0.009526790208880484
# LeadK1_spec_centroid: 88.53395053352395
# LeadK1_spec_rolloff: 597.656249999999
# LeadK1_spec_flatness: 4.8681218777821024e-05
# LeadK1_spec_bandwidth: 222.51402911239077
# LeadK1_band_0: 0.23344781266277206
# LeadK1_band_1: 0.011245043776834475
# LeadK1_band_2: 0.011901159882475677
# LeadK1_band_3: 0.0030115448001825436
# LeadK1_band_4: 0.00014116944391270365
# LeadK1_mfcc_1: -17.763721466064453
# LeadK1_mfcc_2: 208.8040313720703
# LeadK1_mfcc_3: 26.383832931518555
# LeadK1_mfcc_4: -14.750289916992188
# LeadK1_mfcc_5: 3.0117084980010986
# LeadK1_mfcc_6: 5.206258296966553
# LeadK1_mfcc_7: 6.723231792449951
# LeadK1_mfcc_8: 3.412184238433838
# LeadK1_mfcc_9: 0.4339500069618225
# LeadK1_mfcc_10: 2.7570536136627197
# LeadK1_mfcc_11: 3.3805463314056396
# LeadK1_mfcc_12: 10.434342384338379
# LeadK1_mfcc_13: 11.367572784423828
# LeadK2_rms: 1.9371058689307883
# LeadK2_mean: -0.0026731226056299342
# LeadK2_std: 1.937104024532921
# LeadK2_max: 10.732621192932129
# LeadK2_crest: 5.540544458375731
# LeadK2_zcr: 0.00945703140465951
# LeadK2_spec_centroid: 87.94079867586645
# LeadK2_spec_rolloff: 609.374999999999
# LeadK2_spec_flatness: 5.23120608525701e-05
# LeadK2_spec_bandwidth: 223.6971901561261
# LeadK2_band_0: 0.2445816646309081
# LeadK2_band_1: 0.010696672045568985
# LeadK2_band_2: 0.012452697669297038
# LeadK2_band_3: 0.003256617340691732
# LeadK2_band_4: 0.00015306342295107515
# LeadK2_mfcc_1: -18.546117782592773
# LeadK2_mfcc_2: 211.11131286621094
# LeadK2_mfcc_3: 26.655797958374023
# LeadK2_mfcc_4: -18.97373390197754
# LeadK2_mfcc_5: 5.228600978851318
# LeadK2_mfcc_6: 5.840327262878418
# LeadK2_mfcc_7: 1.9448089599609375
# LeadK2_mfcc_8: 7.80372428894043
# LeadK2_mfcc_9: 2.639878511428833
# LeadK2_mfcc_10: -3.6002185344696045
# LeadK2_mfcc_11: 7.627304553985596
# LeadK2_mfcc_12: 14.414793968200684
# LeadK2_mfcc_13: 4.908548355102539
# NAWSSound_rms: 40.626136586431215
# NAWSSound_mean: 0.5078386721357093
# NAWSSound_std: 40.622962395946075
# NAWSSound_max: 484.10152837346885
# NAWSSound_crest: 11.916011933146473
# NAWSSound_zcr: 0.013955192302777123
# NAWSSound_spec_centroid: 62.05973944615825
# NAWSSound_spec_rolloff: 195.3125
# NAWSSound_spec_flatness: 0.0006443271671135279
# NAWSSound_spec_bandwidth: 192.41284803239398
# NAWSSound_band_0: 217.41954790477556
# NAWSSound_band_1: 5.897033499315805
# NAWSSound_band_2: 2.924687754355567
# NAWSSound_band_3: 1.2089704374712587
# NAWSSound_band_4: 0.08538429513942536
# NAWSSound_mfcc_1: 289.68536376953125
# NAWSSound_mfcc_2: 163.6353302001953
# NAWSSound_mfcc_3: 31.034826278686523
# NAWSSound_mfcc_4: -13.15053939819336
# NAWSSound_mfcc_5: 11.55073356628418
# NAWSSound_mfcc_6: 27.787843704223633
# NAWSSound_mfcc_7: 12.580154418945312
# NAWSSound_mfcc_8: -2.9258360862731934
# NAWSSound_mfcc_9: 0.8906653523445129
# NAWSSound_mfcc_10: 12.2007417678833
# NAWSSound_mfcc_11: 12.40893840789795
# NAWSSound_mfcc_12: 1.5914157629013062
# NAWSSound_mfcc_13: -6.233059883117676
# mic_iso_rms: 0.0519708218749731
# mic_iso_mean: -0.00017169532403472971
# mic_iso_std: 0.051970538260401794
# mic_iso_max: 0.24461996840709999
# mic_iso_crest: 4.706871180307949
# mic_iso_zcr: 0.02377951067411986
# mic_iso_spec_centroid: 602.6251764211765
# mic_iso_spec_rolloff: 1582.03125253125
# mic_iso_spec_flatness: 0.0009222255491812177
# mic_iso_spec_bandwidth: 600.4520120223549
# mic_iso_band_0: 4.0079790283768785e-05
# mic_iso_band_1: 1.0084637025723936e-05
# mic_iso_band_2: 3.71970987565494e-05
# mic_iso_band_3: 1.9897179900935697e-05
# mic_iso_band_4: 2.15007634072227e-06
# mic_iso_mfcc_1: -307.54595947265625
# mic_iso_mfcc_2: 214.69635009765625
# mic_iso_mfcc_3: -28.779455184936523
# mic_iso_mfcc_4: -7.333923816680908
# mic_iso_mfcc_5: -12.927000999450684
# mic_iso_mfcc_6: 4.4120192527771
# mic_iso_mfcc_7: 3.8807783126831055
# mic_iso_mfcc_8: 1.8926771879196167
# mic_iso_mfcc_9: 8.542153358459473
# mic_iso_mfcc_10: 4.145444393157959
# mic_iso_mfcc_11: 5.436092376708984
# mic_iso_mfcc_12: 10.195422172546387
# mic_iso_mfcc_13: 8.724066734313965
# 168

# %%
# Filename metadata parsing (track type, car id, tyre id)

def parse_metadata_from_filename(path):
    fname = os.path.basename(path)
    stem = os.path.splitext(fname)[0]  # remove ".h5"

    # Example: track211_E-Golf_tyre13_meas1_2p5_1_2025-09-26_14-48-57
    m = re.match(r"track(\d+)_(.+?)_tyre(\d+)_", stem)
    if not m:
        # fallback: return minimal info if pattern doesn't match
        print(f"Could not parse metadata from filename because pattern did not match: {fname}")
        return {
            "road_type": None,
            "car_id": None,
            "tyre_id": None,
            "filename": fname,
        }

    road_type = m.group(1)        # 150 or 211
    car_name = m.group(2)         # e.g. "E-Golf" or "VW Golf Variant"
    tyre_id = m.group(3)          # e.g. "13"

    return {
        "road_type": road_type,
        "car_id": car_name,
        "tyre_id": tyre_id,
        "filename": fname,
    }

# %% [markdown]
# ### Build the initial dataset

# %%
# Get the h5 file paths
DATA_ROOT = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data"

h5_paths = glob.glob(os.path.join(DATA_ROOT, "**", "*.h5"), recursive=True)
print(f"Found {len(h5_paths)} files")

rows = []

for path in h5_paths:
    try:
        feat_dict = extract_features_from_h5(path)
        if not feat_dict:
            print(f"No usable mic data in {path}, skipping.")
            continue  # no usable mic data

        meta = parse_metadata_from_filename(path)

        row = {
            **feat_dict,
            **meta,
            "filepath": path,
        }
        rows.append(row)

    except Exception as e:
        print(f"Error processing {path}: {e}")

df = pd.DataFrame(rows)
print(df.shape)
df.head()
# Out:
# Found 204 files
# (204, 173)
#    TrailK1_rms  TrailK1_mean  TrailK1_std  TrailK1_max  TrailK1_crest  \
# 0     1.237135      0.014010     1.237055     9.396573       7.595433
# 1     1.261951      0.015262     1.261859     6.910773       5.476261
# 2     1.570797      0.026359     1.570576     9.626661       6.128520
# 3     4.930482     -0.095541     4.929557    27.651320       5.608238
# 4     4.625517      0.033804     4.625393    30.330170       6.557142
#
#    TrailK1_zcr  TrailK1_spec_centroid  TrailK1_spec_rolloff  \
# 0     0.015142             208.052350             949.21875
# 1     0.015054             181.074575             914.06250
# 2     0.012861             129.853970             808.59375
# 3     0.010237              92.329721             738.28125
# 4     0.012252             104.023525             785.15625
#
#    TrailK1_spec_flatness  TrailK1_spec_bandwidth  ...  mic_iso_mfcc_9  \
# 0               0.000157              357.254596  ...        8.019507
# 1               0.000119              338.288246  ...        5.190659
# 2               0.000072              285.697787  ...        3.687949
# 3               0.000049              252.684620  ...        7.476211
# 4               0.000069              274.546315  ...        7.616546
#
#    mic_iso_mfcc_10  mic_iso_mfcc_11  mic_iso_mfcc_12  mic_iso_mfcc_13  \
# 0         3.718992         5.368348         6.144391         1.221954
# 1         5.405526         2.371301         8.211204        -0.281236
# 2         4.325697         1.898233         7.558691        -1.297250
# 3         3.614376         6.377722         7.380404         4.932734
# 4         3.679830         6.844580         7.089043         4.531528
#
#    road_type  car_id  tyre_id  \
# 0        150    ID.4        1
# 1        150    ID.4        1
# 2        150    ID.4        1
# 3        150    ID.4        1
# 4        150    ID.4        1
#
#                                             filename  \
# 0  track150_ID.4_tyre1_meas1_2p5_1_2025-08-07_11-...
# 1  track150_ID.4_tyre1_meas1_2p5_1_2025-08-07_11-...
# 2  track150_ID.4_tyre1_meas1_2p5_1_2025-08-07_11-...
# 3  track150_ID.4_tyre1_meas2_2p5_1_2025-08-07_11-...
# 4  track150_ID.4_tyre1_meas2_2p5_1_2025-08-07_11-...
#
#                                             filepath
# 0  C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Se...
# 1  C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Se...
# 2  C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Se...
# 3  C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Se...
# 4  C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Se...
#
# [5 rows x 173 columns]

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 173 columns):
#  #    Column                    Non-Null Count  Dtype
# ---   ------                    --------------  -----
#  0    TrailK1_rms               204 non-null    float64
#  1    TrailK1_mean              204 non-null    float64
#  2    TrailK1_std               204 non-null    float64
#  3    TrailK1_max               204 non-null    float64
#  4    TrailK1_crest             204 non-null    float64
#  5    TrailK1_zcr               204 non-null    float64
#  6    TrailK1_spec_centroid     204 non-null    float64
#  7    TrailK1_spec_rolloff      204 non-null    float64
#  8    TrailK1_spec_flatness     204 non-null    float64
#  9    TrailK1_spec_bandwidth    204 non-null    float64
#  10   TrailK1_band_0            204 non-null    float64
#  11   TrailK1_band_1            204 non-null    float64
#  12   TrailK1_band_2            204 non-null    float64
#  13   TrailK1_band_3            204 non-null    float64
#  14   TrailK1_band_4            204 non-null    float64
#  15   TrailK1_mfcc_1            204 non-null    float64
#  16   TrailK1_mfcc_2            204 non-null    float64
#  17   TrailK1_mfcc_3            204 non-null    float64
#  18   TrailK1_mfcc_4            204 non-null    float64
#  19   TrailK1_mfcc_5            204 non-null    float64
#  20   TrailK1_mfcc_6            204 non-null    float64
#  21   TrailK1_mfcc_7            204 non-null    float64
#  22   TrailK1_mfcc_8            204 non-null    float64
#  23   TrailK1_mfcc_9            204 non-null    float64
#  24   TrailK1_mfcc_10           204 non-null    float64
#  25   TrailK1_mfcc_11           204 non-null    float64
#  26   TrailK1_mfcc_12           204 non-null    float64
#  27   TrailK1_mfcc_13           204 non-null    float64
#  28   TrailK2_rms               204 non-null    float64
#  29   TrailK2_mean              204 non-null    float64
#  30   TrailK2_std               204 non-null    float64
#  31   TrailK2_max               204 non-null    float64
#  32   TrailK2_crest             204 non-null    float64
#  33   TrailK2_zcr               204 non-null    float64
#  34   TrailK2_spec_centroid     204 non-null    float64
#  35   TrailK2_spec_rolloff      204 non-null    float64
#  36   TrailK2_spec_flatness     204 non-null    float64
#  37   TrailK2_spec_bandwidth    204 non-null    float64
#  38   TrailK2_band_0            204 non-null    float64
#  39   TrailK2_band_1            204 non-null    float64
#  40   TrailK2_band_2            204 non-null    float64
#  41   TrailK2_band_3            204 non-null    float64
#  42   TrailK2_band_4            204 non-null    float64
#  43   TrailK2_mfcc_1            204 non-null    float64
#  44   TrailK2_mfcc_2            204 non-null    float64
#  45   TrailK2_mfcc_3            204 non-null    float64
#  46   TrailK2_mfcc_4            204 non-null    float64
#  47   TrailK2_mfcc_5            204 non-null    float64
#  48   TrailK2_mfcc_6            204 non-null    float64
#  49   TrailK2_mfcc_7            204 non-null    float64
#  50   TrailK2_mfcc_8            204 non-null    float64
#  51   TrailK2_mfcc_9            204 non-null    float64
#  52   TrailK2_mfcc_10           204 non-null    float64
#  53   TrailK2_mfcc_11           204 non-null    float64
#  54   TrailK2_mfcc_12           204 non-null    float64
#  55   TrailK2_mfcc_13           204 non-null    float64
#  56   LeadK1_rms                204 non-null    float64
#  57   LeadK1_mean               204 non-null    float64
#  58   LeadK1_std                204 non-null    float64
#  59   LeadK1_max                204 non-null    float64
#  60   LeadK1_crest              204 non-null    float64
#  61   LeadK1_zcr                204 non-null    float64
#  62   LeadK1_spec_centroid      204 non-null    float64
#  63   LeadK1_spec_rolloff       204 non-null    float64
#  64   LeadK1_spec_flatness      204 non-null    float64
#  65   LeadK1_spec_bandwidth     204 non-null    float64
#  66   LeadK1_band_0             204 non-null    float64
#  67   LeadK1_band_1             204 non-null    float64
#  68   LeadK1_band_2             204 non-null    float64
#  69   LeadK1_band_3             204 non-null    float64
#  70   LeadK1_band_4             204 non-null    float64
#  71   LeadK1_mfcc_1             204 non-null    float64
#  72   LeadK1_mfcc_2             204 non-null    float64
#  73   LeadK1_mfcc_3             204 non-null    float64
#  74   LeadK1_mfcc_4             204 non-null    float64
#  75   LeadK1_mfcc_5             204 non-null    float64
#  76   LeadK1_mfcc_6             204 non-null    float64
#  77   LeadK1_mfcc_7             204 non-null    float64
#  78   LeadK1_mfcc_8             204 non-null    float64
#  79   LeadK1_mfcc_9             204 non-null    float64
#  80   LeadK1_mfcc_10            204 non-null    float64
#  81   LeadK1_mfcc_11            204 non-null    float64
#  82   LeadK1_mfcc_12            204 non-null    float64
#  83   LeadK1_mfcc_13            204 non-null    float64
#  84   LeadK2_rms                204 non-null    float64
#  85   LeadK2_mean               204 non-null    float64
#  86   LeadK2_std                204 non-null    float64
#  87   LeadK2_max                204 non-null    float64
#  88   LeadK2_crest              204 non-null    float64
#  89   LeadK2_zcr                204 non-null    float64
#  90   LeadK2_spec_centroid      204 non-null    float64
#  91   LeadK2_spec_rolloff       204 non-null    float64
#  92   LeadK2_spec_flatness      204 non-null    float64
#  93   LeadK2_spec_bandwidth     204 non-null    float64
#  94   LeadK2_band_0             204 non-null    float64
#  95   LeadK2_band_1             204 non-null    float64
#  96   LeadK2_band_2             204 non-null    float64
#  97   LeadK2_band_3             204 non-null    float64
#  98   LeadK2_band_4             204 non-null    float64
#  99   LeadK2_mfcc_1             204 non-null    float64
#  100  LeadK2_mfcc_2             204 non-null    float64
#  101  LeadK2_mfcc_3             204 non-null    float64
#  102  LeadK2_mfcc_4             204 non-null    float64
#  103  LeadK2_mfcc_5             204 non-null    float64
#  104  LeadK2_mfcc_6             204 non-null    float64
#  105  LeadK2_mfcc_7             204 non-null    float64
#  106  LeadK2_mfcc_8             204 non-null    float64
#  107  LeadK2_mfcc_9             204 non-null    float64
#  108  LeadK2_mfcc_10            204 non-null    float64
#  109  LeadK2_mfcc_11            204 non-null    float64
#  110  LeadK2_mfcc_12            204 non-null    float64
#  111  LeadK2_mfcc_13            204 non-null    float64
#  112  NAWSSound_rms             199 non-null    float64
#  113  NAWSSound_mean            199 non-null    float64
#  114  NAWSSound_std             199 non-null    float64
#  115  NAWSSound_max             199 non-null    float64
#  116  NAWSSound_crest           199 non-null    float64
#  117  NAWSSound_zcr             199 non-null    float64
#  118  NAWSSound_spec_centroid   199 non-null    float64
#  119  NAWSSound_spec_rolloff    199 non-null    float64
#  120  NAWSSound_spec_flatness   199 non-null    float64
#  121  NAWSSound_spec_bandwidth  199 non-null    float64
#  122  NAWSSound_band_0          199 non-null    float64
#  123  NAWSSound_band_1          199 non-null    float64
#  124  NAWSSound_band_2          199 non-null    float64
#  125  NAWSSound_band_3          199 non-null    float64
#  126  NAWSSound_band_4          199 non-null    float64
#  127  NAWSSound_mfcc_1          199 non-null    float64
#  128  NAWSSound_mfcc_2          199 non-null    float64
#  129  NAWSSound_mfcc_3          199 non-null    float64
#  130  NAWSSound_mfcc_4          199 non-null    float64
#  131  NAWSSound_mfcc_5          199 non-null    float64
#  132  NAWSSound_mfcc_6          199 non-null    float64
#  133  NAWSSound_mfcc_7          199 non-null    float64
#  134  NAWSSound_mfcc_8          199 non-null    float64
#  135  NAWSSound_mfcc_9          199 non-null    float64
#  136  NAWSSound_mfcc_10         199 non-null    float64
#  137  NAWSSound_mfcc_11         199 non-null    float64
#  138  NAWSSound_mfcc_12         199 non-null    float64
#  139  NAWSSound_mfcc_13         199 non-null    float64
#  140  mic_iso_rms               151 non-null    float64
#  141  mic_iso_mean              151 non-null    float64
#  142  mic_iso_std               151 non-null    float64
#  143  mic_iso_max               151 non-null    float64
#  144  mic_iso_crest             151 non-null    float64
#  145  mic_iso_zcr               151 non-null    float64
#  146  mic_iso_spec_centroid     151 non-null    float64
#  147  mic_iso_spec_rolloff      151 non-null    float64
#  148  mic_iso_spec_flatness     151 non-null    float64
#  149  mic_iso_spec_bandwidth    151 non-null    float64
#  150  mic_iso_band_0            151 non-null    float64
#  151  mic_iso_band_1            151 non-null    float64
#  152  mic_iso_band_2            151 non-null    float64
#  153  mic_iso_band_3            151 non-null    float64
#  154  mic_iso_band_4            151 non-null    float64
#  155  mic_iso_mfcc_1            151 non-null    float64
#  156  mic_iso_mfcc_2            151 non-null    float64
#  157  mic_iso_mfcc_3            151 non-null    float64
#  158  mic_iso_mfcc_4            151 non-null    float64
#  159  mic_iso_mfcc_5            151 non-null    float64
#  160  mic_iso_mfcc_6            151 non-null    float64
#  161  mic_iso_mfcc_7            151 non-null    float64
#  162  mic_iso_mfcc_8            151 non-null    float64
#  163  mic_iso_mfcc_9            151 non-null    float64
#  164  mic_iso_mfcc_10           151 non-null    float64
#  165  mic_iso_mfcc_11           151 non-null    float64
#  166  mic_iso_mfcc_12           151 non-null    float64
#  167  mic_iso_mfcc_13           151 non-null    float64
#  168  road_type                 204 non-null    object
#  169  car_id                    204 non-null    object
#  170  tyre_id                   204 non-null    object
#  171  filename                  204 non-null    object
#  172  filepath                  204 non-null    object
# dtypes: float64(168), object(5)
# memory usage: 275.8+ KB

# %% [markdown]
# ### Missing values

# %% [markdown]
# mic_iso channels 151/204 non-null

# %% [markdown]
# track211 ID.4 tyre3 is missing mic iso, contains however "MikrofonOst" & "MikrofonWest" with similar sample rates
# (btw regular files also contain a "mic_2m" additionally to "mic_iso")

# %%
# Get the filenames of all files with empty mic_iso data from the dataframe

missing_iso_paths = df[df["mic_iso_rms"].isna()]["filepath"].tolist()
print(f"Files with missing mic_iso data: {len(missing_iso_paths)}")
for path in missing_iso_paths:
    print(os.path.basename(path))
# Out:
# Files with missing mic_iso data: 53
# track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-06.h5
# track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-58.h5
# track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-33-49.h5
# track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-24-28.h5
# track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-25-31.h5
# track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-26-33.h5
# track211_ID.4_tyre3_2pt6_vr50_2025-07-11_10-35-11.h5
# track211_ID.4_tyre3_2pt6_vr50_2025-07-11_10-36-17.h5
# track211_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-37-31.h5
# track211_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-38-35.h5
# track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-40-06.h5
# track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-41-07.h5
# track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-42-10.h5
# track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-43-33.h5
# track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-44-35.h5
# track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-45-35.h5
# track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-27-40.h5
# track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-28-35.h5
# track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-29-30.h5
# track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-30-26.h5
# track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-48-47.h5
# track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-49-51.h5
# track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-50-40.h5
# track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-51-30.h5
# track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-52-21.h5
# track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-14-45.h5
# track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-05.h5
# track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-55.h5
# track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-17-44.h5
# track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-39-41.h5
# track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-42-29.h5
# track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-43-38.h5
# track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-44-56.h5
# track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-08-44.h5
# track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-09-42.h5
# track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-10-48.h5
# track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-55-07.h5
# track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-56-10.h5
# track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-57-46.h5
# track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-58-50.h5
# track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-59-53.h5
# track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-01-19.h5
# track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-02-20.h5
# track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-03-24.h5
# track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-04-43.h5
# track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-05-45.h5
# track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-06-45.h5
# track211_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-00.h5
# track211_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-54.h5
# track211_ID.4_tyre3_3pt1_vr80_2025-07-11_09-47-46.h5
# track211_ID.4_tyre3_3pt1_vr80_2025-07-11_10-11-49.h5
# track211_ID.4_tyre3_3pt1_vr80_2025-07-11_10-12-44.h5
# track211_ID.4_tyre3_3pt1_vr80_2025-07-11_10-13-39.h5

# %%
# Sanity check if the channel is actually missing

test_path = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\track211\01_ID.4\tyre3\track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-24-28.h5"
with h5py.File(test_path, "r") as h5file:
    for key in h5file.keys():
        print(f"{key}: {h5file[key].shape}, attrs: {h5file[key].attrs}")
# Out:
# Antrieb: (1, 183600), attrs: <Attributes of HDF5 object at 1967750648816>
# BCM1_Aussen_Temp: (1, 5100), attrs: <Attributes of HDF5 object at 1968096652848>
# Cnt_CAN_Sig_0_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_12_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_16_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_18_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_20_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_22_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_24_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_26_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_28_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_32_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_36_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_4_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Cnt_CAN_Sig_8_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# EM1_IstMoment_C: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# EM1_Raddrehzahl_: (1, 5100), attrs: <Attributes of HDF5 object at 1968096652848>
# ESC_Allrad_Antei: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# ESP_Gierrate_CA: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# ESP_HL_Bremsmome: (1, 5100), attrs: <Attributes of HDF5 object at 1968096641568>
# ESP_HR_Bremsmome: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# ESP_VL_Bremsmome: (1, 5100), attrs: <Attributes of HDF5 object at 1968096650048>
# ESP_VL_Radgeschw: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# ESP_VR_Bremsmome: (1, 5100), attrs: <Attributes of HDF5 object at 1968096641568>
# ESP_VR_Radgeschw: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# ESP_VZ_Gierrate: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# ESP_Vorsteuerung: (1, 5100), attrs: <Attributes of HDF5 object at 1968096652848>
# ESP_v_Signal_CA: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Fahrwerk: (1, 183600), attrs: <Attributes of HDF5 object at 1967750648816>
# GPS: (1, 344064), attrs: <Attributes of HDF5 object at 1967750648816>
# IMA: (1, 183600), attrs: <Attributes of HDF5 object at 1967750648816>
# IREnd: (3, 80, 80), attrs: <Attributes of HDF5 object at 1967750648816>
# IRStart: (3, 80, 80), attrs: <Attributes of HDF5 object at 1967750648816>
# LWI_Lenkradwinke: (1, 5100), attrs: <Attributes of HDF5 object at 1968096652848>
# Lat_CAN_Sig_25_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# LeadK1: (1, 244800), attrs: <Attributes of HDF5 object at 1967750648816>
# LeadK2: (1, 244800), attrs: <Attributes of HDF5 object at 1967750648816>
# Long_CAN_Sig_23: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# MO_Gangposition: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# MikrofonOst: (1, 344064), attrs: <Attributes of HDF5 object at 1967750648816>
# MikrofonWest: (1, 344064), attrs: <Attributes of HDF5 object at 1967750648816>
# Mode_CAN_Sig_16: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Mode_CAN_Sig_21: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# NAWSPressure: (1, 763), attrs: <Attributes of HDF5 object at 1967750648816>
# NAWSSound: (1, 170912), attrs: <Attributes of HDF5 object at 1967750648816>
# NAWSTemperature: (1, 763), attrs: <Attributes of HDF5 object at 1967750648816>
# OBD_Aussen_Temp_: (1, 5100), attrs: <Attributes of HDF5 object at 1968096650048>
# OCU_Privacymode_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# PSD_LR_Fahrzeug_: (1, 5100), attrs: <Attributes of HDF5 object at 1968096652848>
# RS_Regenmenge_C: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# StdDev_Alt_CAN_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# StdDev_Lat_CAN_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# StdDev_Long_CAN: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# StdDev_pitch_CA: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# StdDev_roll_CAN: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# StdDev_vEast_CA: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# StdDev_vNorth_C: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# StdDev_vUp_CAN_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# StdDev_yaw_CAN_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# TSMomBegrenzung: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# Temperatur: (1, 244800), attrs: <Attributes of HDF5 object at 1967750648816>
# TrailK1: (1, 244800), attrs: <Attributes of HDF5 object at 1967750648816>
# TrailK2: (1, 244800), attrs: <Attributes of HDF5 object at 1967750648816>
# aCnt_CAN_Sig_40: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# aInsSolState_CA: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# a_x_CAN_Sig_10_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# a_x_CAN_Sig_6_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# a_y_CAN_Sig_5_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# a_y_CAN_Sig_9_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# a_z_CAN_Sig_11_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# a_z_CAN_Sig_7_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# bSats_CAN_Sig_4: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# bUTC_CAN_Sig_41: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# cGpsSolState_CA: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# cLeapSec_CAN_Si: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# dDiffAge_CAN_Si: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# dGpsPosType_CAN: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# dpitch_CAN_Sig_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# droll_CAN_Sig_2: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# dyaw_CAN_Sig_3_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# eSolAge_CAN_Sig: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# pitch_CAN_Sig_1: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# roll_CAN_Sig_13: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# v_east_CAN_Sig_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# v_north_CAN_Sig: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# v_up_CAN_Sig_21: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# xAlt_CAN_Sig_27: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>
# yaw_CAN_Sig_15_: (1, 5100), attrs: <Attributes of HDF5 object at 1967750648816>

# %% [markdown]
# NAWSSound channels 199/204 non-null

# %% [markdown]
# 5 track211 Q8 e-tron tyre12 files are missing the NAWS channel, I'll fill it with means of the respective group

# %%
# Get the filenames of all files with empty NAWSSound data from the dataframe

missing_nawssound_paths = df[df["NAWSSound_rms"].isna()]["filepath"].tolist()
print(f"Files with missing NAWSSound data: {len(missing_nawssound_paths)}")
for path in missing_nawssound_paths:
    print(os.path.basename(path))
# Out:
# Files with missing NAWSSound data: 5
# track211_Q8 e-tron_tyre12_meas3_2p5_1_2025-08-15_12-02-31.h5
# track211_Q8 e-tron_tyre12_meas5_2p5_1_2025-08-15_12-13-33.h5
# track211_Q8 e-tron_tyre12_meas6_2p5_1_2025-08-15_12-30-46.h5
# track211_Q8 e-tron_tyre12_meas6_2p5_1_2025-08-15_12-32-47.h5
# track211_Q8 e-tron_tyre12_meas6_2p5_1_2025-08-15_12-34-39.h5

# %%
# Sanity check if the channel is actually missing

test_path = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\track211\02_Q8 e-tron\tyre12\track211_Q8 e-tron_tyre12_meas3_2p5_1_2025-08-15_12-02-31.h5"
with h5py.File(test_path, "r") as h5file:
    for key in h5file.keys():
        print(f"{key}: {h5file[key].shape}, attrs: {h5file[key].attrs}")
# Out:
# BCM1_Aussen_Temp: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# CAN1_labCTRLI_: (1, 99000), attrs: <Attributes of HDF5 object at 1901419254528>
# CAN2_labDX_B: (1, 198000), attrs: <Attributes of HDF5 object at 1901419254528>
# Ch_1_labV12: (1, 132000), attrs: <Attributes of HDF5 object at 1901419254528>
# Ch_2_labV12: (1, 132000), attrs: <Attributes of HDF5 object at 1901419254528>
# Ch_3_labV12: (1, 132000), attrs: <Attributes of HDF5 object at 1901419254528>
# Ch_4_labV12: (1, 132000), attrs: <Attributes of HDF5 object at 1901419254528>
# Ch_5_labV12: (1, 132000), attrs: <Attributes of HDF5 object at 1901419254528>
# EPS_Motormoment: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# ESP_HL_Radgeschw: (1, 2750), attrs: <Attributes of HDF5 object at 1901419385840>
# ESP_HR_Radgeschw: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# ESP_VL_Radgeschw: (1, 2750), attrs: <Attributes of HDF5 object at 1901419385280>
# ESP_VR_Radgeschw: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# GPS: (1, 245760), attrs: <Attributes of HDF5 object at 1901419254528>
# IREnd: (3, 80, 80), attrs: <Attributes of HDF5 object at 1901419254528>
# IRStart: (3, 80, 80), attrs: <Attributes of HDF5 object at 1901419254528>
# Lat_CAN_Sig_13_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# Long_CAN_Sig_12: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# MO_NGS_Gangpos_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# RS_Regenmenge_C: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# StdDev_Alt_CAN_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# StdDev_Lat_CAN_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# StdDev_Long_CAN: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# StdDev_pitch_CA: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# StdDev_roll_CAN: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# StdDev_vEast_CA: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# StdDev_vNorth_C: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# StdDev_vUp_CAN_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# StdDev_yaw_CAN_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# aInsSolState_CA: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# a_x_CAN_Sig_4_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# a_y_CAN_Sig_3_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# a_z_CAN_Sig_5_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# bSats_CAN_Sig_2: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# bUTC_CAN_Sig_24: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# cGpsSolState_CA: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# cLeapSec_CAN_Si: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# dDiffAge_CAN_Si: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# dGpsPosType_CAN: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# dpitch_CAN_Sig_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# droll_CAN_Sig_1: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# dyaw_CAN_Sig_2_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# eSolAge_CAN_Sig: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# mic_2m: (1, 245760), attrs: <Attributes of HDF5 object at 1901419254528>
# mic_iso: (1, 245760), attrs: <Attributes of HDF5 object at 1901419254528>
# pitch_CAN_Sig_7: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# roll_CAN_Sig_6_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# v_east_CAN_Sig_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# v_north_CAN_Sig: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# v_up_CAN_Sig_11: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# xAlt_CAN_Sig_14: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>
# yaw_CAN_Sig_8_: (1, 2750), attrs: <Attributes of HDF5 object at 1901419254528>

# %% [markdown]
# ### Build the cleaned dataset

# %%
# Fill missing NAWSSound features with group-wise mean imputation

df_clean = df.copy()

naws_cols = [col for col in df_clean.columns if col.startswith("NAWSSound")]

group_cols = ["road_type", "car_id", "tyre_id"]

for col in naws_cols:
    df_clean[col] = df_clean.groupby(group_cols)[col].transform(
        lambda g: g.fillna(g.mean())
    )

# If some groups have only NaN (rare), fill remaining with global mean
if df_clean[naws_cols].isna().any().any():
    print("Some NAWSSound groups have only NaN, filling with global mean.")
    df_clean[naws_cols] = df_clean[naws_cols].fillna(df_clean[naws_cols].mean())

# Drop the mic_iso channels
df_clean = df_clean.drop(columns=[col for col in df_clean.columns if col.startswith("mic_iso")])

# %%
df_clean.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 145 columns):
#  #    Column                    Non-Null Count  Dtype
# ---   ------                    --------------  -----
#  0    TrailK1_rms               204 non-null    float64
#  1    TrailK1_mean              204 non-null    float64
#  2    TrailK1_std               204 non-null    float64
#  3    TrailK1_max               204 non-null    float64
#  4    TrailK1_crest             204 non-null    float64
#  5    TrailK1_zcr               204 non-null    float64
#  6    TrailK1_spec_centroid     204 non-null    float64
#  7    TrailK1_spec_rolloff      204 non-null    float64
#  8    TrailK1_spec_flatness     204 non-null    float64
#  9    TrailK1_spec_bandwidth    204 non-null    float64
#  10   TrailK1_band_0            204 non-null    float64
#  11   TrailK1_band_1            204 non-null    float64
#  12   TrailK1_band_2            204 non-null    float64
#  13   TrailK1_band_3            204 non-null    float64
#  14   TrailK1_band_4            204 non-null    float64
#  15   TrailK1_mfcc_1            204 non-null    float64
#  16   TrailK1_mfcc_2            204 non-null    float64
#  17   TrailK1_mfcc_3            204 non-null    float64
#  18   TrailK1_mfcc_4            204 non-null    float64
#  19   TrailK1_mfcc_5            204 non-null    float64
#  20   TrailK1_mfcc_6            204 non-null    float64
#  21   TrailK1_mfcc_7            204 non-null    float64
#  22   TrailK1_mfcc_8            204 non-null    float64
#  23   TrailK1_mfcc_9            204 non-null    float64
#  24   TrailK1_mfcc_10           204 non-null    float64
#  25   TrailK1_mfcc_11           204 non-null    float64
#  26   TrailK1_mfcc_12           204 non-null    float64
#  27   TrailK1_mfcc_13           204 non-null    float64
#  28   TrailK2_rms               204 non-null    float64
#  29   TrailK2_mean              204 non-null    float64
#  30   TrailK2_std               204 non-null    float64
#  31   TrailK2_max               204 non-null    float64
#  32   TrailK2_crest             204 non-null    float64
#  33   TrailK2_zcr               204 non-null    float64
#  34   TrailK2_spec_centroid     204 non-null    float64
#  35   TrailK2_spec_rolloff      204 non-null    float64
#  36   TrailK2_spec_flatness     204 non-null    float64
#  37   TrailK2_spec_bandwidth    204 non-null    float64
#  38   TrailK2_band_0            204 non-null    float64
#  39   TrailK2_band_1            204 non-null    float64
#  40   TrailK2_band_2            204 non-null    float64
#  41   TrailK2_band_3            204 non-null    float64
#  42   TrailK2_band_4            204 non-null    float64
#  43   TrailK2_mfcc_1            204 non-null    float64
#  44   TrailK2_mfcc_2            204 non-null    float64
#  45   TrailK2_mfcc_3            204 non-null    float64
#  46   TrailK2_mfcc_4            204 non-null    float64
#  47   TrailK2_mfcc_5            204 non-null    float64
#  48   TrailK2_mfcc_6            204 non-null    float64
#  49   TrailK2_mfcc_7            204 non-null    float64
#  50   TrailK2_mfcc_8            204 non-null    float64
#  51   TrailK2_mfcc_9            204 non-null    float64
#  52   TrailK2_mfcc_10           204 non-null    float64
#  53   TrailK2_mfcc_11           204 non-null    float64
#  54   TrailK2_mfcc_12           204 non-null    float64
#  55   TrailK2_mfcc_13           204 non-null    float64
#  56   LeadK1_rms                204 non-null    float64
#  57   LeadK1_mean               204 non-null    float64
#  58   LeadK1_std                204 non-null    float64
#  59   LeadK1_max                204 non-null    float64
#  60   LeadK1_crest              204 non-null    float64
#  61   LeadK1_zcr                204 non-null    float64
#  62   LeadK1_spec_centroid      204 non-null    float64
#  63   LeadK1_spec_rolloff       204 non-null    float64
#  64   LeadK1_spec_flatness      204 non-null    float64
#  65   LeadK1_spec_bandwidth     204 non-null    float64
#  66   LeadK1_band_0             204 non-null    float64
#  67   LeadK1_band_1             204 non-null    float64
#  68   LeadK1_band_2             204 non-null    float64
#  69   LeadK1_band_3             204 non-null    float64
#  70   LeadK1_band_4             204 non-null    float64
#  71   LeadK1_mfcc_1             204 non-null    float64
#  72   LeadK1_mfcc_2             204 non-null    float64
#  73   LeadK1_mfcc_3             204 non-null    float64
#  74   LeadK1_mfcc_4             204 non-null    float64
#  75   LeadK1_mfcc_5             204 non-null    float64
#  76   LeadK1_mfcc_6             204 non-null    float64
#  77   LeadK1_mfcc_7             204 non-null    float64
#  78   LeadK1_mfcc_8             204 non-null    float64
#  79   LeadK1_mfcc_9             204 non-null    float64
#  80   LeadK1_mfcc_10            204 non-null    float64
#  81   LeadK1_mfcc_11            204 non-null    float64
#  82   LeadK1_mfcc_12            204 non-null    float64
#  83   LeadK1_mfcc_13            204 non-null    float64
#  84   LeadK2_rms                204 non-null    float64
#  85   LeadK2_mean               204 non-null    float64
#  86   LeadK2_std                204 non-null    float64
#  87   LeadK2_max                204 non-null    float64
#  88   LeadK2_crest              204 non-null    float64
#  89   LeadK2_zcr                204 non-null    float64
#  90   LeadK2_spec_centroid      204 non-null    float64
#  91   LeadK2_spec_rolloff       204 non-null    float64
#  92   LeadK2_spec_flatness      204 non-null    float64
#  93   LeadK2_spec_bandwidth     204 non-null    float64
#  94   LeadK2_band_0             204 non-null    float64
#  95   LeadK2_band_1             204 non-null    float64
#  96   LeadK2_band_2             204 non-null    float64
#  97   LeadK2_band_3             204 non-null    float64
#  98   LeadK2_band_4             204 non-null    float64
#  99   LeadK2_mfcc_1             204 non-null    float64
#  100  LeadK2_mfcc_2             204 non-null    float64
#  101  LeadK2_mfcc_3             204 non-null    float64
#  102  LeadK2_mfcc_4             204 non-null    float64
#  103  LeadK2_mfcc_5             204 non-null    float64
#  104  LeadK2_mfcc_6             204 non-null    float64
#  105  LeadK2_mfcc_7             204 non-null    float64
#  106  LeadK2_mfcc_8             204 non-null    float64
#  107  LeadK2_mfcc_9             204 non-null    float64
#  108  LeadK2_mfcc_10            204 non-null    float64
#  109  LeadK2_mfcc_11            204 non-null    float64
#  110  LeadK2_mfcc_12            204 non-null    float64
#  111  LeadK2_mfcc_13            204 non-null    float64
#  112  NAWSSound_rms             204 non-null    float64
#  113  NAWSSound_mean            204 non-null    float64
#  114  NAWSSound_std             204 non-null    float64
#  115  NAWSSound_max             204 non-null    float64
#  116  NAWSSound_crest           204 non-null    float64
#  117  NAWSSound_zcr             204 non-null    float64
#  118  NAWSSound_spec_centroid   204 non-null    float64
#  119  NAWSSound_spec_rolloff    204 non-null    float64
#  120  NAWSSound_spec_flatness   204 non-null    float64
#  121  NAWSSound_spec_bandwidth  204 non-null    float64
#  122  NAWSSound_band_0          204 non-null    float64
#  123  NAWSSound_band_1          204 non-null    float64
#  124  NAWSSound_band_2          204 non-null    float64
#  125  NAWSSound_band_3          204 non-null    float64
#  126  NAWSSound_band_4          204 non-null    float64
#  127  NAWSSound_mfcc_1          204 non-null    float64
#  128  NAWSSound_mfcc_2          204 non-null    float64
#  129  NAWSSound_mfcc_3          204 non-null    float64
#  130  NAWSSound_mfcc_4          204 non-null    float64
#  131  NAWSSound_mfcc_5          204 non-null    float64
#  132  NAWSSound_mfcc_6          204 non-null    float64
#  133  NAWSSound_mfcc_7          204 non-null    float64
#  134  NAWSSound_mfcc_8          204 non-null    float64
#  135  NAWSSound_mfcc_9          204 non-null    float64
#  136  NAWSSound_mfcc_10         204 non-null    float64
#  137  NAWSSound_mfcc_11         204 non-null    float64
#  138  NAWSSound_mfcc_12         204 non-null    float64
#  139  NAWSSound_mfcc_13         204 non-null    float64
#  140  road_type                 204 non-null    object
#  141  car_id                    204 non-null    object
#  142  tyre_id                   204 non-null    object
#  143  filename                  204 non-null    object
#  144  filepath                  204 non-null    object
# dtypes: float64(140), object(5)
# memory usage: 231.2+ KB

# %% [markdown]
# ### Create data split for baseline models

# %%
# # --- Features: all float64 mic features ---
# feature_cols = df_clean.select_dtypes(include=["float64"]).columns.tolist()
# print("Number of features:", len(feature_cols))

# X = df_clean[feature_cols].values
# y = df_clean["road_type"].values

# # Encode string labels to integers for xgboost
# le = LabelEncoder()
# y_enc = le.fit_transform(y)   # e.g. "track150" -> 0, "track211" -> 1
# print("Classes:", le.classes_)

# n_splits = 5
# skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
# Out:
# Number of features: 140
# Classes: ['150' '211']

# %%
# Explicitly exclude non-feature columns (safer than dtype selection alone)
non_feature_cols = ["road_type", "car_id", "tyre_id", "filename", "filepath"]
feature_cols = [c for c in df_clean.columns
                if c not in non_feature_cols and df_clean[c].dtype == "float64"]

print("Number of features:", len(feature_cols))

X = df_clean[feature_cols].to_numpy()
y = df_clean["road_type"].to_numpy()
groups = df_clean["car_id"].to_numpy()

# Encode string labels to integers for XGBoost
le = LabelEncoder()
y_enc = le.fit_transform(y)
print("Classes:", le.classes_)

# LOCO splitter
logo = LeaveOneGroupOut()
# Out:
# Number of features: 140
# Classes: ['150' '211']

# %% [markdown]
# ### Training loop for RF and XGB

# %%
# rf_accs, rf_f1s = [], []
# xgb_accs, xgb_f1s = [], []

# fold_results = []

# for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
#     print(f"\n===== Fold {fold + 1}/{n_splits} =====")

#     X_train, X_val = X[train_idx], X[val_idx]
#     y_train, y_val = y[train_idx], y[val_idx]
#     y_train_enc, y_val_enc = y_enc[train_idx], y_enc[val_idx]

#     # ------------------ Random Forest ------------------
#     rf = RandomForestClassifier(
#         n_estimators=300,
#         max_depth=None,
#         min_samples_split=2,
#         min_samples_leaf=1,
#         n_jobs=-1,
#         random_state=42
#     )

#     rf.fit(X_train, y_train)
#     y_pred_rf = rf.predict(X_val)

#     rf_acc = accuracy_score(y_val, y_pred_rf)
#     rf_f1 = f1_score(y_val, y_pred_rf, average="weighted")

#     rf_accs.append(rf_acc)
#     rf_f1s.append(rf_f1)

#     print(f"RF  - acc: {rf_acc:.3f}, f1: {rf_f1:.3f}")
#     print(confusion_matrix(y_val, y_pred_rf))

#     # ------------------ XGBoost ------------------
#     xgb = XGBClassifier(
#         n_estimators=400,
#         max_depth=5,
#         learning_rate=0.05,
#         subsample=0.8,
#         colsample_bytree=0.8,
#         objective="binary:logistic",  # binary road-type problem
#         n_jobs=-1,
#         eval_metric="logloss",
#         random_state=42
#     )

#     xgb.fit(X_train, y_train_enc)
#     y_pred_xgb_enc = xgb.predict(X_val)
#     y_pred_xgb = le.inverse_transform(y_pred_xgb_enc)

#     xgb_acc = accuracy_score(y_val, y_pred_xgb)
#     xgb_f1 = f1_score(y_val, y_pred_xgb, average="weighted")

#     xgb_accs.append(xgb_acc)
#     xgb_f1s.append(xgb_f1)

#     print(f"XGB - acc: {xgb_acc:.3f}, f1: {xgb_f1:.3f}")
#     print(confusion_matrix(y_val, y_pred_xgb))

#     # store per-fold results
#     fold_results.append({
#         "fold": fold + 1,
#         "rf_acc": rf_acc,
#         "rf_f1": rf_f1,
#         "xgb_acc": xgb_acc,
#         "xgb_f1": xgb_f1
#     })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       2 xgb_accs, xgb_f1s = [], []
#       4 fold_results = []
# ----> 6 for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
#       7     print(f"\n===== Fold {fold + 1}/{n_splits} =====")
#       9     X_train, X_val = X[train_idx], X[val_idx]
#
# NameError: name 'skf' is not defined

# %%
rf_accs, rf_f1s = [], []
xgb_accs, xgb_f1s = [], []
fold_results = []

# Optional: to accumulate global confusion matrices across folds
# (nice for seminar slides)
labels = le.classes_
rf_cm_total = np.zeros((len(labels), len(labels)), dtype=int)
xgb_cm_total = np.zeros((len(labels), len(labels)), dtype=int)

for fold, (train_idx, test_idx) in enumerate(logo.split(X, y, groups=groups), start=1):
    held_out_car = groups[test_idx][0]
    print(f"\n===== LOCO Fold {fold} | Held-out car: {held_out_car} =====")
    print(f"Train n={len(train_idx)}, Test n={len(test_idx)}")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    y_train_enc, y_test_enc = y_enc[train_idx], y_enc[test_idx]

    # ------------------ Random Forest ------------------
    rf = RandomForestClassifier(
        n_estimators=300,
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        n_jobs=-1,
        random_state=42
    )

    rf.fit(X_train, y_train)
    y_pred_rf = rf.predict(X_test)

    rf_acc = accuracy_score(y_test, y_pred_rf)
    rf_f1 = f1_score(y_test, y_pred_rf, average="weighted")

    rf_accs.append(rf_acc)
    rf_f1s.append(rf_f1)

    cm_rf = confusion_matrix(y_test, y_pred_rf, labels=labels)
    rf_cm_total += cm_rf

    print(f"RF  - acc: {rf_acc:.3f}, f1: {rf_f1:.3f}")
    print(cm_rf)

    # ------------------ XGBoost ------------------
    # For 2-class problems you can use binary:logistic.
    # If you ever add more road types, switch to multi:softprob + num_class.
    xgb = XGBClassifier(
        n_estimators=400,
        max_depth=5,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        objective="binary:logistic",
        n_jobs=-1,
        eval_metric="logloss",
        random_state=42
    )

    xgb.fit(X_train, y_train_enc)
    y_pred_xgb_enc = xgb.predict(X_test)
    y_pred_xgb = le.inverse_transform(y_pred_xgb_enc.astype(int))

    xgb_acc = accuracy_score(y_test, y_pred_xgb)
    xgb_f1 = f1_score(y_test, y_pred_xgb, average="weighted")

    xgb_accs.append(xgb_acc)
    xgb_f1s.append(xgb_f1)

    cm_xgb = confusion_matrix(y_test, y_pred_xgb, labels=labels)
    xgb_cm_total += cm_xgb

    print(f"XGB - acc: {xgb_acc:.3f}, f1: {xgb_f1:.3f}")
    print(cm_xgb)

    fold_results.append({
        "fold": fold,
        "held_out_car": held_out_car,
        "n_test": len(test_idx),
        "rf_acc": rf_acc,
        "rf_f1": rf_f1,
        "xgb_acc": xgb_acc,
        "xgb_f1": xgb_f1
    })


# --------------- Summary ---------------
print("\n===== LOCO Summary (per held-out car) =====")
for r in fold_results:
    print(f"{r['held_out_car']}: RF acc={r['rf_acc']:.3f}, XGB acc={r['xgb_acc']:.3f}")

print("\n===== Overall (mean ± std) =====")
print(f"RF  acc: {np.mean(rf_accs):.3f} ± {np.std(rf_accs):.3f} | "
      f"f1: {np.mean(rf_f1s):.3f} ± {np.std(rf_f1s):.3f}")
print(f"XGB acc: {np.mean(xgb_accs):.3f} ± {np.std(xgb_accs):.3f} | "
      f"f1: {np.mean(xgb_f1s):.3f} ± {np.std(xgb_f1s):.3f}")

print("\nRF total confusion matrix (rows=true, cols=pred):")
print(rf_cm_total)
print("\nXGB total confusion matrix (rows=true, cols=pred):")
print(xgb_cm_total)
print("\nLabel order:", labels)
# Out:
# ===== LOCO Fold 1 | Held-out car: E-Golf =====
# Train n=179, Test n=25
# RF  - acc: 0.680, f1: 0.659
# [[ 4  6]
#  [ 2 13]]
# XGB - acc: 0.600, f1: 0.590
# [[ 4  6]
#  [ 4 11]]
#
# ===== LOCO Fold 2 | Held-out car: ID.4 =====
# Train n=115, Test n=89
# RF  - acc: 0.921, f1: 0.898
# [[ 2  7]
#  [ 0 80]]
# XGB - acc: 0.876, f1: 0.865
# [[ 2  7]
#  [ 4 76]]
#
# ===== LOCO Fold 3 | Held-out car: Q8 e-tron =====
# Train n=141, Test n=63
# RF  - acc: 0.698, f1: 0.587
# [[ 0 18]
#  [ 1 44]]
# XGB - acc: 0.698, f1: 0.632
# [[ 2 16]
#  [ 3 42]]
#
# ===== LOCO Fold 4 | Held-out car: Taycan =====
# Train n=177, Test n=27
# RF  - acc: 0.667, f1: 0.533
# [[ 0  9]
#  [ 0 18]]
# XGB - acc: 0.667, f1: 0.533
# [[ 0  9]
#  [ 0 18]]
#
# ===== LOCO Summary (per held-out car) =====
# E-Golf: RF acc=0.680, XGB acc=0.600
# ID.4: RF acc=0.921, XGB acc=0.876
# Q8 e-tron: RF acc=0.698, XGB acc=0.698
# Taycan: RF acc=0.667, XGB acc=0.667
#
# ===== Overall (mean ± std) =====
# RF  acc: 0.742 ± 0.104 | f1: 0.669 ± 0.139
# XGB acc: 0.710 ± 0.102 | f1: 0.655 ± 0.126
#
# RF total confusion matrix (rows=true, cols=pred):
# [[  6  40]
#  [  3 155]]
#
# XGB total confusion matrix (rows=true, cols=pred):
# [[  8  38]
#  [ 11 147]]
#
# Label order: ['150' '211']

# %%
results_df = pd.DataFrame(fold_results)
print("\nPer-fold results:")
print(results_df)

print("\n===== CV Summary =====")
print(f"RF  mean acc: {np.mean(rf_accs):.3f} ± {np.std(rf_accs):.3f}")
print(f"RF  mean f1 : {np.mean(rf_f1s):.3f} ± {np.std(rf_f1s):.3f}")
print(f"XGB mean acc: {np.mean(xgb_accs):.3f} ± {np.std(xgb_accs):.3f}")
print(f"XGB mean f1 : {np.mean(xgb_f1s):.3f} ± {np.std(xgb_f1s):.3f}")
# Out:
# Per-fold results:
#    fold held_out_car  n_test    rf_acc     rf_f1   xgb_acc    xgb_f1
# 0     1       E-Golf      25  0.680000  0.658824  0.600000  0.590278
# 1     2         ID.4      89  0.921348  0.897971  0.876404  0.865182
# 2     3    Q8 e-tron      63  0.698413  0.587450  0.698413  0.632214
# 3     4       Taycan      27  0.666667  0.533333  0.666667  0.533333
#
# ===== CV Summary =====
# RF  mean acc: 0.742 ± 0.104
# RF  mean f1 : 0.669 ± 0.139
# XGB mean acc: 0.710 ± 0.102
# XGB mean f1 : 0.655 ± 0.126

# %%
sns.set_style("whitegrid")

palette = ["mediumseagreen", "royalblue"]

# 1) Accuracy comparison
acc_plot_df = results_df.melt(
    id_vars="fold",
    value_vars=["rf_acc", "xgb_acc"],
    var_name="model",
    value_name="accuracy",
)
acc_plot_df["model"] = acc_plot_df["model"].map(
    {"rf_acc": "Random Forest", "xgb_acc": "XGBoost"}
)

plt.figure(figsize=(6, 4))
sns.barplot(data=acc_plot_df, x="fold", y="accuracy", hue="model", palette=palette)
plt.ylim(0, 1)
plt.title("Per-fold Accuracy")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.tight_layout()
# plt.show()
plt.savefig("accuracy_comparison.png", dpi=300)

# 2) F1-score comparison
f1_plot_df = results_df.melt(
    id_vars="fold",
    value_vars=["rf_f1", "xgb_f1"],
    var_name="model",
    value_name="f1",
)
f1_plot_df["model"] = f1_plot_df["model"].map(
    {"rf_f1": "Random Forest", "xgb_f1": "XGBoost"}
)

plt.figure(figsize=(6, 4))
sns.barplot(data=f1_plot_df, x="fold", y="f1", hue="model", palette=palette)
plt.ylim(0, 1)
plt.title("Per-fold F1-score")
plt.xlabel("Fold")
plt.ylabel("F1-score")
plt.legend(title="Model")
plt.tight_layout()
# plt.show()
plt.savefig("f1score_comparison.png", dpi=300)

# %% [markdown]
# ### Training loop for RF and XGB with oversampling

# %%
rf_accs, rf_f1s = [], []
xgb_accs, xgb_f1s = [], []

fold_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
    print(f"\n===== Fold {fold + 1}/{n_splits} =====")

    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    y_train_enc, y_val_enc = y_enc[train_idx], y_enc[val_idx]

    # ------------------ Random Forest ------------------
    rf = RandomForestClassifier(
        n_estimators=300,
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        class_weight={'150': 1.0, '211': 0.3},
        n_jobs=-1,
        random_state=42
    )

    rf.fit(X_train, y_train)
    y_pred_rf = rf.predict(X_val)

    rf_acc = accuracy_score(y_val, y_pred_rf)
    rf_f1 = f1_score(y_val, y_pred_rf, average="weighted")

    rf_accs.append(rf_acc)
    rf_f1s.append(rf_f1)

    print(f"RF  - acc: {rf_acc:.3f}, f1: {rf_f1:.3f}")
    print(confusion_matrix(y_val, y_pred_rf))

    # ------------------ XGBoost ------------------
    xgb = XGBClassifier(
        n_estimators=400,
        max_depth=5,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        scale_pos_weight=0.3,
        objective="binary:logistic",  # binary road-type problem
        n_jobs=-1,
        eval_metric="logloss",
        random_state=42
    )

    xgb.fit(X_train, y_train_enc)
    y_pred_xgb_enc = xgb.predict(X_val)
    y_pred_xgb = le.inverse_transform(y_pred_xgb_enc)

    xgb_acc = accuracy_score(y_val, y_pred_xgb)
    xgb_f1 = f1_score(y_val, y_pred_xgb, average="weighted")

    xgb_accs.append(xgb_acc)
    xgb_f1s.append(xgb_f1)

    print(f"XGB - acc: {xgb_acc:.3f}, f1: {xgb_f1:.3f}")
    print(confusion_matrix(y_val, y_pred_xgb))

    # store per-fold results
    fold_results.append({
        "fold": fold + 1,
        "rf_acc": rf_acc,
        "rf_f1": rf_f1,
        "xgb_acc": xgb_acc,
        "xgb_f1": xgb_f1
    })
# Out:
# ===== Fold 1/5 =====
# RF  - acc: 0.829, f1: 0.792
# [[ 3  7]
#  [ 0 31]]
# XGB - acc: 0.854, f1: 0.854
# [[ 7  3]
#  [ 3 28]]
#
# ===== Fold 2/5 =====
# RF  - acc: 0.878, f1: 0.869
# [[ 5  4]
#  [ 1 31]]
# XGB - acc: 0.902, f1: 0.902
# [[ 7  2]
#  [ 2 30]]
#
# ===== Fold 3/5 =====
# RF  - acc: 0.902, f1: 0.891
# [[ 5  4]
#  [ 0 32]]
# XGB - acc: 0.927, f1: 0.925
# [[ 7  2]
#  [ 1 31]]
#
# ===== Fold 4/5 =====
# RF  - acc: 0.829, f1: 0.783
# [[ 2  7]
#  [ 0 32]]
# XGB - acc: 0.878, f1: 0.859
# [[ 4  5]
#  [ 0 32]]
#
# ===== Fold 5/5 =====
# RF  - acc: 0.825, f1: 0.798
# [[ 3  6]
#  [ 1 30]]
# XGB - acc: 0.825, f1: 0.828
# [[ 6  3]
#  [ 4 27]]

# %%
results_df = pd.DataFrame(fold_results)
print("\nPer-fold results:")
print(results_df)

print("\n===== CV Summary =====")
print(f"RF  mean acc: {np.mean(rf_accs):.3f} ± {np.std(rf_accs):.3f}")
print(f"RF  mean f1 : {np.mean(rf_f1s):.3f} ± {np.std(rf_f1s):.3f}")
print(f"XGB mean acc: {np.mean(xgb_accs):.3f} ± {np.std(xgb_accs):.3f}")
print(f"XGB mean f1 : {np.mean(xgb_f1s):.3f} ± {np.std(xgb_f1s):.3f}")
# Out:
# Per-fold results:
#    fold    rf_acc     rf_f1   xgb_acc    xgb_f1
# 0     1  0.829268  0.791962  0.853659  0.853659
# 1     2  0.878049  0.868584  0.902439  0.902439
# 2     3  0.902439  0.891371  0.926829  0.925240
# 3     4  0.829268  0.783361  0.878049  0.859015
# 4     5  0.825000  0.797876  0.825000  0.828171
#
# ===== CV Summary =====
# RF  mean acc: 0.853 ± 0.032
# RF  mean f1 : 0.827 ± 0.044
# XGB mean acc: 0.877 ± 0.036
# XGB mean f1 : 0.874 ± 0.035

# %%
sns.set_style("whitegrid")

palette = ["mediumseagreen", "royalblue"]

# 1) Accuracy comparison
acc_plot_df = results_df.melt(
    id_vars="fold",
    value_vars=["rf_acc", "xgb_acc"],
    var_name="model",
    value_name="accuracy",
)
acc_plot_df["model"] = acc_plot_df["model"].map(
    {"rf_acc": "Random Forest", "xgb_acc": "XGBoost"}
)

plt.figure(figsize=(6, 4))
sns.barplot(data=acc_plot_df, x="fold", y="accuracy", hue="model", palette=palette)
plt.ylim(0, 1)
plt.title("Per-fold Accuracy")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.tight_layout()
# plt.show()
plt.savefig("accuracy_comparison.png", dpi=300)

# 2) F1-score comparison
f1_plot_df = results_df.melt(
    id_vars="fold",
    value_vars=["rf_f1", "xgb_f1"],
    var_name="model",
    value_name="f1",
)
f1_plot_df["model"] = f1_plot_df["model"].map(
    {"rf_f1": "Random Forest", "xgb_f1": "XGBoost"}
)

plt.figure(figsize=(6, 4))
sns.barplot(data=f1_plot_df, x="fold", y="f1", hue="model", palette=palette)
plt.ylim(0, 1)
plt.title("Per-fold F1-score")
plt.xlabel("Fold")
plt.ylabel("F1-score")
plt.legend(title="Model")
plt.tight_layout()
# plt.show()
plt.savefig("f1score_comparison.png", dpi=300)

# %% [markdown]
# ### Feature Importance

# %%
rf_final = RandomForestClassifier(
    n_estimators=500,
    max_depth=None,
    n_jobs=-1,
    random_state=42
)
rf_final.fit(X, y)

importances_rf = pd.Series(rf_final.feature_importances_, index=feature_cols)
print(importances_rf.sort_values(ascending=False).head(20))
# Out:
# NAWSSound_mfcc_10          0.038810
# NAWSSound_spec_centroid    0.026309
# NAWSSound_mfcc_2           0.025923
# NAWSSound_mfcc_13          0.023332
# NAWSSound_band_0           0.021139
# NAWSSound_mfcc_9           0.018412
# TrailK2_mfcc_5             0.017112
# NAWSSound_mfcc_12          0.014606
# LeadK1_mfcc_12             0.014236
# TrailK2_mfcc_2             0.013254
# LeadK2_mfcc_11             0.012359
# NAWSSound_mfcc_4           0.012028
# TrailK1_mfcc_5             0.012013
# TrailK1_mfcc_7             0.011929
# TrailK2_mfcc_11            0.011890
# TrailK1_mfcc_2             0.011686
# TrailK1_mfcc_13            0.011635
# NAWSSound_crest            0.011538
# LeadK2_mfcc_13             0.011247
# LeadK2_mfcc_12             0.010854
# dtype: float64

# %%
top10_rf = importances_rf.sort_values(ascending=False).head(10)

sns.set_style("whitegrid")

plt.figure(figsize=(8, 4))
sns.barplot(
    x=top10_rf.values,
    y=top10_rf.index,
    color="royalblue"  # single color, matches your palette
)
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.title("Top 10 Features Random Forest")
plt.tight_layout()
# plt.show()
plt.savefig("rf_top10_feature_importances.png", dpi=300)

# %%
xgb_final = XGBClassifier(
    n_estimators=400,
    max_depth=5,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="binary:logistic",
    n_jobs=-1,
    eval_metric="logloss",
    random_state=42
)
xgb_final.fit(X, y_enc)

xgb_feature_scores = xgb_final.get_booster().get_score(importance_type='gain')
    
# Convert to pandas Series
importances_xgb = (
    pd.Series(xgb_feature_scores)
    .rename(index=lambda x: feature_cols[int(x[1:])])  # maps f0 → feature name
    .sort_values(ascending=False)
)

xgb_norm = importances_xgb / importances_xgb.sum()
print(xgb_norm.head(20))
# Out:
# TrailK2_band_4       0.054945
# NAWSSound_mfcc_10    0.037640
# TrailK2_mfcc_5       0.028344
# LeadK1_mfcc_3        0.024948
# TrailK1_max          0.021990
# TrailK1_band_3       0.020786
# LeadK2_mfcc_3        0.020777
# TrailK2_band_3       0.020295
# LeadK1_std           0.018516
# NAWSSound_band_3     0.017127
# NAWSSound_mfcc_9     0.016655
# NAWSSound_mfcc_4     0.016536
# LeadK2_mfcc_2        0.015765
# LeadK2_mfcc_12       0.015042
# TrailK1_mfcc_8       0.014937
# TrailK2_mfcc_4       0.014925
# TrailK2_mfcc_7       0.014760
# NAWSSound_mfcc_2     0.014693
# TrailK1_band_0       0.014567
# TrailK1_mfcc_2       0.014507
# dtype: float64

# %%
top10_xgb = xgb_norm.sort_values(ascending=False).head(10)

sns.set_style("whitegrid")

plt.figure(figsize=(8, 4))
sns.barplot(
    x=top10_xgb.values,
    y=top10_xgb.index,
    color="royalblue"  # single color, matches your palette
)
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.title("Top 10 Features XGBoost")
plt.tight_layout()
# plt.show()
plt.savefig("xgb_top10_feature_importances.png", dpi=300)
