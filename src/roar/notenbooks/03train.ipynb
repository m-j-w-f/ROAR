# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Imports and constants

# %%
import os
import re
from pathlib import Path

import h5py
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.model_selection import LeaveOneGroupOut, StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier

from roar import ROOT_DIR
from roar.preprocessing import extract_features_from_h5_file

# %%
MIC_CHANNELS = {
    "TrailK1": "Ch_1_labV12",
    "TrailK2": "Ch_2_labV12",
    "LeadK1": "Ch_3_labV12",
    "LeadK2": "Ch_4_labV12",
    "NAWSSound": "NAWSSound",
    "mic_iso": "mic_iso",
}

tracks = ["track150", "track211"]
cars = ["01_ID.4", "02_Q8 e-tron", "03_Taycan", "04_E-Golf"]
tyres = ["tyre1", "tyre3", "tyre6", "tyre10", "tyre12", "tyre13"]

experiment_mapping = {
    "track150": {
        "01_ID.4": ["tyre1"],
        "02_Q8 e-tron": ["tyre6", "tyre12"],
        "03_Taycan": ["tyre10"],
        "04_E-Golf": ["tyre13"],
    },
    "track211": {
        "01_ID.4": ["tyre1", "tyre3"],
        "02_Q8 e-tron": ["tyre6", "tyre12"],
        "03_Taycan": ["tyre10"],
        "04_E-Golf": ["tyre13"],
    },
}

# %% [markdown]
# ### Renaming the ikaISO files (track 259)

# %%
## Renaming helpers


def rename_h5_files(directory):
    pattern = re.compile(
        r"""
        ^(?P<prefix>b\d{2}_)?                # optional b##
        (?P<vehicle>ID4|Q8\ e-tron|Taycan|E-Golf)_
        (?P<tyre>[\w-]+)_
        (?P<test>ikaISO|ikaTP|ikaST)_
        (?P<amplitude>[^_]+)_
        (?P<speed>vr\d{2,3})_
        (?P<rest>.+\.h5)$
        """,
        re.VERBOSE,
    )

    for path in Path(directory).glob("*.h5"):
        match = pattern.match(path.name)
        if not match:
            continue

        prefix = (match.group("prefix") or "").rstrip("_")
        parts = [
            match.group("test"),
            match.group("vehicle"),
            match.group("tyre"),
            match.group("amplitude"),
            match.group("speed"),
        ]
        if prefix:
            parts.append(prefix)

        parts.append(match.group("rest"))
        new_name = "_".join(parts)

        if new_name != path.name:
            new_path = path.with_name(new_name)
            print(f"Renaming {path.name} -> {new_name}")
            path.rename(new_path)


def retag_h5_files(directory):
    test_map = {"track150": "track211"}
    vehicle_map = {"ID.4": "ID.4"}
    tyre_map = {"tyre3": "tyre3"}
    pattern = re.compile(r"^(?P<test>[^_]+)_(?P<vehicle>[^_]+)_(?P<tyre>[^_]+)_(?P<rest>.+)$")

    for path in Path(directory).glob("*.h5"):
        match = pattern.match(path.name)
        if not match:
            continue

        test = test_map.get(match.group("test"), match.group("test"))
        vehicle = vehicle_map.get(match.group("vehicle"), match.group("vehicle"))
        tyre = tyre_map.get(match.group("tyre"), match.group("tyre"))

        new_name = f"{test}_{vehicle}_{tyre}_{match.group('rest')}"
        if new_name != path.name:
            print(f"Renaming {path.name} -> {new_name}")
            path.rename(path.with_name(new_name))

# %%
target_dir = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\259\01 VW ID4\02 UniRoyal RainSport5 - Tyre3"

rename_h5_files(target_dir)
# Out:
# Renaming ID4_RainSport5_ikaISO_2pt6_vr100_2025-07-11_10-32-06.h5 -> ikaISO_ID4_RainSport5_2pt6_vr100_2025-07-11_10-32-06.h5
# Renaming ID4_RainSport5_ikaISO_2pt6_vr100_2025-07-11_10-32-58.h5 -> ikaISO_ID4_RainSport5_2pt6_vr100_2025-07-11_10-32-58.h5
# Renaming ID4_RainSport5_ikaISO_2pt6_vr100_2025-07-11_10-33-49.h5 -> ikaISO_ID4_RainSport5_2pt6_vr100_2025-07-11_10-33-49.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-48-47.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-48-47.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-49-51.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-49-51.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-50-40.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-50-40.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-51-30.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-51-30.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_09-52-21.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_09-52-21.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_10-14-45.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_10-14-45.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_10-16-05.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_10-16-05.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_10-16-55.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_10-16-55.h5
# Renaming ID4_RainSport5_ikaISO_3pt1_vr100_2025-07-11_10-17-44.h5 -> ikaISO_ID4_RainSport5_3pt1_vr100_2025-07-11_10-17-44.h5

# %%
target_dir = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\track211\01_ID.4\tyre3"

retag_h5_files(target_dir)
# Out:
# Renaming track150_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-06.h5 -> track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-06.h5
# Renaming track150_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-58.h5 -> track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-32-58.h5
# Renaming track150_ID.4_tyre3_2pt6_vr100_2025-07-11_10-33-49.h5 -> track211_ID.4_tyre3_2pt6_vr100_2025-07-11_10-33-49.h5
# Renaming track150_ID.4_tyre3_2pt6_vr45_2025-07-11_10-24-28.h5 -> track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-24-28.h5
# Renaming track150_ID.4_tyre3_2pt6_vr45_2025-07-11_10-25-31.h5 -> track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-25-31.h5
# Renaming track150_ID.4_tyre3_2pt6_vr45_2025-07-11_10-26-33.h5 -> track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-26-33.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_2025-07-11_10-35-11.h5 -> track211_ID.4_tyre3_2pt6_vr50_2025-07-11_10-35-11.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_2025-07-11_10-36-17.h5 -> track211_ID.4_tyre3_2pt6_vr50_2025-07-11_10-36-17.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-37-31.h5 -> track211_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-37-31.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-38-35.h5 -> track211_ID.4_tyre3_2pt6_vr50_b35_2025-07-11_10-38-35.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-40-06.h5 -> track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-40-06.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-41-07.h5 -> track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-41-07.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-42-10.h5 -> track211_ID.4_tyre3_2pt6_vr50_b50_2025-07-11_10-42-10.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-43-33.h5 -> track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-43-33.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-44-35.h5 -> track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-44-35.h5
# Renaming track150_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-45-35.h5 -> track211_ID.4_tyre3_2pt6_vr50_b70_2025-07-11_10-45-35.h5
# Renaming track150_ID.4_tyre3_2pt6_vr80_2025-07-11_10-27-40.h5 -> track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-27-40.h5
# Renaming track150_ID.4_tyre3_2pt6_vr80_2025-07-11_10-28-35.h5 -> track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-28-35.h5
# Renaming track150_ID.4_tyre3_2pt6_vr80_2025-07-11_10-29-30.h5 -> track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-29-30.h5
# Renaming track150_ID.4_tyre3_2pt6_vr80_2025-07-11_10-30-26.h5 -> track211_ID.4_tyre3_2pt6_vr80_2025-07-11_10-30-26.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-48-47.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-48-47.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-49-51.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-49-51.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-50-40.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-50-40.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-51-30.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-51-30.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_09-52-21.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_09-52-21.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_10-14-45.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-14-45.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-05.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-05.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-55.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-16-55.h5
# Renaming track150_ID.4_tyre3_3pt1_vr100_2025-07-11_10-17-44.h5 -> track211_ID.4_tyre3_3pt1_vr100_2025-07-11_10-17-44.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_09-39-41.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-39-41.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_09-42-29.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-42-29.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_09-43-38.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-43-38.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_09-44-56.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_09-44-56.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_10-08-44.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-08-44.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_10-09-42.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-09-42.h5
# Renaming track150_ID.4_tyre3_3pt1_vr45_2025-07-11_10-10-48.h5 -> track211_ID.4_tyre3_3pt1_vr45_2025-07-11_10-10-48.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-55-07.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-55-07.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-56-10.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-56-10.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-57-46.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-57-46.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-58-50.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-58-50.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-59-53.h5 -> track211_ID.4_tyre3_3pt1_vr50_b35_2025-07-11_09-59-53.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-01-19.h5 -> track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-01-19.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-02-20.h5 -> track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-02-20.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-03-24.h5 -> track211_ID.4_tyre3_3pt1_vr50_b50_2025-07-11_10-03-24.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-04-43.h5 -> track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-04-43.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-05-45.h5 -> track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-05-45.h5
# Renaming track150_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-06-45.h5 -> track211_ID.4_tyre3_3pt1_vr50_b70_2025-07-11_10-06-45.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-00.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-00.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-54.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_09-46-54.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_09-47-46.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_09-47-46.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_10-11-49.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_10-11-49.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_10-12-44.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_10-12-44.h5
# Renaming track150_ID.4_tyre3_3pt1_vr80_2025-07-11_10-13-39.h5 -> track211_ID.4_tyre3_3pt1_vr80_2025-07-11_10-13-39.h5

# %% [markdown]
# ### NAMING INCONSISTENCY PROBLEMS

# %%
# File Naming suggests road type 150, metadata says 211

etron_testfilepath = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\data\data_original\02 Audi Q8\ikastandard\Tyre12\01_2025-08-15\track150_Q8 e-tron_tyre12_meas0_2p5_1_2025-08-15_13-06-24.h5"
etron_cleanedfilepath = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\track150\02_Q8 e-tron\tyre12\track150_Q8 e-tron_tyre12_meas0_2p5_1_2025-08-15_13-06-24.h5"
print("Original ETron file metadata:\n")
with h5py.File(etron_testfilepath, "r") as h5file:
    for meta_key in h5file.attrs.keys():
        print(f"{meta_key} = {h5file.attrs[meta_key]}")
print()
print("Cleaned ETron file metadata:\n")
with h5py.File(etron_cleanedfilepath, "r") as h5file:
    for meta_key in h5file.attrs.keys():
        print(f"{meta_key} = {h5file.attrs[meta_key]}")
# Out:
# Original ETron file metadata:
#
# CreationDate = 2025-08-15_13-06-24
# MeasCount = [1.]
# MeasName = Select Measurement
# MeasTypeID = [0.]
# Pressure = [2.5]
# TrackID = [211.]
# TrackName = ika Teststrecke
# TyreID = [12.]
# TyreName = R12 - Hankook Ventus S1 evo3 ev 255/50R20 109H
# carName = Q8 e-tron
#
# Cleaned ETron file metadata:
#
# CreationDate = 2025-08-15_13-06-24
# MeasCount = [1.]
# MeasName = Select Measurement
# MeasTypeID = [0.]
# Pressure = [2.5]
# TrackID = [211.]
# TrackName = ika Teststrecke
# TyreID = [12.]
# TyreName = R12 - Hankook Ventus S1 evo3 ev 255/50R20 109H
# carName = Q8 e-tron

# %%
# File Naming suggests road type 211, metadata says 150

ikaISO_testfilepath = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\data\data_original\01 VW ID4\01 ika ISO-Akustikstrecke track211\02 UniRoyal RainSport5 - Tyre3\b35_ID4_RainSport5_ikaISO_2pt6_vr50_2025-07-11_10-37-31.h5"
ikaISO_cleanedfilepath = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data\track259\01_ID.4\tyre3\track259_ID.4_tyre3_2pt6_vr45_2025-07-11_10-24-28.h5"
print("Original IkaISO file metadata:\n")
with h5py.File(ikaISO_testfilepath, "r") as h5file:
    for meta_key in h5file.attrs.keys():
        print(f"{meta_key} = {h5file.attrs[meta_key]}")
print()
print("Cleaned IkaISO file metadata:\n")
with h5py.File(ikaISO_cleanedfilepath, "r") as h5file:
    for meta_key in h5file.attrs.keys():
        print(f"{meta_key} = {h5file.attrs[meta_key]}")
# Out:
# Original IkaISO file metadata:
#
# CreationDate = 2025-07-11_10-37-31
# MeasCount = [1.]
# MeasName = _Meas
# MeasTypeID = [0.]
# Pressure = ['2pt6']
# TrackID = [150.]
# TrackName = ['Road']
# TyreID = ['']
# TyreName = _UniRoyal RainSport5
# carName = ['Vehicle']
#
# Cleaned IkaISO file metadata:
#
# CreationDate = 2025-07-11_10-24-28
# MeasCount = [1.]
# MeasName = _Meas
# MeasTypeID = [0.]
# Pressure = ['2pt6']
# TrackID = [150.]
# TrackName = ['Road']
# TyreID = ['']
# TyreName = _UniRoyal RainSport5
# carName = ['Vehicle']

# %%
# List all test files and their metadata reveals mismatches

data_path = r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data"
meta_keys = ["TrackID", "carName", "TyreID"]

test_paths = []

for track in tracks:
    for car in cars:
        for tyre in experiment_mapping.get(track, {}).get(car, []):
            if not tyre:
                continue
            test_path = os.path.join(data_path, track, car, tyre)
            test_paths.append(test_path)

for test_path in test_paths:
    print(f"[{test_path[len(data_path) + 1 :]}]\n")
    for testfilepath in os.listdir(test_path):
        if testfilepath.endswith(".h5"):
            full_testfilepath = os.path.join(test_path, testfilepath)
            with h5py.File(full_testfilepath, "r") as h5file:
                meta_values = []
                for meta_key in meta_keys:
                    meta_values.append(str(h5file.attrs.get(meta_key, "N/A")))
                print(", ".join(meta_values))
    print()
# Out:
# [track150\01_ID.4\tyre1]
#
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
# [150.], ID.4, [1.]
#
# [track150\01_ID.4\tyre3]
#
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
# [150.], ['Vehicle'], ['']
#
# [track150\02_Q8 e-tron\tyre6]
#
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
# [150.], Q8 e-tron, [6.]
#
# [track150\02_Q8 e-tron\tyre12]
#
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
#
# [track150\03_Taycan\tyre10]
#
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
# [150.], Taycan, [10.]
#
# [track150\04_E-Golf\tyre13]
#
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
# [150.], E-Golf, [13.]
#
# [track211\01_ID.4\tyre1]
#
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
# [211.], ID.4, [1.]
#
# [track211\02_Q8 e-tron\tyre6]
#
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
# [211.], Q8 e-tron, [6.]
#
# [track211\02_Q8 e-tron\tyre12]
#
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
# [211.], Q8 e-tron, [12.]
#
# [track211\03_Taycan\tyre10]
#
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
# [211.], Taycan, [10.]
#
# [track211\04_E-Golf\tyre13]
#
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]
# [211.], E-Golf, [13.]

# %% [markdown]
# ### Single scalar audio feature extraction for baseline models and name parser

# %%
from roar import DATA_DIR as DATA_ROOT
from roar import MIC_CHANNELS  # noqa: F811

if not DATA_ROOT.exists():
    DATA_ROOT = Path(r"C:\Users\Lars\Büro\KIT\Master\WS_25_26\AIFB_Seminar\projects\workspace\data")
# Test feature extraction
features = extract_features_from_h5_file(
    DATA_ROOT
    / "track211/02_Q8 e-tron/tyre12/track211_Q8 e-tron_tyre12_meas1_2p5_1_2025-08-15_11-46-48.h5",
    MIC_CHANNELS,
)
for feature in features.keys():
    print(f"{feature}: {features[feature]}")
print(len(features))
# Out:
# Ch_1_labV12_rms: 1.9825720167974183
# Ch_1_labV12_mean: -7.507651404992822e-05
# Ch_1_labV12_std: 1.9825720153759108
# Ch_1_labV12_max: 8.968762397766113
# Ch_1_labV12_crest: 4.523801565468555
# Ch_1_labV12_zcr: 0.008376712625777952
# Ch_1_labV12_spec_centroid: 76.32497673989454
# Ch_1_labV12_spec_rolloff: 445.31249999999926
# Ch_1_labV12_spec_flatness: 3.621808391661969e-05
# Ch_1_labV12_spec_bandwidth: 205.7811301947801
# Ch_1_labV12_band_0: 0.26112378989874435
# Ch_1_labV12_band_1: 0.007389678246942566
# Ch_1_labV12_band_2: 0.009410983385702936
# Ch_1_labV12_band_3: 0.0033581412924817682
# Ch_1_labV12_band_4: 0.00013030426464310808
# Ch_1_labV12_mfcc_1: -26.38875389099121
# Ch_1_labV12_mfcc_2: 213.49420166015625
# Ch_1_labV12_mfcc_3: 20.73758888244629
# Ch_1_labV12_mfcc_4: -15.789551734924316
# Ch_1_labV12_mfcc_5: 2.5844290256500244
# Ch_1_labV12_mfcc_6: 1.983687400817871
# Ch_1_labV12_mfcc_7: 7.090250492095947
# Ch_1_labV12_mfcc_8: 9.382965087890625
# Ch_1_labV12_mfcc_9: 6.579596042633057
# Ch_1_labV12_mfcc_10: 5.388495922088623
# Ch_1_labV12_mfcc_11: 3.723315477371216
# Ch_1_labV12_mfcc_12: 9.787144660949707
# Ch_1_labV12_mfcc_13: 10.762883186340332
# Ch_2_labV12_rms: 1.9467883905979049
# Ch_2_labV12_mean: 0.0003081211155831302
# Ch_2_labV12_std: 1.9467883662145096
# Ch_2_labV12_max: 9.150646209716797
# Ch_2_labV12_crest: 4.700380508333541
# Ch_2_labV12_zcr: 0.008842399778280125
# Ch_2_labV12_spec_centroid: 80.9199064871507
# Ch_2_labV12_spec_rolloff: 515.6249999999991
# Ch_2_labV12_spec_flatness: 4.019228692187646e-05
# Ch_2_labV12_spec_bandwidth: 215.9146785538445
# Ch_2_labV12_band_0: 0.2453080475099907
# Ch_2_labV12_band_1: 0.00700476447828398
# Ch_2_labV12_band_2: 0.00971479799788268
# Ch_2_labV12_band_3: 0.0036148711630344765
# Ch_2_labV12_band_4: 0.00013902888249632436
# Ch_2_labV12_mfcc_1: -27.638397216796875
# Ch_2_labV12_mfcc_2: 215.28260803222656
# Ch_2_labV12_mfcc_3: 21.4366397857666
# Ch_2_labV12_mfcc_4: -20.27928924560547
# Ch_2_labV12_mfcc_5: 3.4920334815979004
# Ch_2_labV12_mfcc_6: 3.536736488342285
# Ch_2_labV12_mfcc_7: 4.022161960601807
# Ch_2_labV12_mfcc_8: 11.546142578125
# Ch_2_labV12_mfcc_9: 7.766989707946777
# Ch_2_labV12_mfcc_10: 1.0631864070892334
# Ch_2_labV12_mfcc_11: 7.041389465332031
# Ch_2_labV12_mfcc_12: 12.859000205993652
# Ch_2_labV12_mfcc_13: 5.201572418212891
# Ch_3_labV12_rms: 1.9063343049544212
# Ch_3_labV12_mean: -0.002668439659196499
# Ch_3_labV12_std: 1.9063324373455541
# Ch_3_labV12_max: 10.62474536895752
# Ch_3_labV12_crest: 5.573390425683053
# Ch_3_labV12_zcr: 0.009526790208880484
# Ch_3_labV12_spec_centroid: 88.53395053352395
# Ch_3_labV12_spec_rolloff: 597.656249999999
# Ch_3_labV12_spec_flatness: 4.8681218777821024e-05
# Ch_3_labV12_spec_bandwidth: 222.5140291123908
# Ch_3_labV12_band_0: 0.23344781266277204
# Ch_3_labV12_band_1: 0.011245043776834475
# Ch_3_labV12_band_2: 0.011901159882475677
# Ch_3_labV12_band_3: 0.0030115448001825436
# Ch_3_labV12_band_4: 0.00014116944391270362
# Ch_3_labV12_mfcc_1: -17.763721466064453
# Ch_3_labV12_mfcc_2: 208.8040313720703
# Ch_3_labV12_mfcc_3: 26.383832931518555
# Ch_3_labV12_mfcc_4: -14.750289916992188
# Ch_3_labV12_mfcc_5: 3.0117084980010986
# Ch_3_labV12_mfcc_6: 5.206258296966553
# Ch_3_labV12_mfcc_7: 6.723231792449951
# Ch_3_labV12_mfcc_8: 3.412184238433838
# Ch_3_labV12_mfcc_9: 0.4339500069618225
# Ch_3_labV12_mfcc_10: 2.7570536136627197
# Ch_3_labV12_mfcc_11: 3.3805463314056396
# Ch_3_labV12_mfcc_12: 10.434342384338379
# Ch_3_labV12_mfcc_13: 11.367571830749512
# Ch_4_labV12_rms: 1.9371058689307883
# Ch_4_labV12_mean: -0.0026731226056299342
# Ch_4_labV12_std: 1.937104024532921
# Ch_4_labV12_max: 10.732621192932129
# Ch_4_labV12_crest: 5.540544458375731
# Ch_4_labV12_zcr: 0.00945703140465951
# Ch_4_labV12_spec_centroid: 87.94079867586645
# Ch_4_labV12_spec_rolloff: 609.374999999999
# Ch_4_labV12_spec_flatness: 5.23120608525701e-05
# Ch_4_labV12_spec_bandwidth: 223.6971901561261
# Ch_4_labV12_band_0: 0.2445816646309081
# Ch_4_labV12_band_1: 0.010696672045568985
# Ch_4_labV12_band_2: 0.012452697669297037
# Ch_4_labV12_band_3: 0.003256617340691732
# Ch_4_labV12_band_4: 0.00015306342295107515
# Ch_4_labV12_mfcc_1: -18.546117782592773
# Ch_4_labV12_mfcc_2: 211.11131286621094
# Ch_4_labV12_mfcc_3: 26.655797958374023
# Ch_4_labV12_mfcc_4: -18.97373390197754
# Ch_4_labV12_mfcc_5: 5.228600978851318
# Ch_4_labV12_mfcc_6: 5.840327262878418
# Ch_4_labV12_mfcc_7: 1.944808840751648
# Ch_4_labV12_mfcc_8: 7.8037238121032715
# Ch_4_labV12_mfcc_9: 2.639878511428833
# Ch_4_labV12_mfcc_10: -3.6002187728881836
# Ch_4_labV12_mfcc_11: 7.627304553985596
# Ch_4_labV12_mfcc_12: 14.414793968200684
# Ch_4_labV12_mfcc_13: 4.908548355102539
# NAWSSound_rms: 40.626136586431215
# NAWSSound_mean: 0.5078386721357093
# NAWSSound_std: 40.622962395946075
# NAWSSound_max: 484.10152837346885
# NAWSSound_crest: 11.916011933146473
# NAWSSound_zcr: 0.013955192302777123
# NAWSSound_spec_centroid: 62.059739446158254
# NAWSSound_spec_rolloff: 195.3125
# NAWSSound_spec_flatness: 0.0006443271671135279
# NAWSSound_spec_bandwidth: 192.41284803239395
# NAWSSound_band_0: 217.41954790477556
# NAWSSound_band_1: 5.897033499315803
# NAWSSound_band_2: 2.9246877543555665
# NAWSSound_band_3: 1.2089704374712587
# NAWSSound_band_4: 0.08538429513942536
# NAWSSound_mfcc_1: 289.68536376953125
# NAWSSound_mfcc_2: 163.6353302001953
# NAWSSound_mfcc_3: 31.034826278686523
# NAWSSound_mfcc_4: -13.15053939819336
# NAWSSound_mfcc_5: 11.550732612609863
# NAWSSound_mfcc_6: 27.7878475189209
# NAWSSound_mfcc_7: 12.580153465270996
# NAWSSound_mfcc_8: -2.9258360862731934
# NAWSSound_mfcc_9: 0.8906654715538025
# NAWSSound_mfcc_10: 12.2007417678833
# NAWSSound_mfcc_11: 12.408939361572266
# NAWSSound_mfcc_12: 1.5914157629013062
# NAWSSound_mfcc_13: -6.233060836791992
# mic_iso_rms: 0.0519708218749731
# mic_iso_mean: -0.00017169532403472971
# mic_iso_std: 0.051970538260401794
# mic_iso_max: 0.24461996840709999
# mic_iso_crest: 4.706871180307949
# mic_iso_zcr: 0.02377951067411986
# mic_iso_spec_centroid: 602.6251764211765
# mic_iso_spec_rolloff: 1582.03125253125
# mic_iso_spec_flatness: 0.0009222255491812177
# mic_iso_spec_bandwidth: 600.4520120223548
# mic_iso_band_0: 4.007979028376878e-05
# mic_iso_band_1: 1.0084637025723936e-05
# mic_iso_band_2: 3.71970987565494e-05
# mic_iso_band_3: 1.9897179900935697e-05
# mic_iso_band_4: 2.15007634072227e-06
# mic_iso_mfcc_1: -307.54595947265625
# mic_iso_mfcc_2: 214.69635009765625
# mic_iso_mfcc_3: -28.779455184936523
# mic_iso_mfcc_4: -7.333923816680908
# mic_iso_mfcc_5: -12.927000999450684
# mic_iso_mfcc_6: 4.4120192527771
# mic_iso_mfcc_7: 3.8807783126831055
# mic_iso_mfcc_8: 1.8926775455474854
# mic_iso_mfcc_9: 8.542154312133789
# mic_iso_mfcc_10: 4.145444393157959
# mic_iso_mfcc_11: 5.436092376708984
# mic_iso_mfcc_12: 10.195422172546387
# mic_iso_mfcc_13: 8.724067687988281
# mic_2m_rms: 0.06011419808606556
# mic_2m_mean: -0.0011764828471290739
# mic_2m_std: 0.060102684629233814
# mic_2m_max: 0.31710462562935
# mic_2m_crest: 5.275037020377681
# mic_2m_zcr: 0.019937001393851406
# mic_2m_spec_centroid: 495.73856978679026
# mic_2m_spec_rolloff: 1500.0000023999999
# mic_2m_spec_flatness: 0.0011072904077524398
# mic_2m_spec_bandwidth: 585.462266233513
# mic_2m_band_0: 4.542081134768161e-05
# mic_2m_band_1: 7.952136834414789e-06
# mic_2m_band_2: 2.859233107418445e-05
# mic_2m_band_3: 1.3508591241490962e-05
# mic_2m_band_4: 1.4562086820114803e-06
# mic_2m_mfcc_1: -309.02301025390625
# mic_2m_mfcc_2: 203.13458251953125
# mic_2m_mfcc_3: -18.99373435974121
# mic_2m_mfcc_4: -9.471330642700195
# mic_2m_mfcc_5: -11.396489143371582
# mic_2m_mfcc_6: 3.3491365909576416
# mic_2m_mfcc_7: 4.624596118927002
# mic_2m_mfcc_8: 1.8503494262695312
# mic_2m_mfcc_9: 8.872352600097656
# mic_2m_mfcc_10: 4.760437488555908
# mic_2m_mfcc_11: 5.926448822021484
# mic_2m_mfcc_12: 10.490684509277344
# mic_2m_mfcc_13: 9.422670364379883
# 196

# %% [markdown]
# ### Build the initial dataset

# %%
from roar.preprocessing import parse_filename

# Get the h5 file paths
h5_paths = list(DATA_ROOT.rglob("*.h5"))
print(f"Found {len(h5_paths)} files")

rows = []
for path in h5_paths:
    feat_dict = extract_features_from_h5_file(path, channels=MIC_CHANNELS)
    meta = parse_filename(path)

    row = {
        **feat_dict,
        **meta,
    }
    rows.append(row)

df = pd.DataFrame(rows)

df.info(verbose=True, show_counts=True)
# Out:
# Found 204 files
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 203 columns):
#  #    Column                      Non-Null Count  Dtype
# ---   ------                      --------------  -----
#  0    Ch_1_labV12_rms             204 non-null    float64
#  1    Ch_1_labV12_mean            204 non-null    float64
#  2    Ch_1_labV12_std             204 non-null    float64
#  3    Ch_1_labV12_max             204 non-null    float64
#  4    Ch_1_labV12_crest           204 non-null    float64
#  5    Ch_1_labV12_zcr             204 non-null    float64
#  6    Ch_1_labV12_spec_centroid   204 non-null    float64
#  7    Ch_1_labV12_spec_rolloff    204 non-null    float64
#  8    Ch_1_labV12_spec_flatness   204 non-null    float64
#  9    Ch_1_labV12_spec_bandwidth  204 non-null    float64
#  10   Ch_1_labV12_band_0          204 non-null    float64
#  11   Ch_1_labV12_band_1          204 non-null    float64
#  12   Ch_1_labV12_band_2          204 non-null    float64
#  13   Ch_1_labV12_band_3          204 non-null    float64
#  14   Ch_1_labV12_band_4          204 non-null    float64
#  15   Ch_1_labV12_mfcc_1          204 non-null    float64
#  16   Ch_1_labV12_mfcc_2          204 non-null    float64
#  17   Ch_1_labV12_mfcc_3          204 non-null    float64
#  18   Ch_1_labV12_mfcc_4          204 non-null    float64
#  19   Ch_1_labV12_mfcc_5          204 non-null    float64
#  20   Ch_1_labV12_mfcc_6          204 non-null    float64
#  21   Ch_1_labV12_mfcc_7          204 non-null    float64
#  22   Ch_1_labV12_mfcc_8          204 non-null    float64
#  23   Ch_1_labV12_mfcc_9          204 non-null    float64
#  24   Ch_1_labV12_mfcc_10         204 non-null    float64
#  25   Ch_1_labV12_mfcc_11         204 non-null    float64
#  26   Ch_1_labV12_mfcc_12         204 non-null    float64
#  27   Ch_1_labV12_mfcc_13         204 non-null    float64
#  28   Ch_2_labV12_rms             204 non-null    float64
#  29   Ch_2_labV12_mean            204 non-null    float64
#  30   Ch_2_labV12_std             204 non-null    float64
#  31   Ch_2_labV12_max             204 non-null    float64
#  32   Ch_2_labV12_crest           204 non-null    float64
#  33   Ch_2_labV12_zcr             204 non-null    float64
#  34   Ch_2_labV12_spec_centroid   204 non-null    float64
#  35   Ch_2_labV12_spec_rolloff    204 non-null    float64
#  36   Ch_2_labV12_spec_flatness   204 non-null    float64
#  37   Ch_2_labV12_spec_bandwidth  204 non-null    float64
#  38   Ch_2_labV12_band_0          204 non-null    float64
#  39   Ch_2_labV12_band_1          204 non-null    float64
#  40   Ch_2_labV12_band_2          204 non-null    float64
#  41   Ch_2_labV12_band_3          204 non-null    float64
#  42   Ch_2_labV12_band_4          204 non-null    float64
#  43   Ch_2_labV12_mfcc_1          204 non-null    float64
#  44   Ch_2_labV12_mfcc_2          204 non-null    float64
#  45   Ch_2_labV12_mfcc_3          204 non-null    float64
#  46   Ch_2_labV12_mfcc_4          204 non-null    float64
#  47   Ch_2_labV12_mfcc_5          204 non-null    float64
#  48   Ch_2_labV12_mfcc_6          204 non-null    float64
#  49   Ch_2_labV12_mfcc_7          204 non-null    float64
#  50   Ch_2_labV12_mfcc_8          204 non-null    float64
#  51   Ch_2_labV12_mfcc_9          204 non-null    float64
#  52   Ch_2_labV12_mfcc_10         204 non-null    float64
#  53   Ch_2_labV12_mfcc_11         204 non-null    float64
#  54   Ch_2_labV12_mfcc_12         204 non-null    float64
#  55   Ch_2_labV12_mfcc_13         204 non-null    float64
#  56   Ch_3_labV12_rms             204 non-null    float64
#  57   Ch_3_labV12_mean            204 non-null    float64
#  58   Ch_3_labV12_std             204 non-null    float64
#  59   Ch_3_labV12_max             204 non-null    float64
#  60   Ch_3_labV12_crest           204 non-null    float64
#  61   Ch_3_labV12_zcr             204 non-null    float64
#  62   Ch_3_labV12_spec_centroid   204 non-null    float64
#  63   Ch_3_labV12_spec_rolloff    204 non-null    float64
#  64   Ch_3_labV12_spec_flatness   204 non-null    float64
#  65   Ch_3_labV12_spec_bandwidth  204 non-null    float64
#  66   Ch_3_labV12_band_0          204 non-null    float64
#  67   Ch_3_labV12_band_1          204 non-null    float64
#  68   Ch_3_labV12_band_2          204 non-null    float64
#  69   Ch_3_labV12_band_3          204 non-null    float64
#  70   Ch_3_labV12_band_4          204 non-null    float64
#  71   Ch_3_labV12_mfcc_1          204 non-null    float64
#  72   Ch_3_labV12_mfcc_2          204 non-null    float64
#  73   Ch_3_labV12_mfcc_3          204 non-null    float64
#  74   Ch_3_labV12_mfcc_4          204 non-null    float64
#  75   Ch_3_labV12_mfcc_5          204 non-null    float64
#  76   Ch_3_labV12_mfcc_6          204 non-null    float64
#  77   Ch_3_labV12_mfcc_7          204 non-null    float64
#  78   Ch_3_labV12_mfcc_8          204 non-null    float64
#  79   Ch_3_labV12_mfcc_9          204 non-null    float64
#  80   Ch_3_labV12_mfcc_10         204 non-null    float64
#  81   Ch_3_labV12_mfcc_11         204 non-null    float64
#  82   Ch_3_labV12_mfcc_12         204 non-null    float64
#  83   Ch_3_labV12_mfcc_13         204 non-null    float64
#  84   Ch_4_labV12_rms             204 non-null    float64
#  85   Ch_4_labV12_mean            204 non-null    float64
#  86   Ch_4_labV12_std             204 non-null    float64
#  87   Ch_4_labV12_max             204 non-null    float64
#  88   Ch_4_labV12_crest           204 non-null    float64
#  89   Ch_4_labV12_zcr             204 non-null    float64
#  90   Ch_4_labV12_spec_centroid   204 non-null    float64
#  91   Ch_4_labV12_spec_rolloff    204 non-null    float64
#  92   Ch_4_labV12_spec_flatness   204 non-null    float64
#  93   Ch_4_labV12_spec_bandwidth  204 non-null    float64
#  94   Ch_4_labV12_band_0          204 non-null    float64
#  95   Ch_4_labV12_band_1          204 non-null    float64
#  96   Ch_4_labV12_band_2          204 non-null    float64
#  97   Ch_4_labV12_band_3          204 non-null    float64
#  98   Ch_4_labV12_band_4          204 non-null    float64
#  99   Ch_4_labV12_mfcc_1          204 non-null    float64
#  100  Ch_4_labV12_mfcc_2          204 non-null    float64
#  101  Ch_4_labV12_mfcc_3          204 non-null    float64
#  102  Ch_4_labV12_mfcc_4          204 non-null    float64
#  103  Ch_4_labV12_mfcc_5          204 non-null    float64
#  104  Ch_4_labV12_mfcc_6          204 non-null    float64
#  105  Ch_4_labV12_mfcc_7          204 non-null    float64
#  106  Ch_4_labV12_mfcc_8          204 non-null    float64
#  107  Ch_4_labV12_mfcc_9          204 non-null    float64
#  108  Ch_4_labV12_mfcc_10         204 non-null    float64
#  109  Ch_4_labV12_mfcc_11         204 non-null    float64
#  110  Ch_4_labV12_mfcc_12         204 non-null    float64
#  111  Ch_4_labV12_mfcc_13         204 non-null    float64
#  112  NAWSSound_rms               199 non-null    float64
#  113  NAWSSound_mean              199 non-null    float64
#  114  NAWSSound_std               199 non-null    float64
#  115  NAWSSound_max               199 non-null    float64
#  116  NAWSSound_crest             199 non-null    float64
#  117  NAWSSound_zcr               199 non-null    float64
#  118  NAWSSound_spec_centroid     199 non-null    float64
#  119  NAWSSound_spec_rolloff      199 non-null    float64
#  120  NAWSSound_spec_flatness     199 non-null    float64
#  121  NAWSSound_spec_bandwidth    199 non-null    float64
#  122  NAWSSound_band_0            199 non-null    float64
#  123  NAWSSound_band_1            199 non-null    float64
#  124  NAWSSound_band_2            199 non-null    float64
#  125  NAWSSound_band_3            199 non-null    float64
#  126  NAWSSound_band_4            199 non-null    float64
#  127  NAWSSound_mfcc_1            199 non-null    float64
#  128  NAWSSound_mfcc_2            199 non-null    float64
#  129  NAWSSound_mfcc_3            199 non-null    float64
#  130  NAWSSound_mfcc_4            199 non-null    float64
#  131  NAWSSound_mfcc_5            199 non-null    float64
#  132  NAWSSound_mfcc_6            199 non-null    float64
#  133  NAWSSound_mfcc_7            199 non-null    float64
#  134  NAWSSound_mfcc_8            199 non-null    float64
#  135  NAWSSound_mfcc_9            199 non-null    float64
#  136  NAWSSound_mfcc_10           199 non-null    float64
#  137  NAWSSound_mfcc_11           199 non-null    float64
#  138  NAWSSound_mfcc_12           199 non-null    float64
#  139  NAWSSound_mfcc_13           199 non-null    float64
#  140  mic_iso_rms                 204 non-null    float64
#  141  mic_iso_mean                204 non-null    float64
#  142  mic_iso_std                 204 non-null    float64
#  143  mic_iso_max                 204 non-null    float64
#  144  mic_iso_crest               204 non-null    float64
#  145  mic_iso_zcr                 204 non-null    float64
#  146  mic_iso_spec_centroid       204 non-null    float64
#  147  mic_iso_spec_rolloff        204 non-null    float64
#  148  mic_iso_spec_flatness       204 non-null    float64
#  149  mic_iso_spec_bandwidth      204 non-null    float64
#  150  mic_iso_band_0              204 non-null    float64
#  151  mic_iso_band_1              204 non-null    float64
#  152  mic_iso_band_2              204 non-null    float64
#  153  mic_iso_band_3              204 non-null    float64
#  154  mic_iso_band_4              204 non-null    float64
#  155  mic_iso_mfcc_1              204 non-null    float64
#  156  mic_iso_mfcc_2              204 non-null    float64
#  157  mic_iso_mfcc_3              204 non-null    float64
#  158  mic_iso_mfcc_4              204 non-null    float64
#  159  mic_iso_mfcc_5              204 non-null    float64
#  160  mic_iso_mfcc_6              204 non-null    float64
#  161  mic_iso_mfcc_7              204 non-null    float64
#  162  mic_iso_mfcc_8              204 non-null    float64
#  163  mic_iso_mfcc_9              204 non-null    float64
#  164  mic_iso_mfcc_10             204 non-null    float64
#  165  mic_iso_mfcc_11             204 non-null    float64
#  166  mic_iso_mfcc_12             204 non-null    float64
#  167  mic_iso_mfcc_13             204 non-null    float64
#  168  mic_2m_rms                  204 non-null    float64
#  169  mic_2m_mean                 204 non-null    float64
#  170  mic_2m_std                  204 non-null    float64
#  171  mic_2m_max                  204 non-null    float64
#  172  mic_2m_crest                204 non-null    float64
#  173  mic_2m_zcr                  204 non-null    float64
#  174  mic_2m_spec_centroid        204 non-null    float64
#  175  mic_2m_spec_rolloff         204 non-null    float64
#  176  mic_2m_spec_flatness        204 non-null    float64
#  177  mic_2m_spec_bandwidth       204 non-null    float64
#  178  mic_2m_band_0               204 non-null    float64
#  179  mic_2m_band_1               204 non-null    float64
#  180  mic_2m_band_2               204 non-null    float64
#  181  mic_2m_band_3               204 non-null    float64
#  182  mic_2m_band_4               204 non-null    float64
#  183  mic_2m_mfcc_1               204 non-null    float64
#  184  mic_2m_mfcc_2               204 non-null    float64
#  185  mic_2m_mfcc_3               204 non-null    float64
#  186  mic_2m_mfcc_4               204 non-null    float64
#  187  mic_2m_mfcc_5               204 non-null    float64
#  188  mic_2m_mfcc_6               204 non-null    float64
#  189  mic_2m_mfcc_7               204 non-null    float64
#  190  mic_2m_mfcc_8               204 non-null    float64
#  191  mic_2m_mfcc_9               204 non-null    float64
#  192  mic_2m_mfcc_10              204 non-null    float64
#  193  mic_2m_mfcc_11              204 non-null    float64
#  194  mic_2m_mfcc_12              204 non-null    float64
#  195  mic_2m_mfcc_13              204 non-null    float64
#  196  file_path                   204 non-null    object
#  197  file_stem                   204 non-null    object
#  198  vehicle                     204 non-null    object
#  199  tyre_ID                     204 non-null    int64
#  200  track_ID                    204 non-null    int64
#  201  measure                     204 non-null    object
#  202  date                        204 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(196), int64(2), object(4)
# memory usage: 323.7+ KB

# %% [markdown]
# ### Missing values
#
# mic_iso channels 151/204 non-null
#
# track211 ID.4 tyre3 is missing mic iso, contains however "MikrofonOst" & "MikrofonWest" with similar sample rates
# (btw regular files also contain a "mic_2m" additionally to "mic_iso")
#
# This was a naming issue and is solved now! -> 0 missing rows

# %%
# Get the filenames of all files with empty mic_iso data from the dataframe
missing_iso_paths = df[df["mic_iso_rms"].isna()]["file_path"].tolist()
print(f"Files with missing mic_iso data: {len(missing_iso_paths)}")
for path in missing_iso_paths:
    print(os.path.basename(path))
# Out:
# Files with missing mic_iso data: 0

# %%
# Sanity check if the channel is actually missing
test_path = (
    DATA_ROOT / "track211/01_ID.4/tyre3/track211_ID.4_tyre3_2pt6_vr45_2025-07-11_10-24-28.h5"
)
with h5py.File(test_path, "r") as h5file:
    for key in h5file.keys():
        print(f"{key}: {np.array(h5file[key]).shape}, attrs: {h5file[key].attrs.keys()}")
# Out:
# Antrieb: (1, 183600), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# BCM1_Aussen_Temp: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_1_labV12: (1, 244800), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_2_labV12: (1, 244800), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_3_labV12: (1, 244800), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_4_labV12: (1, 244800), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_5_labV12: (1, 244800), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_0_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_12_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_16_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_18_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_20_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_22_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_24_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_26_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_28_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_32_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_36_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_4_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Cnt_CAN_Sig_8_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# EM1_IstMoment_C: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# EM1_Raddrehzahl_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESC_Allrad_Antei: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_Gierrate_CA: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_HL_Bremsmome: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_HR_Bremsmome: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_VL_Bremsmome: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_VL_Radgeschw: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_VR_Bremsmome: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_VR_Radgeschw: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_VZ_Gierrate: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_Vorsteuerung: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_v_Signal_CA: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Fahrwerk: (1, 183600), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# GPS: (1, 344064), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# IMA: (1, 183600), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# IREnd: (3, 80, 80), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# IRStart: (3, 80, 80), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# LWI_Lenkradwinke: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Lat_CAN_Sig_13_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Long_CAN_Sig_12: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# MO_Gangposition: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Mode_CAN_Sig_16: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Mode_CAN_Sig_21: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# NAWSPressure: (1, 763), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# NAWSSound: (1, 170912), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# NAWSTemperature: (1, 763), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# OBD_Aussen_Temp_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# OCU_Privacymode_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# PSD_LR_Fahrzeug_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# RS_Regenmenge_C: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_Alt_CAN_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_Lat_CAN_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_Long_CAN: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_pitch_CA: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_roll_CAN: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_vEast_CA: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_vNorth_C: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_vUp_CAN_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_yaw_CAN_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# TSMomBegrenzung: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# aCnt_CAN_Sig_40: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# aInsSolState_CA: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# a_x_CAN_Sig_4_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# a_y_CAN_Sig_3_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# a_z_CAN_Sig_5_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# bSats_CAN_Sig_2: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# bUTC_CAN_Sig_24: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# cGpsSolState_CA: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# cLeapSec_CAN_Si: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# dDiffAge_CAN_Si: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# dGpsPosType_CAN: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# dpitch_CAN_Sig_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# droll_CAN_Sig_1: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# dyaw_CAN_Sig_2_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# eSolAge_CAN_Sig: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# mic_2m: (1, 344064), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# mic_iso: (1, 344064), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# pitch_CAN_Sig_7: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# roll_CAN_Sig_6_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# v_east_CAN_Sig_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# v_north_CAN_Sig: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# v_up_CAN_Sig_11: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# xAlt_CAN_Sig_14: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# yaw_CAN_Sig_15_: (1, 5100), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>

# %% [markdown]
# NAWSSound channels 199/204 non-null

# %% [markdown]
# 5 track211 Q8 e-tron tyre12 files are missing the NAWS channel, I'll fill it with means of the respective group

# %%
# Get the filenames of all files with empty NAWSSound data from the dataframe

missing_nawssound_paths = df[df["NAWSSound_rms"].isna()]["file_path"].tolist()
print(f"Files with missing NAWSSound data: {len(missing_nawssound_paths)}")
for path in missing_nawssound_paths:
    print(os.path.basename(path))
# Out:
# Files with missing NAWSSound data: 5
# track211_Q8 e-tron_tyre12_meas5_2p5_1_2025-08-15_12-13-33.h5
# track211_Q8 e-tron_tyre12_meas6_2p5_1_2025-08-15_12-34-39.h5
# track211_Q8 e-tron_tyre12_meas6_2p5_1_2025-08-15_12-30-46.h5
# track211_Q8 e-tron_tyre12_meas3_2p5_1_2025-08-15_12-02-31.h5
# track211_Q8 e-tron_tyre12_meas6_2p5_1_2025-08-15_12-32-47.h5

# %%
# Sanity check if the channel is actually missing
test_path = (
    DATA_ROOT
    / "track211/02_Q8 e-tron/tyre12/track211_Q8 e-tron_tyre12_meas3_2p5_1_2025-08-15_12-02-31.h5"
)
with h5py.File(test_path, "r") as h5file:
    for key in h5file.keys():
        print(f"{key}: {np.array(h5file[key]).shape}, attrs: {h5file[key].attrs.keys()}")
# Out:
# BCM1_Aussen_Temp: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# CAN1_labCTRLI_: (1, 99000), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# CAN2_labDX_B: (1, 198000), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_1_labV12: (1, 132000), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_2_labV12: (1, 132000), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_3_labV12: (1, 132000), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_4_labV12: (1, 132000), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Ch_5_labV12: (1, 132000), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# EPS_Motormoment: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_HL_Radgeschw: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_HR_Radgeschw: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_VL_Radgeschw: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# ESP_VR_Radgeschw: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# GPS: (1, 245760), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# IREnd: (3, 80, 80), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# IRStart: (3, 80, 80), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Lat_CAN_Sig_13_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# Long_CAN_Sig_12: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# MO_NGS_Gangpos_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# RS_Regenmenge_C: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_Alt_CAN_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_Lat_CAN_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_Long_CAN: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_pitch_CA: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_roll_CAN: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_vEast_CA: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_vNorth_C: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_vUp_CAN_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# StdDev_yaw_CAN_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# aInsSolState_CA: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# a_x_CAN_Sig_4_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# a_y_CAN_Sig_3_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# a_z_CAN_Sig_5_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# bSats_CAN_Sig_2: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# bUTC_CAN_Sig_24: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# cGpsSolState_CA: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# cLeapSec_CAN_Si: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# dDiffAge_CAN_Si: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# dGpsPosType_CAN: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# dpitch_CAN_Sig_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# droll_CAN_Sig_1: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# dyaw_CAN_Sig_2_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# eSolAge_CAN_Sig: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# mic_2m: (1, 245760), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# mic_iso: (1, 245760), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# pitch_CAN_Sig_7: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# roll_CAN_Sig_6_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# v_east_CAN_Sig_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# v_north_CAN_Sig: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# v_up_CAN_Sig_11: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# xAlt_CAN_Sig_14: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>
# yaw_CAN_Sig_15_: (1, 2750), attrs: <KeysViewHDF5 ['sample_rate', 'unit']>

# %% [markdown]
# ### Build the cleaned dataset

# %%
list(df.columns)
# Out:
# ['Ch_1_labV12_rms',
#  'Ch_1_labV12_mean',
#  'Ch_1_labV12_std',
#  'Ch_1_labV12_max',
#  'Ch_1_labV12_crest',
#  'Ch_1_labV12_zcr',
#  'Ch_1_labV12_spec_centroid',
#  'Ch_1_labV12_spec_rolloff',
#  'Ch_1_labV12_spec_flatness',
#  'Ch_1_labV12_spec_bandwidth',
#  'Ch_1_labV12_band_0',
#  'Ch_1_labV12_band_1',
#  'Ch_1_labV12_band_2',
#  'Ch_1_labV12_band_3',
#  'Ch_1_labV12_band_4',
#  'Ch_1_labV12_mfcc_1',
#  'Ch_1_labV12_mfcc_2',
#  'Ch_1_labV12_mfcc_3',
#  'Ch_1_labV12_mfcc_4',
#  'Ch_1_labV12_mfcc_5',
#  'Ch_1_labV12_mfcc_6',
#  'Ch_1_labV12_mfcc_7',
#  'Ch_1_labV12_mfcc_8',
#  'Ch_1_labV12_mfcc_9',
#  'Ch_1_labV12_mfcc_10',
#  'Ch_1_labV12_mfcc_11',
#  'Ch_1_labV12_mfcc_12',
#  'Ch_1_labV12_mfcc_13',
#  'Ch_2_labV12_rms',
#  'Ch_2_labV12_mean',
#  'Ch_2_labV12_std',
#  'Ch_2_labV12_max',
#  'Ch_2_labV12_crest',
#  'Ch_2_labV12_zcr',
#  'Ch_2_labV12_spec_centroid',
#  'Ch_2_labV12_spec_rolloff',
#  'Ch_2_labV12_spec_flatness',
#  'Ch_2_labV12_spec_bandwidth',
#  'Ch_2_labV12_band_0',
#  'Ch_2_labV12_band_1',
#  'Ch_2_labV12_band_2',
#  'Ch_2_labV12_band_3',
#  'Ch_2_labV12_band_4',
#  'Ch_2_labV12_mfcc_1',
#  'Ch_2_labV12_mfcc_2',
#  'Ch_2_labV12_mfcc_3',
#  'Ch_2_labV12_mfcc_4',
#  'Ch_2_labV12_mfcc_5',
#  'Ch_2_labV12_mfcc_6',
#  'Ch_2_labV12_mfcc_7',
#  'Ch_2_labV12_mfcc_8',
#  'Ch_2_labV12_mfcc_9',
#  'Ch_2_labV12_mfcc_10',
#  'Ch_2_labV12_mfcc_11',
#  'Ch_2_labV12_mfcc_12',
#  'Ch_2_labV12_mfcc_13',
#  'Ch_3_labV12_rms',
#  'Ch_3_labV12_mean',
#  'Ch_3_labV12_std',
#  'Ch_3_labV12_max',
#  'Ch_3_labV12_crest',
#  'Ch_3_labV12_zcr',
#  'Ch_3_labV12_spec_centroid',
#  'Ch_3_labV12_spec_rolloff',
#  'Ch_3_labV12_spec_flatness',
#  'Ch_3_labV12_spec_bandwidth',
#  'Ch_3_labV12_band_0',
#  'Ch_3_labV12_band_1',
#  'Ch_3_labV12_band_2',
#  'Ch_3_labV12_band_3',
#  'Ch_3_labV12_band_4',
#  'Ch_3_labV12_mfcc_1',
#  'Ch_3_labV12_mfcc_2',
#  'Ch_3_labV12_mfcc_3',
#  'Ch_3_labV12_mfcc_4',
#  'Ch_3_labV12_mfcc_5',
#  'Ch_3_labV12_mfcc_6',
#  'Ch_3_labV12_mfcc_7',
#  'Ch_3_labV12_mfcc_8',
#  'Ch_3_labV12_mfcc_9',
#  'Ch_3_labV12_mfcc_10',
#  'Ch_3_labV12_mfcc_11',
#  'Ch_3_labV12_mfcc_12',
#  'Ch_3_labV12_mfcc_13',
#  'Ch_4_labV12_rms',
#  'Ch_4_labV12_mean',
#  'Ch_4_labV12_std',
#  'Ch_4_labV12_max',
#  'Ch_4_labV12_crest',
#  'Ch_4_labV12_zcr',
#  'Ch_4_labV12_spec_centroid',
#  'Ch_4_labV12_spec_rolloff',
#  'Ch_4_labV12_spec_flatness',
#  'Ch_4_labV12_spec_bandwidth',
#  'Ch_4_labV12_band_0',
#  'Ch_4_labV12_band_1',
#  'Ch_4_labV12_band_2',
#  'Ch_4_labV12_band_3',
#  'Ch_4_labV12_band_4',
#  'Ch_4_labV12_mfcc_1',
#  'Ch_4_labV12_mfcc_2',
#  'Ch_4_labV12_mfcc_3',
#  'Ch_4_labV12_mfcc_4',
#  'Ch_4_labV12_mfcc_5',
#  'Ch_4_labV12_mfcc_6',
#  'Ch_4_labV12_mfcc_7',
#  'Ch_4_labV12_mfcc_8',
#  'Ch_4_labV12_mfcc_9',
#  'Ch_4_labV12_mfcc_10',
#  'Ch_4_labV12_mfcc_11',
#  'Ch_4_labV12_mfcc_12',
#  'Ch_4_labV12_mfcc_13',
#  'NAWSSound_rms',
#  'NAWSSound_mean',
#  'NAWSSound_std',
#  'NAWSSound_max',
#  'NAWSSound_crest',
#  'NAWSSound_zcr',
#  'NAWSSound_spec_centroid',
#  'NAWSSound_spec_rolloff',
#  'NAWSSound_spec_flatness',
#  'NAWSSound_spec_bandwidth',
#  'NAWSSound_band_0',
#  'NAWSSound_band_1',
#  'NAWSSound_band_2',
#  'NAWSSound_band_3',
#  'NAWSSound_band_4',
#  'NAWSSound_mfcc_1',
#  'NAWSSound_mfcc_2',
#  'NAWSSound_mfcc_3',
#  'NAWSSound_mfcc_4',
#  'NAWSSound_mfcc_5',
#  'NAWSSound_mfcc_6',
#  'NAWSSound_mfcc_7',
#  'NAWSSound_mfcc_8',
#  'NAWSSound_mfcc_9',
#  'NAWSSound_mfcc_10',
#  'NAWSSound_mfcc_11',
#  'NAWSSound_mfcc_12',
#  'NAWSSound_mfcc_13',
#  'mic_iso_rms',
#  'mic_iso_mean',
#  'mic_iso_std',
#  'mic_iso_max',
#  'mic_iso_crest',
#  'mic_iso_zcr',
#  'mic_iso_spec_centroid',
#  'mic_iso_spec_rolloff',
#  'mic_iso_spec_flatness',
#  'mic_iso_spec_bandwidth',
#  'mic_iso_band_0',
#  'mic_iso_band_1',
#  'mic_iso_band_2',
#  'mic_iso_band_3',
#  'mic_iso_band_4',
#  'mic_iso_mfcc_1',
#  'mic_iso_mfcc_2',
#  'mic_iso_mfcc_3',
#  'mic_iso_mfcc_4',
#  'mic_iso_mfcc_5',
#  'mic_iso_mfcc_6',
#  'mic_iso_mfcc_7',
#  'mic_iso_mfcc_8',
#  'mic_iso_mfcc_9',
#  'mic_iso_mfcc_10',
#  'mic_iso_mfcc_11',
#  'mic_iso_mfcc_12',
#  'mic_iso_mfcc_13',
#  'mic_2m_rms',
#  'mic_2m_mean',
#  'mic_2m_std',
#  'mic_2m_max',
#  'mic_2m_crest',
#  'mic_2m_zcr',
#  'mic_2m_spec_centroid',
#  'mic_2m_spec_rolloff',
#  'mic_2m_spec_flatness',
#  'mic_2m_spec_bandwidth',
#  'mic_2m_band_0',
#  'mic_2m_band_1',
#  'mic_2m_band_2',
#  'mic_2m_band_3',
#  'mic_2m_band_4',
#  'mic_2m_mfcc_1',
#  'mic_2m_mfcc_2',
#  'mic_2m_mfcc_3',
#  'mic_2m_mfcc_4',
#  'mic_2m_mfcc_5',
#  'mic_2m_mfcc_6',
#  'mic_2m_mfcc_7',
#  'mic_2m_mfcc_8',
#  'mic_2m_mfcc_9',
#  'mic_2m_mfcc_10',
#  'mic_2m_mfcc_11',
#  'mic_2m_mfcc_12',
#  'mic_2m_mfcc_13',
#  'file_path',
#  'file_stem',
#  'vehicle',
#  'tyre_ID',
#  'track_ID',
#  'measure',
#  'date']

# %%
# Fill missing NAWSSound features with group-wise mean imputation

df_clean = df.copy()

naws_cols = [col for col in df_clean.columns if col.startswith("NAWSSound")]
group_cols = ["track_ID", "vehicle", "tyre_ID"]

for col in naws_cols:
    df_clean[col] = df_clean.groupby(group_cols)[col].transform(lambda g: g.fillna(g.mean()))

# If some groups have only NaN (rare), fill remaining with global mean
if df_clean[naws_cols].isna().any().any():
    print("Some NAWSSound groups have only NaN, filling with global mean.")
    df_clean[naws_cols] = df_clean[naws_cols].fillna(df_clean[naws_cols].mean())

# Drop the mic_iso channels
df_clean = df_clean.drop(columns=[col for col in df_clean.columns if col.startswith("mic_iso")])

# %%
df_clean.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 175 columns):
#  #    Column                      Non-Null Count  Dtype
# ---   ------                      --------------  -----
#  0    Ch_1_labV12_rms             204 non-null    float64
#  1    Ch_1_labV12_mean            204 non-null    float64
#  2    Ch_1_labV12_std             204 non-null    float64
#  3    Ch_1_labV12_max             204 non-null    float64
#  4    Ch_1_labV12_crest           204 non-null    float64
#  5    Ch_1_labV12_zcr             204 non-null    float64
#  6    Ch_1_labV12_spec_centroid   204 non-null    float64
#  7    Ch_1_labV12_spec_rolloff    204 non-null    float64
#  8    Ch_1_labV12_spec_flatness   204 non-null    float64
#  9    Ch_1_labV12_spec_bandwidth  204 non-null    float64
#  10   Ch_1_labV12_band_0          204 non-null    float64
#  11   Ch_1_labV12_band_1          204 non-null    float64
#  12   Ch_1_labV12_band_2          204 non-null    float64
#  13   Ch_1_labV12_band_3          204 non-null    float64
#  14   Ch_1_labV12_band_4          204 non-null    float64
#  15   Ch_1_labV12_mfcc_1          204 non-null    float64
#  16   Ch_1_labV12_mfcc_2          204 non-null    float64
#  17   Ch_1_labV12_mfcc_3          204 non-null    float64
#  18   Ch_1_labV12_mfcc_4          204 non-null    float64
#  19   Ch_1_labV12_mfcc_5          204 non-null    float64
#  20   Ch_1_labV12_mfcc_6          204 non-null    float64
#  21   Ch_1_labV12_mfcc_7          204 non-null    float64
#  22   Ch_1_labV12_mfcc_8          204 non-null    float64
#  23   Ch_1_labV12_mfcc_9          204 non-null    float64
#  24   Ch_1_labV12_mfcc_10         204 non-null    float64
#  25   Ch_1_labV12_mfcc_11         204 non-null    float64
#  26   Ch_1_labV12_mfcc_12         204 non-null    float64
#  27   Ch_1_labV12_mfcc_13         204 non-null    float64
#  28   Ch_2_labV12_rms             204 non-null    float64
#  29   Ch_2_labV12_mean            204 non-null    float64
#  30   Ch_2_labV12_std             204 non-null    float64
#  31   Ch_2_labV12_max             204 non-null    float64
#  32   Ch_2_labV12_crest           204 non-null    float64
#  33   Ch_2_labV12_zcr             204 non-null    float64
#  34   Ch_2_labV12_spec_centroid   204 non-null    float64
#  35   Ch_2_labV12_spec_rolloff    204 non-null    float64
#  36   Ch_2_labV12_spec_flatness   204 non-null    float64
#  37   Ch_2_labV12_spec_bandwidth  204 non-null    float64
#  38   Ch_2_labV12_band_0          204 non-null    float64
#  39   Ch_2_labV12_band_1          204 non-null    float64
#  40   Ch_2_labV12_band_2          204 non-null    float64
#  41   Ch_2_labV12_band_3          204 non-null    float64
#  42   Ch_2_labV12_band_4          204 non-null    float64
#  43   Ch_2_labV12_mfcc_1          204 non-null    float64
#  44   Ch_2_labV12_mfcc_2          204 non-null    float64
#  45   Ch_2_labV12_mfcc_3          204 non-null    float64
#  46   Ch_2_labV12_mfcc_4          204 non-null    float64
#  47   Ch_2_labV12_mfcc_5          204 non-null    float64
#  48   Ch_2_labV12_mfcc_6          204 non-null    float64
#  49   Ch_2_labV12_mfcc_7          204 non-null    float64
#  50   Ch_2_labV12_mfcc_8          204 non-null    float64
#  51   Ch_2_labV12_mfcc_9          204 non-null    float64
#  52   Ch_2_labV12_mfcc_10         204 non-null    float64
#  53   Ch_2_labV12_mfcc_11         204 non-null    float64
#  54   Ch_2_labV12_mfcc_12         204 non-null    float64
#  55   Ch_2_labV12_mfcc_13         204 non-null    float64
#  56   Ch_3_labV12_rms             204 non-null    float64
#  57   Ch_3_labV12_mean            204 non-null    float64
#  58   Ch_3_labV12_std             204 non-null    float64
#  59   Ch_3_labV12_max             204 non-null    float64
#  60   Ch_3_labV12_crest           204 non-null    float64
#  61   Ch_3_labV12_zcr             204 non-null    float64
#  62   Ch_3_labV12_spec_centroid   204 non-null    float64
#  63   Ch_3_labV12_spec_rolloff    204 non-null    float64
#  64   Ch_3_labV12_spec_flatness   204 non-null    float64
#  65   Ch_3_labV12_spec_bandwidth  204 non-null    float64
#  66   Ch_3_labV12_band_0          204 non-null    float64
#  67   Ch_3_labV12_band_1          204 non-null    float64
#  68   Ch_3_labV12_band_2          204 non-null    float64
#  69   Ch_3_labV12_band_3          204 non-null    float64
#  70   Ch_3_labV12_band_4          204 non-null    float64
#  71   Ch_3_labV12_mfcc_1          204 non-null    float64
#  72   Ch_3_labV12_mfcc_2          204 non-null    float64
#  73   Ch_3_labV12_mfcc_3          204 non-null    float64
#  74   Ch_3_labV12_mfcc_4          204 non-null    float64
#  75   Ch_3_labV12_mfcc_5          204 non-null    float64
#  76   Ch_3_labV12_mfcc_6          204 non-null    float64
#  77   Ch_3_labV12_mfcc_7          204 non-null    float64
#  78   Ch_3_labV12_mfcc_8          204 non-null    float64
#  79   Ch_3_labV12_mfcc_9          204 non-null    float64
#  80   Ch_3_labV12_mfcc_10         204 non-null    float64
#  81   Ch_3_labV12_mfcc_11         204 non-null    float64
#  82   Ch_3_labV12_mfcc_12         204 non-null    float64
#  83   Ch_3_labV12_mfcc_13         204 non-null    float64
#  84   Ch_4_labV12_rms             204 non-null    float64
#  85   Ch_4_labV12_mean            204 non-null    float64
#  86   Ch_4_labV12_std             204 non-null    float64
#  87   Ch_4_labV12_max             204 non-null    float64
#  88   Ch_4_labV12_crest           204 non-null    float64
#  89   Ch_4_labV12_zcr             204 non-null    float64
#  90   Ch_4_labV12_spec_centroid   204 non-null    float64
#  91   Ch_4_labV12_spec_rolloff    204 non-null    float64
#  92   Ch_4_labV12_spec_flatness   204 non-null    float64
#  93   Ch_4_labV12_spec_bandwidth  204 non-null    float64
#  94   Ch_4_labV12_band_0          204 non-null    float64
#  95   Ch_4_labV12_band_1          204 non-null    float64
#  96   Ch_4_labV12_band_2          204 non-null    float64
#  97   Ch_4_labV12_band_3          204 non-null    float64
#  98   Ch_4_labV12_band_4          204 non-null    float64
#  99   Ch_4_labV12_mfcc_1          204 non-null    float64
#  100  Ch_4_labV12_mfcc_2          204 non-null    float64
#  101  Ch_4_labV12_mfcc_3          204 non-null    float64
#  102  Ch_4_labV12_mfcc_4          204 non-null    float64
#  103  Ch_4_labV12_mfcc_5          204 non-null    float64
#  104  Ch_4_labV12_mfcc_6          204 non-null    float64
#  105  Ch_4_labV12_mfcc_7          204 non-null    float64
#  106  Ch_4_labV12_mfcc_8          204 non-null    float64
#  107  Ch_4_labV12_mfcc_9          204 non-null    float64
#  108  Ch_4_labV12_mfcc_10         204 non-null    float64
#  109  Ch_4_labV12_mfcc_11         204 non-null    float64
#  110  Ch_4_labV12_mfcc_12         204 non-null    float64
#  111  Ch_4_labV12_mfcc_13         204 non-null    float64
#  112  NAWSSound_rms               204 non-null    float64
#  113  NAWSSound_mean              204 non-null    float64
#  114  NAWSSound_std               204 non-null    float64
#  115  NAWSSound_max               204 non-null    float64
#  116  NAWSSound_crest             204 non-null    float64
#  117  NAWSSound_zcr               204 non-null    float64
#  118  NAWSSound_spec_centroid     204 non-null    float64
#  119  NAWSSound_spec_rolloff      204 non-null    float64
#  120  NAWSSound_spec_flatness     204 non-null    float64
#  121  NAWSSound_spec_bandwidth    204 non-null    float64
#  122  NAWSSound_band_0            204 non-null    float64
#  123  NAWSSound_band_1            204 non-null    float64
#  124  NAWSSound_band_2            204 non-null    float64
#  125  NAWSSound_band_3            204 non-null    float64
#  126  NAWSSound_band_4            204 non-null    float64
#  127  NAWSSound_mfcc_1            204 non-null    float64
#  128  NAWSSound_mfcc_2            204 non-null    float64
#  129  NAWSSound_mfcc_3            204 non-null    float64
#  130  NAWSSound_mfcc_4            204 non-null    float64
#  131  NAWSSound_mfcc_5            204 non-null    float64
#  132  NAWSSound_mfcc_6            204 non-null    float64
#  133  NAWSSound_mfcc_7            204 non-null    float64
#  134  NAWSSound_mfcc_8            204 non-null    float64
#  135  NAWSSound_mfcc_9            204 non-null    float64
#  136  NAWSSound_mfcc_10           204 non-null    float64
#  137  NAWSSound_mfcc_11           204 non-null    float64
#  138  NAWSSound_mfcc_12           204 non-null    float64
#  139  NAWSSound_mfcc_13           204 non-null    float64
#  140  mic_2m_rms                  204 non-null    float64
#  141  mic_2m_mean                 204 non-null    float64
#  142  mic_2m_std                  204 non-null    float64
#  143  mic_2m_max                  204 non-null    float64
#  144  mic_2m_crest                204 non-null    float64
#  145  mic_2m_zcr                  204 non-null    float64
#  146  mic_2m_spec_centroid        204 non-null    float64
#  147  mic_2m_spec_rolloff         204 non-null    float64
#  148  mic_2m_spec_flatness        204 non-null    float64
#  149  mic_2m_spec_bandwidth       204 non-null    float64
#  150  mic_2m_band_0               204 non-null    float64
#  151  mic_2m_band_1               204 non-null    float64
#  152  mic_2m_band_2               204 non-null    float64
#  153  mic_2m_band_3               204 non-null    float64
#  154  mic_2m_band_4               204 non-null    float64
#  155  mic_2m_mfcc_1               204 non-null    float64
#  156  mic_2m_mfcc_2               204 non-null    float64
#  157  mic_2m_mfcc_3               204 non-null    float64
#  158  mic_2m_mfcc_4               204 non-null    float64
#  159  mic_2m_mfcc_5               204 non-null    float64
#  160  mic_2m_mfcc_6               204 non-null    float64
#  161  mic_2m_mfcc_7               204 non-null    float64
#  162  mic_2m_mfcc_8               204 non-null    float64
#  163  mic_2m_mfcc_9               204 non-null    float64
#  164  mic_2m_mfcc_10              204 non-null    float64
#  165  mic_2m_mfcc_11              204 non-null    float64
#  166  mic_2m_mfcc_12              204 non-null    float64
#  167  mic_2m_mfcc_13              204 non-null    float64
#  168  file_path                   204 non-null    object
#  169  file_stem                   204 non-null    object
#  170  vehicle                     204 non-null    object
#  171  tyre_ID                     204 non-null    int64
#  172  track_ID                    204 non-null    int64
#  173  measure                     204 non-null    object
#  174  date                        204 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(168), int64(2), object(4)
# memory usage: 279.0+ KB

# %% [markdown]
# ### Create data split for baseline models

# %%
# # --- Features: all float64 mic features ---
# feature_cols = df_clean.select_dtypes(include=["float64"]).columns.tolist()
# print("Number of features:", len(feature_cols))

# X = df_clean[feature_cols].values
# y = df_clean["road_type"].values

# # Encode string labels to integers for xgboost
# le = LabelEncoder()
# y_enc = le.fit_transform(y)   # e.g. "track150" -> 0, "track211" -> 1
# print("Classes:", le.classes_)

# n_splits = 5
# skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# %%
# Explicitly exclude non-feature columns (safer than dtype selection alone)
non_feature_cols = ["track_ID", "vehicle", "tyre_ID", "file_stem", "file_path", "measure", "date"]
feature_cols = [
    c for c in df_clean.columns if c not in non_feature_cols and df_clean[c].dtype == "float64"
]

print("Number of features:", len(feature_cols))

X = df_clean[feature_cols].to_numpy()
y = df_clean["track_ID"].to_numpy()
groups = df_clean["vehicle"].to_numpy()

# Encode string labels to integers for XGBoost
le = LabelEncoder()
y_enc = le.fit_transform(y)
print("Classes:", le.classes_)

# LOGO splitter
logo = LeaveOneGroupOut()

# Stratifed K-Fold for inner splits
# WARNING: This will introduce data leakage!
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
# Out:
# Number of features: 168
# Classes: [150 211]

# %% [markdown]
# ### Training loop for RF and XGB

# %%
# rf_accs, rf_f1s = [], []
# xgb_accs, xgb_f1s = [], []

# fold_results = []

# for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
#     print(f"\n===== Fold {fold + 1}/{n_splits} =====")

#     X_train, X_val = X[train_idx], X[val_idx]
#     y_train, y_val = y[train_idx], y[val_idx]
#     y_train_enc, y_val_enc = y_enc[train_idx], y_enc[val_idx]

#     # ------------------ Random Forest ------------------
#     rf = RandomForestClassifier(
#         n_estimators=300,
#         max_depth=None,
#         min_samples_split=2,
#         min_samples_leaf=1,
#         n_jobs=-1,
#         random_state=42
#     )

#     rf.fit(X_train, y_train)
#     y_pred_rf = rf.predict(X_val)

#     rf_acc = accuracy_score(y_val, y_pred_rf)
#     rf_f1 = f1_score(y_val, y_pred_rf, average="weighted")

#     rf_accs.append(rf_acc)
#     rf_f1s.append(rf_f1)

#     print(f"RF  - acc: {rf_acc:.3f}, f1: {rf_f1:.3f}")
#     print(confusion_matrix(y_val, y_pred_rf))

#     # ------------------ XGBoost ------------------
#     xgb = XGBClassifier(
#         n_estimators=400,
#         max_depth=5,
#         learning_rate=0.05,
#         subsample=0.8,
#         colsample_bytree=0.8,
#         objective="binary:logistic",  # binary road-type problem
#         n_jobs=-1,
#         eval_metric="logloss",
#         random_state=42
#     )

#     xgb.fit(X_train, y_train_enc)
#     y_pred_xgb_enc = xgb.predict(X_val)
#     y_pred_xgb = le.inverse_transform(y_pred_xgb_enc)

#     xgb_acc = accuracy_score(y_val, y_pred_xgb)
#     xgb_f1 = f1_score(y_val, y_pred_xgb, average="weighted")

#     xgb_accs.append(xgb_acc)
#     xgb_f1s.append(xgb_f1)

#     print(f"XGB - acc: {xgb_acc:.3f}, f1: {xgb_f1:.3f}")
#     print(confusion_matrix(y_val, y_pred_xgb))

#     # store per-fold results
#     fold_results.append({
#         "fold": fold + 1,
#         "rf_acc": rf_acc,
#         "rf_f1": rf_f1,
#         "xgb_acc": xgb_acc,
#         "xgb_f1": xgb_f1
#     })

# %%
rf_accs, rf_f1s = [], []
xgb_accs, xgb_f1s = [], []
fold_results = []

# Optional: to accumulate global confusion matrices across folds
# (nice for seminar slides)
labels = le.classes_
rf_cm_total = np.zeros((len(labels), len(labels)), dtype=int)
xgb_cm_total = np.zeros((len(labels), len(labels)), dtype=int)

for fold, (train_idx, test_idx) in enumerate(logo.split(X, y, groups=groups), start=1):
    held_out_car = groups[test_idx][0]
    print(f"\n===== LOGO Fold {fold} | Held-out car: {held_out_car} =====")
    print(f"Train n={len(train_idx)}, Test n={len(test_idx)}")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    y_train_enc, y_test_enc = y_enc[train_idx], y_enc[test_idx]

    # ------------------ Random Forest ------------------
    rf = RandomForestClassifier(
        n_estimators=300,
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        n_jobs=-1,
        random_state=42,
    )

    rf.fit(X_train, y_train)
    y_pred_rf = rf.predict(X_test)

    rf_acc = accuracy_score(y_test, y_pred_rf)
    rf_f1 = f1_score(y_test, y_pred_rf, average="weighted")

    rf_accs.append(rf_acc)
    rf_f1s.append(rf_f1)

    cm_rf = confusion_matrix(y_test, y_pred_rf, labels=labels)
    rf_cm_total += cm_rf

    print(f"RF  - acc: {rf_acc:.3f}, f1: {rf_f1:.3f}")
    print(cm_rf)

    # ------------------ XGBoost ------------------
    # For 2-class problems you can use binary:logistic.
    # If you ever add more road types, switch to multi:softprob + num_class.
    xgb = XGBClassifier(
        n_estimators=400,
        max_depth=5,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        objective="binary:logistic",
        n_jobs=-1,
        eval_metric="logloss",
        random_state=42,
    )

    xgb.fit(X_train, y_train_enc)
    y_pred_xgb_enc = xgb.predict(X_test)
    y_pred_xgb = le.inverse_transform(y_pred_xgb_enc.astype(int))

    xgb_acc = accuracy_score(y_test, y_pred_xgb)
    xgb_f1 = f1_score(y_test, y_pred_xgb, average="weighted")

    xgb_accs.append(xgb_acc)
    xgb_f1s.append(xgb_f1)

    cm_xgb = confusion_matrix(y_test, y_pred_xgb, labels=labels)
    xgb_cm_total += cm_xgb

    print(f"XGB - acc: {xgb_acc:.3f}, f1: {xgb_f1:.3f}")
    print(cm_xgb)

    fold_results.append(
        {
            "fold": fold,
            "held_out_car": held_out_car,
            "n_test": len(test_idx),
            "rf_acc": rf_acc,
            "rf_f1": rf_f1,
            "xgb_acc": xgb_acc,
            "xgb_f1": xgb_f1,
        }
    )


# --------------- Summary ---------------
print("\n===== LOGO Summary (per held-out car) =====")
for r in fold_results:
    print(f"{r['held_out_car']}: RF acc={r['rf_acc']:.3f}, XGB acc={r['xgb_acc']:.3f}")

print("\n===== Overall (mean ± std) =====")
print(
    f"RF  acc: {np.mean(rf_accs):.3f} ± {np.std(rf_accs):.3f} | "
    f"f1: {np.mean(rf_f1s):.3f} ± {np.std(rf_f1s):.3f}"
)
print(
    f"XGB acc: {np.mean(xgb_accs):.3f} ± {np.std(xgb_accs):.3f} | "
    f"f1: {np.mean(xgb_f1s):.3f} ± {np.std(xgb_f1s):.3f}"
)

print("\nRF total confusion matrix (rows=true, cols=pred):")
print(rf_cm_total)
print("\nXGB total confusion matrix (rows=true, cols=pred):")
print(xgb_cm_total)
print("\nLabel order:", labels)
# Out:
# ===== LOGO Fold 1 | Held-out car: E-Golf =====
# Train n=179, Test n=25
# RF  - acc: 0.640, f1: 0.642
# [[ 6  4]
#  [ 5 10]]
# XGB - acc: 0.760, f1: 0.760
# [[ 7  3]
#  [ 3 12]]
#
# ===== LOGO Fold 2 | Held-out car: ID.4 =====
# Train n=115, Test n=89
# RF  - acc: 0.876, f1: 0.855
# [[ 1  8]
#  [ 3 77]]
# XGB - acc: 0.899, f1: 0.881
# [[ 2  7]
#  [ 2 78]]
#
# ===== LOGO Fold 3 | Held-out car: Q8 e-tron =====
# Train n=141, Test n=63
# RF  - acc: 0.714, f1: 0.622
# [[ 1 17]
#  [ 1 44]]
# XGB - acc: 0.730, f1: 0.707
# [[ 6 12]
#  [ 5 40]]
#
# ===== LOGO Fold 4 | Held-out car: Taycan =====
# Train n=177, Test n=27
# RF  - acc: 0.667, f1: 0.533
# [[ 0  9]
#  [ 0 18]]
# XGB - acc: 0.667, f1: 0.533
# [[ 0  9]
#  [ 0 18]]
#
# ===== LOGO Summary (per held-out car) =====
# E-Golf: RF acc=0.640, XGB acc=0.760
# ID.4: RF acc=0.876, XGB acc=0.899
# Q8 e-tron: RF acc=0.714, XGB acc=0.730
# Taycan: RF acc=0.667, XGB acc=0.667
#
# ===== Overall (mean ± std) =====
# RF  acc: 0.724 ± 0.092 | f1: 0.663 ± 0.118
# XGB acc: 0.764 ± 0.085 | f1: 0.720 ± 0.125
#
# RF total confusion matrix (rows=true, cols=pred):
# [[  8  38]
#  [  9 149]]
#
# XGB total confusion matrix (rows=true, cols=pred):
# [[ 15  31]
#  [ 10 148]]
#
# Label order: [150 211]

# %%
results_df = pd.DataFrame(fold_results)
print("\nPer-fold results:")
print(results_df)

print("\n===== CV Summary =====")
print(f"RF  mean acc: {np.mean(rf_accs):.3f} ± {np.std(rf_accs):.3f}")
print(f"RF  mean f1 : {np.mean(rf_f1s):.3f} ± {np.std(rf_f1s):.3f}")
print(f"XGB mean acc: {np.mean(xgb_accs):.3f} ± {np.std(xgb_accs):.3f}")
print(f"XGB mean f1 : {np.mean(xgb_f1s):.3f} ± {np.std(xgb_f1s):.3f}")
# Out:
# Per-fold results:
#    fold held_out_car  n_test    rf_acc     rf_f1   xgb_acc    xgb_f1
# 0     1       E-Golf      25  0.640000  0.642365  0.760000  0.760000
# 1     2         ID.4      89  0.876404  0.854509  0.898876  0.880962
# 2     3    Q8 e-tron      63  0.714286  0.621563  0.730159  0.707328
# 3     4       Taycan      27  0.666667  0.533333  0.666667  0.533333
#
# ===== CV Summary =====
# RF  mean acc: 0.724 ± 0.092
# RF  mean f1 : 0.663 ± 0.118
# XGB mean acc: 0.764 ± 0.085
# XGB mean f1 : 0.720 ± 0.125

# %%
sns.set_style("whitegrid")

palette = ["mediumseagreen", "royalblue"]

# 1) Accuracy comparison
acc_plot_df = results_df.melt(
    id_vars="fold",
    value_vars=["rf_acc", "xgb_acc"],
    var_name="model",
    value_name="accuracy",
)
acc_plot_df["model"] = acc_plot_df["model"].map({"rf_acc": "Random Forest", "xgb_acc": "XGBoost"})

plt.figure(figsize=(6, 4))
sns.barplot(data=acc_plot_df, x="fold", y="accuracy", hue="model", palette=palette)
plt.ylim(0, 1)
plt.title("Per-fold Accuracy")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.tight_layout()
# plt.show()
plt.savefig(ROOT_DIR / "plots" / "accuracy_comparison.pdf", dpi=300)

# 2) F1-score comparison
f1_plot_df = results_df.melt(
    id_vars="fold",
    value_vars=["rf_f1", "xgb_f1"],
    var_name="model",
    value_name="f1",
)
f1_plot_df["model"] = f1_plot_df["model"].map({"rf_f1": "Random Forest", "xgb_f1": "XGBoost"})

plt.figure(figsize=(6, 4))
sns.barplot(data=f1_plot_df, x="fold", y="f1", hue="model", palette=palette)
plt.ylim(0, 1)
plt.title("Per-fold F1-score")
plt.xlabel("Fold")
plt.ylabel("F1-score")
plt.legend(title="Model")
plt.tight_layout()
# plt.show()
plt.savefig(ROOT_DIR / "plots" / "f1score_comparison.pdf", dpi=300)

# %% [markdown]
# ### Training loop for RF and XGB with oversampling

# %%
rf_accs, rf_f1s = [], []
xgb_accs, xgb_f1s = [], []

fold_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
    print(f"\n===== Fold {fold + 1}/{n_splits} =====")

    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    y_train_enc, y_val_enc = y_enc[train_idx], y_enc[val_idx]

    # ------------------ Random Forest ------------------
    rf = RandomForestClassifier(
        n_estimators=300,
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        class_weight={150: 1.0, 211: 0.3},
        n_jobs=-1,
        random_state=42,
    )

    rf.fit(X_train, y_train)
    y_pred_rf = rf.predict(X_val)

    rf_acc = accuracy_score(y_val, y_pred_rf)
    rf_f1 = f1_score(y_val, y_pred_rf, average="weighted")

    rf_accs.append(rf_acc)
    rf_f1s.append(rf_f1)

    print(f"RF  - acc: {rf_acc:.3f}, f1: {rf_f1:.3f}")
    print(confusion_matrix(y_val, y_pred_rf))

    # ------------------ XGBoost ------------------
    xgb = XGBClassifier(
        n_estimators=400,
        max_depth=5,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        scale_pos_weight=0.3,
        objective="binary:logistic",  # binary road-type problem
        n_jobs=-1,
        eval_metric="logloss",
        random_state=42,
    )

    xgb.fit(X_train, y_train_enc)
    y_pred_xgb_enc = xgb.predict(X_val)
    y_pred_xgb = le.inverse_transform(y_pred_xgb_enc)

    xgb_acc = accuracy_score(y_val, y_pred_xgb)
    xgb_f1 = f1_score(y_val, y_pred_xgb, average="weighted")

    xgb_accs.append(xgb_acc)
    xgb_f1s.append(xgb_f1)

    print(f"XGB - acc: {xgb_acc:.3f}, f1: {xgb_f1:.3f}")
    print(confusion_matrix(y_val, y_pred_xgb))

    # store per-fold results
    fold_results.append(
        {"fold": fold + 1, "rf_acc": rf_acc, "rf_f1": rf_f1, "xgb_acc": xgb_acc, "xgb_f1": xgb_f1}
    )
# Out:
# ===== Fold 1/5 =====
# RF  - acc: 0.829, f1: 0.807
# [[ 4  6]
#  [ 1 30]]
# XGB - acc: 0.756, f1: 0.746
# [[ 4  6]
#  [ 4 27]]
#
# ===== Fold 2/5 =====
# RF  - acc: 0.854, f1: 0.837
# [[ 4  5]
#  [ 1 31]]
# XGB - acc: 0.951, f1: 0.949
# [[ 7  2]
#  [ 0 32]]
#
# ===== Fold 3/5 =====
# RF  - acc: 0.878, f1: 0.869
# [[ 5  4]
#  [ 1 31]]
# XGB - acc: 0.829, f1: 0.841
# [[ 8  1]
#  [ 6 26]]
#
# ===== Fold 4/5 =====
# RF  - acc: 0.854, f1: 0.823
# [[ 3  6]
#  [ 0 32]]
# XGB - acc: 0.878, f1: 0.875
# [[ 6  3]
#  [ 2 30]]
#
# ===== Fold 5/5 =====
# RF  - acc: 0.850, f1: 0.819
# [[ 3  6]
#  [ 0 31]]
# XGB - acc: 0.850, f1: 0.843
# [[ 5  4]
#  [ 2 29]]

# %%
results_df = pd.DataFrame(fold_results)
print("\nPer-fold results:")
print(results_df)

print("\n===== CV Summary =====")
print(f"RF  mean acc: {np.mean(rf_accs):.3f} ± {np.std(rf_accs):.3f}")
print(f"RF  mean f1 : {np.mean(rf_f1s):.3f} ± {np.std(rf_f1s):.3f}")
print(f"XGB mean acc: {np.mean(xgb_accs):.3f} ± {np.std(xgb_accs):.3f}")
print(f"XGB mean f1 : {np.mean(xgb_f1s):.3f} ± {np.std(xgb_f1s):.3f}")
# Out:
# Per-fold results:
#    fold    rf_acc     rf_f1   xgb_acc    xgb_f1
# 0     1  0.829268  0.807184  0.756098  0.746358
# 1     2  0.853659  0.837057  0.951220  0.948910
# 2     3  0.878049  0.868584  0.829268  0.840592
# 3     4  0.853659  0.823345  0.878049  0.875400
# 4     5  0.850000  0.819118  0.850000  0.842969
#
# ===== CV Summary =====
# RF  mean acc: 0.853 ± 0.015
# RF  mean f1 : 0.831 ± 0.021
# XGB mean acc: 0.853 ± 0.064
# XGB mean f1 : 0.851 ± 0.065

# %%
sns.set_style("whitegrid")

palette = ["mediumseagreen", "royalblue"]

# 1) Accuracy comparison
acc_plot_df = results_df.melt(
    id_vars="fold",
    value_vars=["rf_acc", "xgb_acc"],
    var_name="model",
    value_name="accuracy",
)
acc_plot_df["model"] = acc_plot_df["model"].map({"rf_acc": "Random Forest", "xgb_acc": "XGBoost"})

plt.figure(figsize=(6, 4))
sns.barplot(data=acc_plot_df, x="fold", y="accuracy", hue="model", palette=palette)
plt.ylim(0, 1)
plt.title("Per-fold Accuracy")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.tight_layout()
# plt.show()
plt.savefig(ROOT_DIR / "plots" / "accuracy_comparison.pdf", dpi=300)

# 2) F1-score comparison
f1_plot_df = results_df.melt(
    id_vars="fold",
    value_vars=["rf_f1", "xgb_f1"],
    var_name="model",
    value_name="f1",
)
f1_plot_df["model"] = f1_plot_df["model"].map({"rf_f1": "Random Forest", "xgb_f1": "XGBoost"})

plt.figure(figsize=(6, 4))
sns.barplot(data=f1_plot_df, x="fold", y="f1", hue="model", palette=palette)
plt.ylim(0, 1)
plt.title("Per-fold F1-score")
plt.xlabel("Fold")
plt.ylabel("F1-score")
plt.legend(title="Model")
plt.tight_layout()
# plt.show()
plt.savefig(ROOT_DIR / "plots" / "f1score_comparison.pdf", dpi=300)

# %% [markdown]
# ### Feature Importance

# %%
rf_final = RandomForestClassifier(n_estimators=500, max_depth=None, n_jobs=-1, random_state=42)
rf_final.fit(X, y)

importances_rf = pd.Series(rf_final.feature_importances_, index=feature_cols)
print(importances_rf.sort_values(ascending=False).head(20))
# Out:
# NAWSSound_mfcc_10          0.041589
# NAWSSound_spec_centroid    0.026226
# NAWSSound_mfcc_2           0.021183
# mic_2m_spec_bandwidth      0.020553
# NAWSSound_mfcc_13          0.017064
# NAWSSound_mfcc_9           0.016544
# NAWSSound_band_0           0.015290
# mic_2m_spec_flatness       0.014938
# mic_2m_crest               0.012465
# Ch_2_labV12_mfcc_4         0.012230
# NAWSSound_crest            0.011644
# Ch_2_labV12_mfcc_5         0.011360
# NAWSSound_zcr              0.011177
# Ch_1_labV12_mfcc_13        0.010937
# Ch_3_labV12_mfcc_13        0.010777
# Ch_4_labV12_mfcc_13        0.010688
# mic_2m_spec_rolloff        0.010630
# Ch_2_labV12_mfcc_2         0.010560
# Ch_3_labV12_mfcc_12        0.010388
# mic_2m_band_1              0.010144
# dtype: float64

# %%
top10_rf = importances_rf.sort_values(ascending=False).head(10)

sns.set_style("whitegrid")

plt.figure(figsize=(8, 4))
sns.barplot(
    x=top10_rf.values,
    y=top10_rf.index,
    color="royalblue",  # single color, matches your palette
)
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.title("Top 10 Features Random Forest")
plt.tight_layout()
# plt.show()
plt.savefig(ROOT_DIR / "plots" / "rf_top10_feature_importances.pdf", dpi=300)

# %%
xgb_final = XGBClassifier(
    n_estimators=400,
    max_depth=5,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="binary:logistic",
    n_jobs=-1,
    eval_metric="logloss",
    random_state=42,
)
xgb_final.fit(X, y_enc)

xgb_feature_scores = xgb_final.get_booster().get_score(importance_type="gain")

# Convert to pandas Series
importances_xgb = (
    pd.Series(xgb_feature_scores)
    .rename(index=lambda x: feature_cols[int(x[1:])])  # maps f0 → feature name
    .sort_values(ascending=False)
)

xgb_norm = importances_xgb / importances_xgb.sum()
print(xgb_norm.head(20))
# Out:
# Ch_3_labV12_rms               0.037155
# Ch_2_labV12_mfcc_5            0.030682
# Ch_4_labV12_mfcc_1            0.029813
# NAWSSound_mfcc_10             0.028653
# Ch_1_labV12_mfcc_3            0.027113
# Ch_3_labV12_spec_bandwidth    0.023152
# Ch_1_labV12_mfcc_11           0.022716
# NAWSSound_rms                 0.019118
# Ch_1_labV12_band_4            0.018606
# mic_2m_max                    0.017997
# Ch_4_labV12_mfcc_12           0.017405
# mic_2m_rms                    0.016282
# Ch_3_labV12_band_2            0.016206
# NAWSSound_mfcc_2              0.015861
# Ch_2_labV12_mfcc_11           0.015657
# mic_2m_spec_bandwidth         0.015397
# NAWSSound_mfcc_13             0.012715
# NAWSSound_spec_centroid       0.011964
# NAWSSound_mfcc_12             0.011464
# mic_2m_mfcc_12                0.011406
# dtype: float64

# %%
top10_xgb = xgb_norm.sort_values(ascending=False).head(10)

sns.set_style("whitegrid")

plt.figure(figsize=(8, 4))
sns.barplot(
    x=top10_xgb.values,
    y=top10_xgb.index,
    color="royalblue",  # single color, matches your palette
)
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.title("Top 10 Features XGBoost")
plt.tight_layout()
# plt.show()
plt.savefig(ROOT_DIR / "plots" / "xgb_top10_feature_importances.pdf", dpi=300)
